# %% [markdown]
# # Actor Critic Algorithms
# In the DQN algorithm, we learned a Q-function by minimizing Bellman errors for an implicit policy that always took the action that maximized the Q-function. However, this scheme requires a discrete action spaces to allow for us to easily compute the optimal action at each state, unlike generic policy gradient algorithms that also worked with continuous action spaces.
#
# In this section, we will explore actor-critic algorithms which maintain an explicit policy (actor) like the policy gradient algorithms, learns a Q-function (critic) capturing the values of the _current policy_, and uses this learned Q-function to update the policy. Using a learned critic can provide much lower variance updates for the policy compared to using Monte-Carlo retun estimates, and also allows us to reuse our data by training the actor and critic on _off-policy_ data for more sample efficiency. We can thus take many more policy updates with an actor critic algorithm using our learned critic, instead of needing to wait and gather fresh samples every time.

# %%
# As usual, a bit of setup
import os
import shutil
import time
import numpy as np
import torch

import deeprl.infrastructure.pytorch_util as ptu
from deeprl.infrastructure.rl_trainer import RL_Trainer
from deeprl.infrastructure.trainers import AC_Trainer

from deeprl.policies.MLP_policy import MLPPolicyAC

# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """ returns relative error """
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

def remove_folder(path):
    # check if folder exists
    if os.path.exists(path): 
        print("Clearing old results at {}".format(path))
        # remove if exists
        shutil.rmtree(path)
    else:
        print("Folder {} does not exist yet. No old results to delete".format(path))

# %%
ac_base_args_dict = dict(
    env_name = 'Hopper-v2', #@param ['Ant-v2', 'Humanoid-v2', 'Walker2d-v2', 'HalfCheetah-v2', 'Hopper-v2']
    exp_name = 'test_ac', #@param
    save_params = False, #@param {type: "boolean"}
    
    ## PDF will tell you how to set ep_len
    ## and discount for each environment
    ep_len = 200, #@param {type: "integer"}
    discount = 0.99, #@param {type: "number"}

    # Training
    num_agent_train_steps_per_iter = 1000, #@param {type: "integer"})
    n_iter = 100, #@param {type: "integer"})

    # batches & buffers
    batch_size = 1000, #@param {type: "integer"})
    eval_batch_size = 1000, #@param {type: "integer"}
    train_batch_size = 256, #@param {type: "integer"}
    max_replay_buffer_size = 1000000, #@param {type: "integer"}

    #@markdown actor network
    n_layers = 2, #@param {type: "integer"}
    size = 256, #@param {type: "integer"}
    entropy_weight=0, #@param {type: "number"}
    learning_rate = 3e-4, #@param {type: "number"}
    
    # critic network
    critic_n_layers = 2, #@param {type: "integer"}
    critic_size = 256, #@param {type: "integer"}
    target_update_rate = 5e-3,

    #@markdown logging
    video_log_freq = -1, #@param {type: "integer"}
    scalar_log_freq = 1, #@param {type: "integer"}

    #@markdown gpu & run-time settings
    no_gpu = False, #@param {type: "boolean"}
    which_gpu = 0, #@param {type: "integer"}
    seed = 2, #@param {type: "integer"}
    logdir = 'test',
)

# %% [markdown]
# First fill out the target value calculation in the <code>compute_target_value</code> method of <code>critics/bootstrapped_continuous_critic.py</code>. Compared to the DQN critic, the key difference is that we are now estimating the value of the current policy, instead of the optimal policy as in DQN or Q-learning.
#
# To train our critic to evaluate the current policy $\pi$, we simply sample actions from the current policy in our target value. For each sample $(s,a,s')$, our loss will be
# $$L(Q_{\theta}(s, a), r(s,a) + \gamma \mathbb{E}_{a'\sim \pi(s')}[Q_{\bar \theta} (s', a')]),$$
# where $L$ is our loss function (for example squared error or the smooth L1 loss).
# In this assignment, we will simply sample a single action from the policy to estimate the target value.

# %%
# Test bellman error for policy evaluation
ac_dim = 3
ob_dim = 11
N = 5

np.random.seed(0)
obs = np.random.normal(size=(N, ob_dim))
acts = np.random.choice(ac_dim, size=(N,))
next_obs = np.random.normal(size=(N, ob_dim))
rewards = np.random.normal(size=N)
terminals = np.zeros(N)
terminals[0] = 1

ac_args = dict(ac_base_args_dict)

env_str = 'Hopper'
ac_args['env_name'] = '{}-v2'.format(env_str)
ac_args['entropy_weight'] = 0.1
actrainer = AC_Trainer(ac_args)
critic = actrainer.rl_trainer.agent.critic

class DummyDist:
    def sample(self):
        return ptu.from_numpy(1 + np.zeros(shape=(N, ac_dim)))

def dummy_actor(next_obs):
    return DummyDist()

# assumes you call actor(next_obs) to get the distribution, then call distribution.sample()
target_vals = critic.compute_target_value(ptu.from_numpy(next_obs), 
                                          ptu.from_numpy(rewards), 
                                          ptu.from_numpy(terminals), 
                                          dummy_actor)
target_vals = ptu.to_numpy(target_vals)
expected_targets = np.array([-0.9167948, -0.11123351, -0.36787638, -2.1131861,  -0.13868617])

target_error = rel_error(target_vals, expected_targets)
print("Target value error", target_error, "should be on the order of 1e-6 or lower")
# Out:
# ########################
# logging outputs to  test
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# Hopper-v2
# Target value error 1.6779968730287167e-07 should be on the order of 1e-6 or lower

# %% [markdown]
# For this section, we will also update our target network parameters as an exponential moving average of the critic parameters, instead of simply copying the current parameters periodically as in DQN. Generally, either method for target networks tends to work with appropriately chosen update rates.
#
# Fill out the update_target_parameter_ema method in <code>critics/bootstrapped_continuous_critic.py</code>.

# %%
# Test target network update
ac_args = dict(ac_base_args_dict)

env_str = 'Hopper'
ac_args['env_name'] = '{}-v2'.format(env_str)
ac_args['entropy_weight'] = 0.1
actrainer = AC_Trainer(ac_args)
critic = actrainer.rl_trainer.agent.critic

critic.target_update_rate = 0.5

# at initialization, target and critic networks are the same
for p in critic.critic_network.parameters():
    p.data += 1.
    
critic.update_target_network_ema()

for p, target_p in zip(critic.critic_network.parameters(), critic.target_network.parameters()):
    assert np.all(ptu.to_numpy((p-target_p)) == 0.5)
# Out:
# ########################
# logging outputs to  test
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# Hopper-v2

# %% [markdown]
# Next, we will implement the actor update using the learned critic instead of Monte Carlo returns.
#
# To update our policy at a particular state $s$, our previous policy gradient (using the reward to go estimator) took a step on the objective (treating $Q^{\pi}$ as a function that didn't depend on $\pi$ and using the results of a single trajectory to estimate $Q^\pi$)
# $$\mathbb E_{a \sim \pi_{\theta}(s)}[Q^{\pi_\theta}(s, a)],$$
# using the REINFORCE gradient estimator
# $$\mathbb E_{a \sim \pi_{\theta}(s)}[\nabla_{\theta} \log \pi_{\theta}(a\vert s) Q^{\pi}(s, a)].$$
# This estimator only relied on the estimated value $Q^{\pi_{\theta}}(s,a)$, so was very general and could be applied with Monte Carlo estimates of $Q^{\pi_\theta}$.
#
# One way to estimate policy gradients with an actor critic algorithm would be to directly replace the Monte Carlo estimate of $Q$ with the learned critic $Q_{\phi}$, and continue using the REINFORCE gradient estimator.
# However, we note that we can explicitly compute derivatives of our learned critic $Q(s, a)$ with respect to the action $a$, which can enable potentially better gradient estimates.
#
# In order to take advantage of this, we would also need to differentiate sampled actions $a$ with respect to our policy parameters, which we can through a technique known as the _reparameterization trick_ or the _pathwise_ estimator.
# The idea is that if our policy sampled actions according to $a \sim \mathcal N(\mu_{\theta}(s), \sigma^2_{\theta}(s))$, we can rewrite $a = f_{\theta}(z)$, where $z \sim \mathcal N(0, 1)$, and $f(z) = \mu_{\theta}(s) + z \cdot \sigma_{\theta}(s)$. Now all the randomness comes from sampling $z$, which doesn't depend on our policy, so we can now differentiate the sampled action $a$ with respect to our policy parameters $\theta$ by simply differentiating through the function $f$ applied at the random noise $z$.
#
# Using the chain rule then allows to directly estimate gradients of
# $$\mathbb{E}_{a \sim \pi_{\theta}(s)}[Q_{\phi}(s,a)]$$
# by drawing samples from $\pi$ and differentiating $Q_{\phi}(s,a)$ on the samples.
#
# Implement the actor update using this pathwise estimator in the update method of the MLPPolicyAC class in <code>policies/MLP_policy.py</code> (Hint: see the rsample function in for torch.distributions). Note that our implementation samples states uniformly from the entire replay buffer, not necessarily from the state distribution of the current policy. While this means we are no longer taking unbiased policy gradients (our estimates were already biased anyways due to using a learned critic), it works well in practice.

# %%
# Compute actor update using the policy gradient. 
# For this test to pass, make sure you only call sample once per actor update to not throw off 
# the actor samples expected for the updates in the this test.
torch.manual_seed(0)
ac_dim = 2
ob_dim = 3
batch_size = 5

np.random.seed(0)
obs = np.random.normal(size=(N, ob_dim))

policy = MLPPolicyAC(
            ac_dim=ac_dim,
            ob_dim=ob_dim,
            n_layers=1,
            size=2,
            learning_rate=0.25,
            entropy_weight=0.)

def dummy_critic(obs, acts):
    return torch.sum(acts + 1) + torch.sum(obs)

initial_loss = policy.update(obs, dummy_critic)['Actor Training Loss']
expected_initial_loss = -17.083496

print("Initial loss error", rel_error(expected_initial_loss, initial_loss), "should be on the order of 1e-6 or less.")
for i in range(5):
    loss = policy.update(obs, dummy_critic)['Actor Training Loss']
    print(loss)

expected_final_loss = -30.103575

print("Final loss error", rel_error(expected_final_loss, loss), "should be on the order of 1e-6 or less.")
# Out:
# tensor(-17.0835, grad_fn=<NegBackward>)
# Initial loss error 2.7438762975115168e-09 should be on the order of 1e-6 or less.
# tensor(-17.3147, grad_fn=<NegBackward>)
# -17.314678
# tensor(-22.6220, grad_fn=<NegBackward>)
# -22.621984
# tensor(-25.8285, grad_fn=<NegBackward>)
# -25.828484
# tensor(-29.6705, grad_fn=<NegBackward>)
# -29.670477
# tensor(-30.1036, grad_fn=<NegBackward>)
# -30.103575
# Final loss error 4.105698129439902e-09 should be on the order of 1e-6 or less.

# %% [markdown]
# Now we'll train our actor critic agent on the HalfCheetah task. You should see your policies generally get over 600 returns.
#
# We note that these actor critic algorithms, since they make use of off-policy updates, can be much more sample efficient than the basic policy gradient algorith we saw earlier. In our actor critic algorithms here, we only take 1000 new samples from the environment per iteration, while the policy gradient algorithms often needed many more samples per iteration to estimate the Monte Carlo returns (for example, we used 10000 in the Hopper experiments with policy gradient).

# %%
ac_args = dict(ac_base_args_dict)

env_str = 'HalfCheetah'
ac_args['env_name'] = '{}-v2'.format(env_str)
ac_args['n_iter'] = 50

# Delete all previous logs
remove_folder('logs/actor_critic/{}'.format(env_str))

for seed in range(3):
    print("Running actor critic experiment with seed", seed)
    ac_args['seed'] = seed
    ac_args['logdir'] = 'logs/actor_critic/{}/seed{}'.format(env_str, seed)
    actrainer = AC_Trainer(ac_args)
    actrainer.run_training_loop()
# Out:
# Clearing old results at logs/actor_critic/HalfCheetah
# Running actor critic experiment with seed 0
# ########################
# logging outputs to  logs/actor_critic/HalfCheetah/seed0
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# HalfCheetah-v2
#
#
# ********** Iteration 0 ************
#
# Collecting initial random data to be used for training...
# At timestep:     10050 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -90.31543731689453
# Eval_StdReturn : 3.3160579204559326
# Eval_MaxReturn : -85.4679946899414
# Eval_MinReturn : -95.55809020996094
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : -53.001216888427734
# Train_StdReturn : 30.279033660888672
# Train_MaxReturn : -0.5765558481216431
# Train_MinReturn : -122.80113220214844
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 10050
# TimeSinceStart : 19.503093957901
# Critic Training Loss : 0.4120471775531769
# Critic Mean : 22.111787796020508
# Actor Training Loss : -22.47426414489746
# Initial_DataCollection_AverageReturn : -53.001216888427734
# Done logging...
#
#
#
#
# ********** Iteration 1 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -97.78307342529297
# Eval_StdReturn : 5.349978446960449
# Eval_MaxReturn : -91.06309509277344
# Eval_MinReturn : -105.61219787597656
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : -89.6517562866211
# Train_StdReturn : 3.6034417152404785
# Train_MaxReturn : -86.42121887207031
# Train_MinReturn : -96.61843872070312
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 11055
# TimeSinceStart : 37.472585916519165
# Critic Training Loss : 0.6316822171211243
# Critic Mean : 22.757144927978516
# Actor Training Loss : -23.4752197265625
# Initial_DataCollection_AverageReturn : -53.001216888427734
# Done logging...
#
#
#
#
# ********** Iteration 2 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -63.86536407470703
# Eval_StdReturn : 7.189162731170654
# Eval_MaxReturn : -56.27151870727539
# Eval_MinReturn : -76.6261215209961
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : -88.07161712646484
# Train_StdReturn : 9.908499717712402
# Train_MaxReturn : -74.17724609375
# Train_MinReturn : -100.05166625976562
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 12060
# TimeSinceStart : 57.97373175621033
# Critic Training Loss : 0.3841361105442047
# Critic Mean : 32.132755279541016
# Actor Training Loss : -32.857215881347656
# Initial_DataCollection_AverageReturn : -53.001216888427734
# Done logging...
#
#
#
#
# ********** Iteration 3 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -97.3903579711914
# Eval_StdReturn : 9.765600204467773
# Eval_MaxReturn : -84.92142486572266
# Eval_MinReturn : -111.71697998046875
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : -62.48859405517578
# Train_StdReturn : 6.620045185089111
# Train_MaxReturn : -55.79359436035156
# Train_MinReturn : -74.52519226074219
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 13065
# TimeSinceStart : 74.75658798217773
# Critic Training Loss : 0.28666144609451294
# Critic Mean : 42.77250289916992
# Actor Training Loss : -43.51986312866211
# Initial_DataCollection_AverageReturn : -53.001216888427734
# Done logging...
#
#
#
#
# ********** Iteration 4 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 101.81449890136719
# Eval_StdReturn : 73.590087890625
# Eval_MaxReturn : 197.8405303955078
# Eval_MinReturn : 2.0848121643066406
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : -102.9372329711914
# Train_StdReturn : 5.541801929473877
# Train_MaxReturn : -96.9359359741211
# Train_MinReturn : -111.4508056640625
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 14070
# TimeSinceStart : 91.30949664115906
# Critic Training Loss : 0.5857940316200256
# Critic Mean : 43.82027816772461
# Actor Training Loss : -44.6623420715332
# Initial_DataCollection_AverageReturn : -53.001216888427734
# Done logging...
#
#
#
#
# ********** Iteration 5 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 187.2342529296875
# Eval_StdReturn : 18.006513595581055
# Eval_MaxReturn : 214.88336181640625
# Eval_MinReturn : 164.10281372070312
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 13.734814643859863
# Train_StdReturn : 99.12223052978516
# Train_MaxReturn : 185.78256225585938
# Train_MinReturn : -95.93589782714844
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 15075
# TimeSinceStart : 107.73943495750427
# Critic Training Loss : 0.49763432145118713
# Critic Mean : 55.6309814453125
# Actor Training Loss : -56.55696487426758
# Initial_DataCollection_AverageReturn : -53.001216888427734
# Done logging...
#
#
#
#
# ********** Iteration 6 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 171.60238647460938
# Eval_StdReturn : 5.98945951461792
# Eval_MaxReturn : 180.72361755371094
# Eval_MinReturn : 163.57455444335938
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 141.2266082763672
# Train_StdReturn : 48.363338470458984
# Train_MaxReturn : 171.39059448242188
# Train_MinReturn : 44.98249053955078
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 16080
# TimeSinceStart : 129.36425805091858
# Critic Training Loss : 0.3825988173484802
# Critic Mean : 67.79350280761719
# Actor Training Loss : -68.91513061523438
# Initial_DataCollection_AverageReturn : -53.001216888427734
# Done logging...
#
#
#
#
# ********** Iteration 7 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.3206024169922
# Eval_StdReturn : 9.213130950927734
# Eval_MaxReturn : 214.98260498046875
# Eval_MinReturn : 189.31256103515625
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 178.10482788085938
# Train_StdReturn : 11.306557655334473
# Train_MaxReturn : 186.9973602294922
# Train_MinReturn : 157.02610778808594
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 17085
# TimeSinceStart : 149.51904368400574
# Critic Training Loss : 0.8487874269485474
# Critic Mean : 84.27971649169922
# Actor Training Loss : -85.3155288696289
# Initial_DataCollection_AverageReturn : -53.001216888427734
# Done logging...
#
#
#
#
# ********** Iteration 8 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 189.4783935546875
# Eval_StdReturn : 12.381714820861816
# Eval_MaxReturn : 200.65277099609375
# Eval_MinReturn : 167.9693603515625
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 212.5233612060547
# Train_StdReturn : 16.897165298461914
# Train_MaxReturn : 232.828857421875
# Train_MinReturn : 188.9862060546875
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 18090
# TimeSinceStart : 172.36237788200378
# Critic Training Loss : 0.8079122304916382
# Critic Mean : 101.77713012695312
# Actor Training Loss : -102.97850799560547
# Initial_DataCollection_AverageReturn : -53.001216888427734
# Done logging...
#
#
#
#
# ********** Iteration 9 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 267.4636535644531
# Eval_StdReturn : 13.723531723022461
# Eval_MaxReturn : 290.33575439453125
# Eval_MinReturn : 251.95370483398438
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 211.7039794921875
# Train_StdReturn : 6.276882648468018
# Train_MaxReturn : 222.59727478027344
# Train_MinReturn : 204.82940673828125
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 19095
# TimeSinceStart : 192.3308129310608
# Critic Training Loss : 1.1227904558181763
# Critic Mean : 107.724365234375
# Actor Training Loss : -108.84867095947266
# Initial_DataCollection_AverageReturn : -53.001216888427734
# Done logging...
#
#
#
#
# ********** Iteration 10 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 296.83331298828125
# Eval_StdReturn : 13.115283966064453
# Eval_MaxReturn : 311.7648620605469
# Eval_MinReturn : 278.59674072265625
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 268.18548583984375
# Train_StdReturn : 22.93358039855957
# Train_MaxReturn : 302.7632141113281
# Train_MinReturn : 243.4164581298828
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 20100
# TimeSinceStart : 212.42126989364624
# Critic Training Loss : 0.7096513509750366
# Critic Mean : 116.7470703125
# Actor Training Loss : -117.97205352783203
# Initial_DataCollection_AverageReturn : -53.001216888427734
# Done logging...
#
#
#
#
# ********** Iteration 11 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 275.52008056640625
# Eval_StdReturn : 24.71648406982422
# Eval_MaxReturn : 302.2674255371094
# Eval_MinReturn : 238.65716552734375
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 262.54766845703125
# Train_StdReturn : 46.49913787841797
# Train_MaxReturn : 302.05145263671875
# Train_MinReturn : 173.83090209960938
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 21105
# TimeSinceStart : 234.2202627658844
# Critic Training Loss : 0.3971601128578186
# Critic Mean : 129.9991455078125
# Actor Training Loss : -131.50950622558594
# Initial_DataCollection_AverageReturn : -53.001216888427734
# Done logging...
#
#
#
#
# ********** Iteration 12 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 324.84197998046875
# Eval_StdReturn : 25.496829986572266
# Eval_MaxReturn : 358.8191223144531
# Eval_MinReturn : 294.955078125
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 272.3898010253906
# Train_StdReturn : 19.07786750793457
# Train_MaxReturn : 301.6006164550781
# Train_MinReturn : 248.78704833984375
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 22110
# TimeSinceStart : 252.47214889526367
# Critic Training Loss : 1.3314787149429321
# Critic Mean : 136.3454132080078
# Actor Training Loss : -137.70462036132812
# Initial_DataCollection_AverageReturn : -53.001216888427734
# Done logging...
#
#
#
#
# ********** Iteration 13 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 293.0935974121094
# Eval_StdReturn : 26.989919662475586
# Eval_MaxReturn : 336.1625671386719
# Eval_MinReturn : 263.2078857421875
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 279.0127258300781
# Train_StdReturn : 70.12615966796875
# Train_MaxReturn : 337.99749755859375
# Train_MinReturn : 151.46421813964844
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 23115
# TimeSinceStart : 269.1543638706207
# Critic Training Loss : 0.3973607122898102
# Critic Mean : 146.89019775390625
# Actor Training Loss : -148.13099670410156
# Initial_DataCollection_AverageReturn : -53.001216888427734
# Done logging...
#
#
#
#
# ********** Iteration 14 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 335.69390869140625
# Eval_StdReturn : 48.724693298339844
# Eval_MaxReturn : 401.54827880859375
# Eval_MinReturn : 266.28192138671875
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 288.1961364746094
# Train_StdReturn : 49.1528434753418
# Train_MaxReturn : 353.39056396484375
# Train_MinReturn : 230.09039306640625
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 24120
# TimeSinceStart : 285.8349907398224
# Critic Training Loss : 0.5009706020355225
# Critic Mean : 155.37545776367188
# Actor Training Loss : -156.8149871826172
# Initial_DataCollection_AverageReturn : -53.001216888427734
# Done logging...
#
#
#
#
# ********** Iteration 15 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 277.06787109375
# Eval_StdReturn : 168.2354278564453
# Eval_MaxReturn : 410.34759521484375
# Eval_MinReturn : -48.950111389160156
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 365.5448303222656
# Train_StdReturn : 12.299201011657715
# Train_MaxReturn : 379.7051086425781
# Train_MinReturn : 344.9490966796875
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 25125
# TimeSinceStart : 302.5659487247467
# Critic Training Loss : 1.0582960844039917
# Critic Mean : 167.90077209472656
# Actor Training Loss : -169.23219299316406
# Initial_DataCollection_AverageReturn : -53.001216888427734
# Done logging...
#
#
#
#
# ********** Iteration 16 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 263.7984619140625
# Eval_StdReturn : 111.12242889404297
# Eval_MaxReturn : 360.34375
# Eval_MinReturn : 52.150760650634766
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 327.7984313964844
# Train_StdReturn : 32.604000091552734
# Train_MaxReturn : 374.13189697265625
# Train_MinReturn : 289.69891357421875
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 26130
# TimeSinceStart : 321.1455178260803
# Critic Training Loss : 2.9898581504821777
# Critic Mean : 171.65626525878906
# Actor Training Loss : -173.0639190673828
# Initial_DataCollection_AverageReturn : -53.001216888427734
# Done logging...
#
#
#
#
# ********** Iteration 17 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 378.98138427734375
# Eval_StdReturn : 13.639175415039062
# Eval_MaxReturn : 398.6964111328125
# Eval_MinReturn : 356.18310546875
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 275.01190185546875
# Train_StdReturn : 45.963722229003906
# Train_MaxReturn : 334.61065673828125
# Train_MinReturn : 196.450439453125
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 27135
# TimeSinceStart : 341.59783601760864
# Critic Training Loss : 1.1088581085205078
# Critic Mean : 176.49319458007812
# Actor Training Loss : -177.82989501953125
# Initial_DataCollection_AverageReturn : -53.001216888427734
# Done logging...
#
#
#
#
# ********** Iteration 18 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 414.06182861328125
# Eval_StdReturn : 26.856834411621094
# Eval_MaxReturn : 435.6600036621094
# Eval_MinReturn : 361.81976318359375
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 368.78216552734375
# Train_StdReturn : 44.20267105102539
# Train_MaxReturn : 419.6199951171875
# Train_MinReturn : 286.8917541503906
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 28140
# TimeSinceStart : 358.90268778800964
# Critic Training Loss : 1.7657569646835327
# Critic Mean : 182.79037475585938
# Actor Training Loss : -184.12664794921875
# Initial_DataCollection_AverageReturn : -53.001216888427734
# Done logging...
#
#
#
#
# ********** Iteration 19 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 411.35943603515625
# Eval_StdReturn : 11.70544147491455
# Eval_MaxReturn : 423.1561279296875
# Eval_MinReturn : 390.753173828125
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 406.5242614746094
# Train_StdReturn : 29.731510162353516
# Train_MaxReturn : 442.39691162109375
# Train_MinReturn : 361.71173095703125
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 29145
# TimeSinceStart : 376.45500588417053
# Critic Training Loss : 1.1849581003189087
# Critic Mean : 193.0782928466797
# Actor Training Loss : -194.5970916748047
# Initial_DataCollection_AverageReturn : -53.001216888427734
# Done logging...
#
#
#
#
# ********** Iteration 20 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 409.3319396972656
# Eval_StdReturn : 27.54010009765625
# Eval_MaxReturn : 435.47613525390625
# Eval_MinReturn : 358.3095703125
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 423.477294921875
# Train_StdReturn : 15.362039566040039
# Train_MaxReturn : 439.6726989746094
# Train_MinReturn : 398.41143798828125
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 30150
# TimeSinceStart : 395.19729471206665
# Critic Training Loss : 1.3270334005355835
# Critic Mean : 200.65296936035156
# Actor Training Loss : -202.15895080566406
# Initial_DataCollection_AverageReturn : -53.001216888427734
# Done logging...
#
#
#
#
# ********** Iteration 21 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 298.9920654296875
# Eval_StdReturn : 35.22999572753906
# Eval_MaxReturn : 359.7818603515625
# Eval_MinReturn : 266.73486328125
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 437.71197509765625
# Train_StdReturn : 16.211833953857422
# Train_MaxReturn : 450.0612487792969
# Train_MinReturn : 406.266357421875
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 31155
# TimeSinceStart : 412.22196769714355
# Critic Training Loss : 2.3492178916931152
# Critic Mean : 211.05072021484375
# Actor Training Loss : -212.59518432617188
# Initial_DataCollection_AverageReturn : -53.001216888427734
# Done logging...
#
#
#
#
# ********** Iteration 22 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 439.94647216796875
# Eval_StdReturn : 35.0020751953125
# Eval_MaxReturn : 488.338623046875
# Eval_MinReturn : 382.490478515625
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 330.61761474609375
# Train_StdReturn : 50.47114181518555
# Train_MaxReturn : 395.1283264160156
# Train_MinReturn : 260.5400390625
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 32160
# TimeSinceStart : 429.1339650154114
# Critic Training Loss : 1.2446329593658447
# Critic Mean : 215.17645263671875
# Actor Training Loss : -216.67811584472656
# Initial_DataCollection_AverageReturn : -53.001216888427734
# Done logging...
#
#
#
#
# ********** Iteration 23 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 445.22589111328125
# Eval_StdReturn : 30.505294799804688
# Eval_MaxReturn : 466.81878662109375
# Eval_MinReturn : 385.6366882324219
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 397.9180908203125
# Train_StdReturn : 80.874267578125
# Train_MaxReturn : 453.87890625
# Train_MinReturn : 237.828369140625
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 33165
# TimeSinceStart : 445.7665238380432
# Critic Training Loss : 1.3210928440093994
# Critic Mean : 219.683349609375
# Actor Training Loss : -221.20240783691406
# Initial_DataCollection_AverageReturn : -53.001216888427734
# Done logging...
#
#
#
#
# ********** Iteration 24 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 509.85772705078125
# Eval_StdReturn : 48.882225036621094
# Eval_MaxReturn : 544.99560546875
# Eval_MinReturn : 414.1820983886719
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 454.80950927734375
# Train_StdReturn : 43.720863342285156
# Train_MaxReturn : 505.58740234375
# Train_MinReturn : 385.9092712402344
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 34170
# TimeSinceStart : 462.9415547847748
# Critic Training Loss : 3.9889326095581055
# Critic Mean : 223.17030334472656
# Actor Training Loss : -224.9337615966797
# Initial_DataCollection_AverageReturn : -53.001216888427734
# Done logging...
#
#
#
#
# ********** Iteration 25 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 500.3485412597656
# Eval_StdReturn : 52.90471267700195
# Eval_MaxReturn : 575.013671875
# Eval_MinReturn : 417.4267272949219
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 524.1512451171875
# Train_StdReturn : 27.857175827026367
# Train_MaxReturn : 565.088134765625
# Train_MinReturn : 486.4825134277344
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 35175
# TimeSinceStart : 480.42690873146057
# Critic Training Loss : 1.1054291725158691
# Critic Mean : 231.26034545898438
# Actor Training Loss : -232.7898712158203
# Initial_DataCollection_AverageReturn : -53.001216888427734
# Done logging...
#
#
#
#
# ********** Iteration 26 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 514.5335083007812
# Eval_StdReturn : 19.809560775756836
# Eval_MaxReturn : 539.83251953125
# Eval_MinReturn : 483.0474548339844
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 474.2975158691406
# Train_StdReturn : 51.001827239990234
# Train_MaxReturn : 575.2860717773438
# Train_MinReturn : 442.19805908203125
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 36180
# TimeSinceStart : 498.79463481903076
# Critic Training Loss : 0.5693395733833313
# Critic Mean : 243.82162475585938
# Actor Training Loss : -245.48858642578125
# Initial_DataCollection_AverageReturn : -53.001216888427734
# Done logging...
#
#
#
#
# ********** Iteration 27 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 560.1828002929688
# Eval_StdReturn : 31.51856803894043
# Eval_MaxReturn : 587.9317626953125
# Eval_MinReturn : 502.7074890136719
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 512.3912353515625
# Train_StdReturn : 15.46364688873291
# Train_MaxReturn : 527.61328125
# Train_MinReturn : 487.03729248046875
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 37185
# TimeSinceStart : 516.9692888259888
# Critic Training Loss : 1.4930229187011719
# Critic Mean : 249.78607177734375
# Actor Training Loss : -251.39208984375
# Initial_DataCollection_AverageReturn : -53.001216888427734
# Done logging...
#
#
#
#
# ********** Iteration 28 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 517.1954345703125
# Eval_StdReturn : 70.04631042480469
# Eval_MaxReturn : 587.4017333984375
# Eval_MinReturn : 429.808349609375
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 589.353515625
# Train_StdReturn : 38.26488494873047
# Train_MaxReturn : 638.6495971679688
# Train_MinReturn : 524.3087768554688
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 38190
# TimeSinceStart : 536.1671888828278
# Critic Training Loss : 3.098721981048584
# Critic Mean : 262.20330810546875
# Actor Training Loss : -263.8758544921875
# Initial_DataCollection_AverageReturn : -53.001216888427734
# Done logging...
#
#
#
#
# ********** Iteration 29 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 476.58856201171875
# Eval_StdReturn : 209.75050354003906
# Eval_MaxReturn : 631.4476318359375
# Eval_MinReturn : 62.29570388793945
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 544.1566162109375
# Train_StdReturn : 56.89453125
# Train_MaxReturn : 598.6533813476562
# Train_MinReturn : 450.14227294921875
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 39195
# TimeSinceStart : 554.2275969982147
# Critic Training Loss : 2.6240298748016357
# Critic Mean : 268.98797607421875
# Actor Training Loss : -270.42578125
# Initial_DataCollection_AverageReturn : -53.001216888427734
# Done logging...
#
#
#
#
# ********** Iteration 30 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 597.3634033203125
# Eval_StdReturn : 24.67791175842285
# Eval_MaxReturn : 632.3603515625
# Eval_MinReturn : 560.641845703125
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 494.20947265625
# Train_StdReturn : 82.69996643066406
# Train_MaxReturn : 628.7223510742188
# Train_MinReturn : 376.19842529296875
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 40200
# TimeSinceStart : 572.201789855957
# Critic Training Loss : 1.9566819667816162
# Critic Mean : 278.04364013671875
# Actor Training Loss : -279.6684265136719
# Initial_DataCollection_AverageReturn : -53.001216888427734
# Done logging...
#
#
#
#
# ********** Iteration 31 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 495.2774963378906
# Eval_StdReturn : 234.91329956054688
# Eval_MaxReturn : 648.01953125
# Eval_MinReturn : 27.038036346435547
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 622.6436767578125
# Train_StdReturn : 17.840892791748047
# Train_MaxReturn : 652.1217041015625
# Train_MinReturn : 597.3966064453125
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 41205
# TimeSinceStart : 590.8154196739197
# Critic Training Loss : 4.036986351013184
# Critic Mean : 288.08935546875
# Actor Training Loss : -289.7071533203125
# Initial_DataCollection_AverageReturn : -53.001216888427734
# Done logging...
#
#
#
#
# ********** Iteration 32 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 490.30072021484375
# Eval_StdReturn : 232.32740783691406
# Eval_MaxReturn : 654.0078125
# Eval_MinReturn : 33.60002136230469
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 582.2974243164062
# Train_StdReturn : 35.1473388671875
# Train_MaxReturn : 612.49853515625
# Train_MinReturn : 514.5028076171875
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 42210
# TimeSinceStart : 609.0287318229675
# Critic Training Loss : 3.0767507553100586
# Critic Mean : 292.81640625
# Actor Training Loss : -294.4369201660156
# Initial_DataCollection_AverageReturn : -53.001216888427734
# Done logging...
#
#
#
#
# ********** Iteration 33 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 567.0406494140625
# Eval_StdReturn : 60.002071380615234
# Eval_MaxReturn : 646.346923828125
# Eval_MinReturn : 476.5703430175781
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 474.763427734375
# Train_StdReturn : 30.567882537841797
# Train_MaxReturn : 500.1271057128906
# Train_MinReturn : 416.48248291015625
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 43215
# TimeSinceStart : 626.096971988678
# Critic Training Loss : 1.9880023002624512
# Critic Mean : 296.63568115234375
# Actor Training Loss : -298.4972839355469
# Initial_DataCollection_AverageReturn : -53.001216888427734
# Done logging...
#
#
#
#
# ********** Iteration 34 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 618.0841674804688
# Eval_StdReturn : 15.731854438781738
# Eval_MaxReturn : 633.287841796875
# Eval_MinReturn : 597.6011962890625
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 593.1100463867188
# Train_StdReturn : 28.768285751342773
# Train_MaxReturn : 635.1397705078125
# Train_MinReturn : 558.6045532226562
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 44220
# TimeSinceStart : 645.1739337444305
# Critic Training Loss : 1.0781759023666382
# Critic Mean : 297.1095275878906
# Actor Training Loss : -298.7528991699219
# Initial_DataCollection_AverageReturn : -53.001216888427734
# Done logging...
#
#
#
#
# ********** Iteration 35 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 459.61492919921875
# Eval_StdReturn : 158.58084106445312
# Eval_MaxReturn : 586.71923828125
# Eval_MinReturn : 156.70828247070312
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 613.1297607421875
# Train_StdReturn : 24.008928298950195
# Train_MaxReturn : 659.41162109375
# Train_MinReturn : 590.2430419921875
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 45225
# TimeSinceStart : 664.142062664032
# Critic Training Loss : 3.2026705741882324
# Critic Mean : 302.74847412109375
# Actor Training Loss : -304.64990234375
# Initial_DataCollection_AverageReturn : -53.001216888427734
# Done logging...
#
#
#
#
# ********** Iteration 36 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 474.694580078125
# Eval_StdReturn : 148.4204864501953
# Eval_MaxReturn : 607.7947998046875
# Eval_MinReturn : 211.34140014648438
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 514.409423828125
# Train_StdReturn : 151.48548889160156
# Train_MaxReturn : 608.1234130859375
# Train_MinReturn : 212.79400634765625
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 46230
# TimeSinceStart : 687.7693438529968
# Critic Training Loss : 1.8823158740997314
# Critic Mean : 306.7466125488281
# Actor Training Loss : -308.3834228515625
# Initial_DataCollection_AverageReturn : -53.001216888427734
# Done logging...
#
#
#
#
# ********** Iteration 37 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 593.1510009765625
# Eval_StdReturn : 50.5190544128418
# Eval_MaxReturn : 654.3676147460938
# Eval_MinReturn : 511.16119384765625
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 475.67681884765625
# Train_StdReturn : 169.42616271972656
# Train_MaxReturn : 636.9635620117188
# Train_MinReturn : 153.7855224609375
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 47235
# TimeSinceStart : 706.1567599773407
# Critic Training Loss : 4.389586925506592
# Critic Mean : 307.0863952636719
# Actor Training Loss : -309.1483154296875
# Initial_DataCollection_AverageReturn : -53.001216888427734
# Done logging...
#
#
#
#
# ********** Iteration 38 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 628.805419921875
# Eval_StdReturn : 19.44264030456543
# Eval_MaxReturn : 659.609130859375
# Eval_MinReturn : 604.3892822265625
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 620.7921752929688
# Train_StdReturn : 21.193235397338867
# Train_MaxReturn : 647.9297485351562
# Train_MinReturn : 586.404296875
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 48240
# TimeSinceStart : 724.6395828723907
# Critic Training Loss : 2.30329966545105
# Critic Mean : 311.0102844238281
# Actor Training Loss : -312.7687683105469
# Initial_DataCollection_AverageReturn : -53.001216888427734
# Done logging...
#
#
#
#
# ********** Iteration 39 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 467.66168212890625
# Eval_StdReturn : 212.71495056152344
# Eval_MaxReturn : 665.20263671875
# Eval_MinReturn : 126.45098114013672
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 634.91455078125
# Train_StdReturn : 20.166439056396484
# Train_MaxReturn : 655.6142578125
# Train_MinReturn : 605.255126953125
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 49245
# TimeSinceStart : 746.4156179428101
# Critic Training Loss : 2.4865026473999023
# Critic Mean : 307.655029296875
# Actor Training Loss : -309.4893493652344
# Initial_DataCollection_AverageReturn : -53.001216888427734
# Done logging...
#
#
#
#
# ********** Iteration 40 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 633.1027221679688
# Eval_StdReturn : 28.497051239013672
# Eval_MaxReturn : 672.7158203125
# Eval_MinReturn : 601.3760986328125
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 621.8262939453125
# Train_StdReturn : 27.09499740600586
# Train_MaxReturn : 641.5005493164062
# Train_MinReturn : 569.053466796875
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 50250
# TimeSinceStart : 765.5635859966278
# Critic Training Loss : 0.7600329518318176
# Critic Mean : 312.475341796875
# Actor Training Loss : -314.0750427246094
# Initial_DataCollection_AverageReturn : -53.001216888427734
# Done logging...
#
#
#
#
# ********** Iteration 41 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 650.3552856445312
# Eval_StdReturn : 16.27579689025879
# Eval_MaxReturn : 673.200927734375
# Eval_MinReturn : 625.110107421875
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 513.6384887695312
# Train_StdReturn : 196.7771759033203
# Train_MaxReturn : 673.055908203125
# Train_MinReturn : 144.61985778808594
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 51255
# TimeSinceStart : 782.8027126789093
# Critic Training Loss : 2.0555005073547363
# Critic Mean : 318.07794189453125
# Actor Training Loss : -319.6632080078125
# Initial_DataCollection_AverageReturn : -53.001216888427734
# Done logging...
#
#
#
#
# ********** Iteration 42 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 639.1412353515625
# Eval_StdReturn : 52.133262634277344
# Eval_MaxReturn : 675.3472900390625
# Eval_MinReturn : 536.2763671875
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 622.1508178710938
# Train_StdReturn : 46.29732894897461
# Train_MaxReturn : 659.581298828125
# Train_MinReturn : 531.1283569335938
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 52260
# TimeSinceStart : 800.6077959537506
# Critic Training Loss : 0.7918776869773865
# Critic Mean : 325.8370666503906
# Actor Training Loss : -327.10595703125
# Initial_DataCollection_AverageReturn : -53.001216888427734
# Done logging...
#
#
#
#
# ********** Iteration 43 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 644.9080810546875
# Eval_StdReturn : 6.920444965362549
# Eval_MaxReturn : 651.5767211914062
# Eval_MinReturn : 634.420166015625
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 627.4456787109375
# Train_StdReturn : 28.83306312561035
# Train_MaxReturn : 653.9252319335938
# Train_MinReturn : 574.9691162109375
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 53265
# TimeSinceStart : 819.5125896930695
# Critic Training Loss : 0.940638542175293
# Critic Mean : 325.6229248046875
# Actor Training Loss : -327.39990234375
# Initial_DataCollection_AverageReturn : -53.001216888427734
# Done logging...
#
#
#
#
# ********** Iteration 44 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 683.0411987304688
# Eval_StdReturn : 21.250858306884766
# Eval_MaxReturn : 709.6978759765625
# Eval_MinReturn : 649.8407592773438
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 508.1241149902344
# Train_StdReturn : 268.22430419921875
# Train_MaxReturn : 661.322265625
# Train_MinReturn : -27.86456298828125
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 54270
# TimeSinceStart : 837.7714397907257
# Critic Training Loss : 2.2258567810058594
# Critic Mean : 324.8128967285156
# Actor Training Loss : -326.49188232421875
# Initial_DataCollection_AverageReturn : -53.001216888427734
# Done logging...
#
#
#
#
# ********** Iteration 45 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 661.858642578125
# Eval_StdReturn : 31.03900718688965
# Eval_MaxReturn : 697.69921875
# Eval_MinReturn : 621.3015747070312
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 644.49755859375
# Train_StdReturn : 26.51913070678711
# Train_MaxReturn : 686.137939453125
# Train_MinReturn : 611.40576171875
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 55275
# TimeSinceStart : 856.2278327941895
# Critic Training Loss : 2.3453030586242676
# Critic Mean : 324.56201171875
# Actor Training Loss : -326.197509765625
# Initial_DataCollection_AverageReturn : -53.001216888427734
# Done logging...
#
#
#
#
# ********** Iteration 46 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 695.6813354492188
# Eval_StdReturn : 21.303354263305664
# Eval_MaxReturn : 726.2813110351562
# Eval_MinReturn : 672.074951171875
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 662.6155395507812
# Train_StdReturn : 22.749982833862305
# Train_MaxReturn : 683.82373046875
# Train_MinReturn : 619.9586181640625
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 56280
# TimeSinceStart : 874.4242260456085
# Critic Training Loss : 2.2827072143554688
# Critic Mean : 327.38079833984375
# Actor Training Loss : -329.17523193359375
# Initial_DataCollection_AverageReturn : -53.001216888427734
# Done logging...
#
#
#
#
# ********** Iteration 47 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 709.6624145507812
# Eval_StdReturn : 18.98830795288086
# Eval_MaxReturn : 737.140380859375
# Eval_MinReturn : 689.009765625
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 670.13427734375
# Train_StdReturn : 31.07035255432129
# Train_MaxReturn : 703.1193237304688
# Train_MinReturn : 626.9683227539062
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 57285
# TimeSinceStart : 895.6773638725281
# Critic Training Loss : 0.5857108235359192
# Critic Mean : 328.64227294921875
# Actor Training Loss : -330.56280517578125
# Initial_DataCollection_AverageReturn : -53.001216888427734
# Done logging...
#
#
#
#
# ********** Iteration 48 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 646.6884765625
# Eval_StdReturn : 31.3218994140625
# Eval_MaxReturn : 674.9629516601562
# Eval_MinReturn : 604.8671875
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 684.0782470703125
# Train_StdReturn : 32.45817184448242
# Train_MaxReturn : 724.260498046875
# Train_MinReturn : 639.914306640625
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 58290
# TimeSinceStart : 913.065456867218
# Critic Training Loss : 3.2328319549560547
# Critic Mean : 326.88543701171875
# Actor Training Loss : -328.48394775390625
# Initial_DataCollection_AverageReturn : -53.001216888427734
# Done logging...
#
#
#
#
# ********** Iteration 49 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 545.5596313476562
# Eval_StdReturn : 229.6579132080078
# Eval_MaxReturn : 688.46435546875
# Eval_MinReturn : 87.20921325683594
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 632.1194458007812
# Train_StdReturn : 37.926570892333984
# Train_MaxReturn : 669.4819946289062
# Train_MinReturn : 569.4964599609375
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 59295
# TimeSinceStart : 930.5553090572357
# Critic Training Loss : 5.391783714294434
# Critic Mean : 331.78125
# Actor Training Loss : -333.42926025390625
# Initial_DataCollection_AverageReturn : -53.001216888427734
# Done logging...
#
#
# Running actor critic experiment with seed 1
# ########################
# logging outputs to  logs/actor_critic/HalfCheetah/seed1
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# HalfCheetah-v2
#
#
# ********** Iteration 0 ************
#
# Collecting initial random data to be used for training...
# At timestep:     10050 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -58.46521759033203
# Eval_StdReturn : 7.3232035636901855
# Eval_MaxReturn : -45.663734436035156
# Eval_MinReturn : -67.59564208984375
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : -57.30979919433594
# Train_StdReturn : 33.58537292480469
# Train_MaxReturn : 30.625934600830078
# Train_MinReturn : -182.1383056640625
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 10050
# TimeSinceStart : 17.108444929122925
# Critic Training Loss : 0.4816415011882782
# Critic Mean : 19.301223754882812
# Actor Training Loss : -19.832839965820312
# Initial_DataCollection_AverageReturn : -57.30979919433594
# Done logging...
#
#
#
#
# ********** Iteration 1 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -82.15934753417969
# Eval_StdReturn : 12.816075325012207
# Eval_MaxReturn : -68.35099792480469
# Eval_MinReturn : -102.27639770507812
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : -64.65076446533203
# Train_StdReturn : 7.213555335998535
# Train_MaxReturn : -52.68854522705078
# Train_MinReturn : -73.40214538574219
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 11055
# TimeSinceStart : 34.034404039382935
# Critic Training Loss : 0.5570679306983948
# Critic Mean : 21.260765075683594
# Actor Training Loss : -21.853723526000977
# Initial_DataCollection_AverageReturn : -57.30979919433594
# Done logging...
#
#
#
#
# ********** Iteration 2 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -90.98243713378906
# Eval_StdReturn : 12.745438575744629
# Eval_MaxReturn : -68.52128601074219
# Eval_MinReturn : -106.88076782226562
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : -98.7354965209961
# Train_StdReturn : 21.357851028442383
# Train_MaxReturn : -81.34929656982422
# Train_MinReturn : -131.26292419433594
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 12060
# TimeSinceStart : 50.847822189331055
# Critic Training Loss : 0.798397958278656
# Critic Mean : 34.565765380859375
# Actor Training Loss : -35.30631637573242
# Initial_DataCollection_AverageReturn : -57.30979919433594
# Done logging...
#
#
#
#
# ********** Iteration 3 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -54.915313720703125
# Eval_StdReturn : 53.12058639526367
# Eval_MaxReturn : 32.72560501098633
# Eval_MinReturn : -101.84767150878906
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : -93.17149353027344
# Train_StdReturn : 3.2919929027557373
# Train_MaxReturn : -86.76609802246094
# Train_MinReturn : -96.22815704345703
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 13065
# TimeSinceStart : 68.00520706176758
# Critic Training Loss : 0.5188156366348267
# Critic Mean : 38.95003128051758
# Actor Training Loss : -39.79171371459961
# Initial_DataCollection_AverageReturn : -57.30979919433594
# Done logging...
#
#
#
#
# ********** Iteration 4 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 187.21176147460938
# Eval_StdReturn : 30.95991325378418
# Eval_MaxReturn : 220.31930541992188
# Eval_MinReturn : 135.20738220214844
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : -58.56013107299805
# Train_StdReturn : 84.87469482421875
# Train_MaxReturn : 110.83003234863281
# Train_MinReturn : -106.26580810546875
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 14070
# TimeSinceStart : 86.78352904319763
# Critic Training Loss : 0.7038437724113464
# Critic Mean : 47.83601379394531
# Actor Training Loss : -48.698333740234375
# Initial_DataCollection_AverageReturn : -57.30979919433594
# Done logging...
#
#
#
#
# ********** Iteration 5 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 168.3056182861328
# Eval_StdReturn : 12.632047653198242
# Eval_MaxReturn : 189.70468139648438
# Eval_MinReturn : 151.20053100585938
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 150.6806182861328
# Train_StdReturn : 65.72270965576172
# Train_MaxReturn : 201.96487426757812
# Train_MinReturn : 23.92174530029297
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 15075
# TimeSinceStart : 105.06553721427917
# Critic Training Loss : 0.6313395500183105
# Critic Mean : 68.84224700927734
# Actor Training Loss : -69.88292694091797
# Initial_DataCollection_AverageReturn : -57.30979919433594
# Done logging...
#
#
#
#
# ********** Iteration 6 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 272.54656982421875
# Eval_StdReturn : 22.01485824584961
# Eval_MaxReturn : 310.2273254394531
# Eval_MinReturn : 246.92807006835938
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 175.36648559570312
# Train_StdReturn : 14.447613716125488
# Train_MaxReturn : 195.92828369140625
# Train_MinReturn : 161.26052856445312
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 16080
# TimeSinceStart : 122.70465111732483
# Critic Training Loss : 0.6575114727020264
# Critic Mean : 83.2028579711914
# Actor Training Loss : -84.25135040283203
# Initial_DataCollection_AverageReturn : -57.30979919433594
# Done logging...
#
#
#
#
# ********** Iteration 7 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 308.16180419921875
# Eval_StdReturn : 19.289371490478516
# Eval_MaxReturn : 337.72796630859375
# Eval_MinReturn : 281.17047119140625
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 287.5703125
# Train_StdReturn : 21.306760787963867
# Train_MaxReturn : 316.509521484375
# Train_MinReturn : 266.3912048339844
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 17085
# TimeSinceStart : 141.41702890396118
# Critic Training Loss : 0.38757964968681335
# Critic Mean : 111.27525329589844
# Actor Training Loss : -112.60375213623047
# Initial_DataCollection_AverageReturn : -57.30979919433594
# Done logging...
#
#
#
#
# ********** Iteration 8 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 234.37368774414062
# Eval_StdReturn : 67.16026306152344
# Eval_MaxReturn : 297.82720947265625
# Eval_MinReturn : 151.32020568847656
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 290.2084655761719
# Train_StdReturn : 35.218631744384766
# Train_MaxReturn : 322.7799072265625
# Train_MinReturn : 225.53158569335938
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 18090
# TimeSinceStart : 159.90613508224487
# Critic Training Loss : 1.684713363647461
# Critic Mean : 134.4008026123047
# Actor Training Loss : -136.08255004882812
# Initial_DataCollection_AverageReturn : -57.30979919433594
# Done logging...
#
#
#
#
# ********** Iteration 9 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 281.40863037109375
# Eval_StdReturn : 34.780921936035156
# Eval_MaxReturn : 331.0842590332031
# Eval_MinReturn : 244.46905517578125
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 273.74212646484375
# Train_StdReturn : 51.470481872558594
# Train_MaxReturn : 357.42169189453125
# Train_MinReturn : 222.42965698242188
# Train_AverageEpLen : 201.0
# ...
# Train_EnvstepsSoFar : 39195
# TimeSinceStart : 557.7432789802551
# Critic Training Loss : 1.4543863534927368
# Critic Mean : 269.675048828125
# Actor Training Loss : -271.54827880859375
# Initial_DataCollection_AverageReturn : -60.98212814331055
# Done logging...
#
#
#
#
# ********** Iteration 30 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 538.0958251953125
# Eval_StdReturn : 14.682600975036621
# Eval_MaxReturn : 552.0822143554688
# Eval_MinReturn : 510.35919189453125
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 490.54766845703125
# Train_StdReturn : 42.724124908447266
# Train_MaxReturn : 545.4166870117188
# Train_MinReturn : 425.77001953125
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 40200
# TimeSinceStart : 578.2463240623474
# Critic Training Loss : 1.872257113456726
# Critic Mean : 274.506103515625
# Actor Training Loss : -276.0850830078125
# Initial_DataCollection_AverageReturn : -60.98212814331055
# Done logging...
#
#
#
#
# ********** Iteration 31 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 573.1868896484375
# Eval_StdReturn : 18.149215698242188
# Eval_MaxReturn : 596.2159423828125
# Eval_MinReturn : 545.1906127929688
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 540.3809204101562
# Train_StdReturn : 50.267276763916016
# Train_MaxReturn : 585.00634765625
# Train_MinReturn : 443.85986328125
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 41205
# TimeSinceStart : 598.1253180503845
# Critic Training Loss : 2.7803690433502197
# Critic Mean : 273.4089050292969
# Actor Training Loss : -275.31964111328125
# Initial_DataCollection_AverageReturn : -60.98212814331055
# Done logging...
#
#
#
#
# ********** Iteration 32 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 579.1251220703125
# Eval_StdReturn : 19.20098114013672
# Eval_MaxReturn : 603.049560546875
# Eval_MinReturn : 555.306396484375
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 554.920654296875
# Train_StdReturn : 27.024126052856445
# Train_MaxReturn : 588.541748046875
# Train_MinReturn : 521.9619750976562
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 42210
# TimeSinceStart : 617.6231389045715
# Critic Training Loss : 3.125213146209717
# Critic Mean : 282.0851135253906
# Actor Training Loss : -283.81353759765625
# Initial_DataCollection_AverageReturn : -60.98212814331055
# Done logging...
#
#
#
#
# ********** Iteration 33 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 481.43963623046875
# Eval_StdReturn : 33.42942428588867
# Eval_MaxReturn : 518.1423950195312
# Eval_MinReturn : 433.1734619140625
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 585.5604248046875
# Train_StdReturn : 8.024704933166504
# Train_MaxReturn : 598.2384033203125
# Train_MinReturn : 573.5638427734375
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 43215
# TimeSinceStart : 634.4186980724335
# Critic Training Loss : 3.9329354763031006
# Critic Mean : 287.6617431640625
# Actor Training Loss : -289.5848083496094
# Initial_DataCollection_AverageReturn : -60.98212814331055
# Done logging...
#
#
#
#
# ********** Iteration 34 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 600.6087646484375
# Eval_StdReturn : 16.762065887451172
# Eval_MaxReturn : 624.2099609375
# Eval_MinReturn : 575.451904296875
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 492.26544189453125
# Train_StdReturn : 99.2835922241211
# Train_MaxReturn : 615.3212890625
# Train_MinReturn : 317.64886474609375
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 44220
# TimeSinceStart : 652.0346441268921
# Critic Training Loss : 4.310113906860352
# Critic Mean : 286.0649108886719
# Actor Training Loss : -287.723876953125
# Initial_DataCollection_AverageReturn : -60.98212814331055
# Done logging...
#
#
#
#
# ********** Iteration 35 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 555.4573974609375
# Eval_StdReturn : 48.4241943359375
# Eval_MaxReturn : 620.39111328125
# Eval_MinReturn : 482.94140625
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 597.84814453125
# Train_StdReturn : 45.15799331665039
# Train_MaxReturn : 630.948486328125
# Train_MinReturn : 512.565185546875
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 45225
# TimeSinceStart : 673.2063119411469
# Critic Training Loss : 0.6638925075531006
# Critic Mean : 291.73956298828125
# Actor Training Loss : -293.18646240234375
# Initial_DataCollection_AverageReturn : -60.98212814331055
# Done logging...
#
#
#
#
# ********** Iteration 36 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 616.9111938476562
# Eval_StdReturn : 16.419330596923828
# Eval_MaxReturn : 640.8336181640625
# Eval_MinReturn : 594.8426513671875
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 585.2431030273438
# Train_StdReturn : 25.24945640563965
# Train_MaxReturn : 607.7052001953125
# Train_MinReturn : 537.6224975585938
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 46230
# TimeSinceStart : 693.8363528251648
# Critic Training Loss : 2.9628491401672363
# Critic Mean : 295.65960693359375
# Actor Training Loss : -297.3481140136719
# Initial_DataCollection_AverageReturn : -60.98212814331055
# Done logging...
#
#
#
#
# ********** Iteration 37 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 521.4378662109375
# Eval_StdReturn : 80.63067626953125
# Eval_MaxReturn : 606.1857299804688
# Eval_MinReturn : 399.44635009765625
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 608.7738647460938
# Train_StdReturn : 21.803462982177734
# Train_MaxReturn : 636.5078125
# Train_MinReturn : 579.3133544921875
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 47235
# TimeSinceStart : 713.8318619728088
# Critic Training Loss : 2.352762222290039
# Critic Mean : 294.7651672363281
# Actor Training Loss : -296.5791931152344
# Initial_DataCollection_AverageReturn : -60.98212814331055
# Done logging...
#
#
#
#
# ********** Iteration 38 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 552.7510986328125
# Eval_StdReturn : 78.61436462402344
# Eval_MaxReturn : 630.771728515625
# Eval_MinReturn : 426.482666015625
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 584.2379760742188
# Train_StdReturn : 27.437475204467773
# Train_MaxReturn : 601.0418701171875
# Train_MinReturn : 530.116455078125
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 48240
# TimeSinceStart : 732.5872118473053
# Critic Training Loss : 4.405853748321533
# Critic Mean : 302.214599609375
# Actor Training Loss : -304.10784912109375
# Initial_DataCollection_AverageReturn : -60.98212814331055
# Done logging...
#
#
#
#
# ********** Iteration 39 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 537.7100830078125
# Eval_StdReturn : 83.03443145751953
# Eval_MaxReturn : 656.6553344726562
# Eval_MinReturn : 413.2192077636719
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 571.2820434570312
# Train_StdReturn : 46.003421783447266
# Train_MaxReturn : 639.5418701171875
# Train_MinReturn : 495.91162109375
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 49245
# TimeSinceStart : 749.3755900859833
# Critic Training Loss : 3.1232471466064453
# Critic Mean : 305.4603576660156
# Actor Training Loss : -306.99822998046875
# Initial_DataCollection_AverageReturn : -60.98212814331055
# Done logging...
#
#
#
#
# ********** Iteration 40 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 607.6558837890625
# Eval_StdReturn : 35.90357971191406
# Eval_MaxReturn : 645.7451171875
# Eval_MinReturn : 542.9337768554688
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 565.2939453125
# Train_StdReturn : 77.66166687011719
# Train_MaxReturn : 643.484619140625
# Train_MinReturn : 428.44720458984375
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 50250
# TimeSinceStart : 769.0237860679626
# Critic Training Loss : 6.291599273681641
# Critic Mean : 309.32720947265625
# Actor Training Loss : -310.7425537109375
# Initial_DataCollection_AverageReturn : -60.98212814331055
# Done logging...
#
#
#
#
# ********** Iteration 41 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 618.4855346679688
# Eval_StdReturn : 19.40786361694336
# Eval_MaxReturn : 642.1265869140625
# Eval_MinReturn : 591.6922607421875
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 628.3353271484375
# Train_StdReturn : 14.839309692382812
# Train_MaxReturn : 645.353271484375
# Train_MinReturn : 601.094970703125
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 51255
# TimeSinceStart : 789.3986699581146
# Critic Training Loss : 0.6451345682144165
# Critic Mean : 309.4874572753906
# Actor Training Loss : -311.20556640625
# Initial_DataCollection_AverageReturn : -60.98212814331055
# Done logging...
#
#
#
#
# ********** Iteration 42 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 503.14019775390625
# Eval_StdReturn : 228.87074279785156
# Eval_MaxReturn : 636.1854248046875
# Eval_MinReturn : 45.86725997924805
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 629.2068481445312
# Train_StdReturn : 8.17080020904541
# Train_MaxReturn : 641.0089111328125
# Train_MinReturn : 616.1838989257812
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 52260
# TimeSinceStart : 806.4614539146423
# Critic Training Loss : 0.7561984062194824
# Critic Mean : 314.08929443359375
# Actor Training Loss : -315.8135681152344
# Initial_DataCollection_AverageReturn : -60.98212814331055
# Done logging...
#
#
#
#
# ********** Iteration 43 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 645.9093627929688
# Eval_StdReturn : 17.25695037841797
# Eval_MaxReturn : 665.8375244140625
# Eval_MinReturn : 617.29638671875
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 609.9005126953125
# Train_StdReturn : 39.82927322387695
# Train_MaxReturn : 648.5182495117188
# Train_MinReturn : 535.054931640625
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 53265
# TimeSinceStart : 825.2941689491272
# Critic Training Loss : 2.0081660747528076
# Critic Mean : 316.08203125
# Actor Training Loss : -317.45916748046875
# Initial_DataCollection_AverageReturn : -60.98212814331055
# Done logging...
#
#
#
#
# ********** Iteration 44 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 622.3663940429688
# Eval_StdReturn : 26.435522079467773
# Eval_MaxReturn : 641.6947021484375
# Eval_MinReturn : 570.530029296875
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 657.0721435546875
# Train_StdReturn : 13.625367164611816
# Train_MaxReturn : 678.0564575195312
# Train_MinReturn : 637.0604858398438
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 54270
# TimeSinceStart : 845.9921329021454
# Critic Training Loss : 1.8024344444274902
# Critic Mean : 316.3244323730469
# Actor Training Loss : -317.9708251953125
# Initial_DataCollection_AverageReturn : -60.98212814331055
# Done logging...
#
#
#
#
# ********** Iteration 45 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 647.5494384765625
# Eval_StdReturn : 4.018712043762207
# Eval_MaxReturn : 653.0950927734375
# Eval_MinReturn : 642.7655639648438
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 613.3600463867188
# Train_StdReturn : 24.872325897216797
# Train_MaxReturn : 647.72412109375
# Train_MinReturn : 572.2901611328125
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 55275
# TimeSinceStart : 866.8037238121033
# Critic Training Loss : 4.072201728820801
# Critic Mean : 317.7657470703125
# Actor Training Loss : -319.4615173339844
# Initial_DataCollection_AverageReturn : -60.98212814331055
# Done logging...
#
#
#
#
# ********** Iteration 46 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 632.6002807617188
# Eval_StdReturn : 11.259839057922363
# Eval_MaxReturn : 641.3299560546875
# Eval_MinReturn : 610.8130493164062
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 646.3557739257812
# Train_StdReturn : 9.143542289733887
# Train_MaxReturn : 660.998046875
# Train_MinReturn : 633.4808959960938
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 56280
# TimeSinceStart : 886.926362991333
# Critic Training Loss : 1.780348777770996
# Critic Mean : 323.8221435546875
# Actor Training Loss : -325.1537170410156
# Initial_DataCollection_AverageReturn : -60.98212814331055
# Done logging...
#
#
#
#
# ********** Iteration 47 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 688.8375854492188
# Eval_StdReturn : 9.903478622436523
# Eval_MaxReturn : 705.3392333984375
# Eval_MinReturn : 674.8555297851562
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 623.8350219726562
# Train_StdReturn : 40.621517181396484
# Train_MaxReturn : 663.470703125
# Train_MinReturn : 545.3272094726562
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 57285
# TimeSinceStart : 907.8192369937897
# Critic Training Loss : 3.1469473838806152
# Critic Mean : 326.8253173828125
# Actor Training Loss : -328.40460205078125
# Initial_DataCollection_AverageReturn : -60.98212814331055
# Done logging...
#
#
#
#
# ********** Iteration 48 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 645.9821166992188
# Eval_StdReturn : 10.719869613647461
# Eval_MaxReturn : 662.0472412109375
# Eval_MinReturn : 630.5006103515625
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 625.3018798828125
# Train_StdReturn : 61.92930603027344
# Train_MaxReturn : 691.676513671875
# Train_MinReturn : 510.36236572265625
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 58290
# TimeSinceStart : 926.6483089923859
# Critic Training Loss : 0.5221414566040039
# Critic Mean : 324.1800231933594
# Actor Training Loss : -325.8126220703125
# Initial_DataCollection_AverageReturn : -60.98212814331055
# Done logging...
#
#
#
#
# ********** Iteration 49 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 617.6805419921875
# Eval_StdReturn : 24.683807373046875
# Eval_MaxReturn : 635.60009765625
# Eval_MinReturn : 569.9856567382812
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 632.1180419921875
# Train_StdReturn : 19.89545440673828
# Train_MaxReturn : 651.84375
# Train_MinReturn : 597.5250244140625
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 59295
# TimeSinceStart : 943.9947459697723
# Critic Training Loss : 4.7394795417785645
# Critic Mean : 326.7402648925781
# Actor Training Loss : -328.2588195800781
# Initial_DataCollection_AverageReturn : -60.98212814331055
# Done logging...

# %%
### Visualize Actor Critic results on Halfheetah
# %load_ext tensorboard
# %tensorboard --logdir logs/actor_critic/HalfCheetah
# Out:
#       <iframe id="tensorboard-frame-e92acf30653d8cd" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-e92acf30653d8cd");
#           const url = new URL("/", window.location);
#           const port = 6013;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
