# %% [markdown]
# # Policy Gradients
# The goal in policy gradient algorithms is to maximize the expected returns of a policy $\pi_\theta$ with parameters $\theta$. Letting $\tau=((s_0, a_0, r_0), \ldots, (s_T, a_T, r_T) )$ denote a trajectory and $R(\tau)$ the return of $\tau$, this objective can be written as
# $$\max_{\theta} \mathbb E_{\tau \sim \pi_{\theta}}[R(\tau)].$$
#
# Using the REINFORCE trick, we can compute the policy gradient (the gradient of expected policy returns) as
# $$\sum_{t=0}^T \mathbb E_{s_t, a_t \sim \pi(\tau)} \nabla_{\theta} \log \pi_{\theta}(a_t \vert s_t) R(\tau).$$
#
# We can then estimate this with a very simple scheme.
# We first sample a trajectory $\tau = ((s_t, a_t, r_t))_{t=0}^\infty$ from our current policy, compute the discounted return of the trajectory as $R$, then take a stochastic estimate of the policy gradient as
#
# $$\sum_{t=0}^T \mathbb \nabla_{\theta} \log \pi_{\theta}(a_t \vert s_t) R(\tau).$$
# We can then repeat sample more trajectories to average the estimate over multiple samples.
# In practice, we will often use _discounted_ returns $\tilde R(\tau) = \sum_{t=0}^T \gamma^t r_t$ where $\gamma$ is the discount factor and our policy gradient estimate will simply replace the undiscounted returns with $\tilde R(\tau)$.

# %%
#@title imports
# As usual, a bit of setup
import os
import shutil
import time
import numpy as np
import gym
import torch

import deeprl.infrastructure.pytorch_util as ptu

from deeprl.infrastructure.rl_trainer import RL_Trainer
from deeprl.infrastructure.trainers import PG_Trainer
from deeprl.infrastructure.trainers import BC_Trainer

from deeprl.agents.pg_agent import PGAgent
from deeprl.policies.MLP_policy import MLPPolicyPG

# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """ returns relative error """
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

def remove_folder(path):
    # check if folder exists
    if os.path.exists(path): 
        print("Clearing old results at {}".format(path))
        # remove if exists
        shutil.rmtree(path)
    else:
        print("Folder {} does not exist yet. No old results to delete".format(path))

# %%
pg_base_args_dict = dict(
    env_name = 'Hopper-v2', #@param ['Ant-v2', 'Humanoid-v2', 'Walker2d-v2', 'HalfCheetah-v2', 'Hopper-v2']
    exp_name = 'test_pg', #@param
    save_params = False, #@param {type: "boolean"}
    
    ep_len = 200, #@param {type: "integer"}
    discount = 0.95, #@param {type: "number"}

    reward_to_go = True, #@param {type: "boolean"}
    nn_baseline = False, #@param {type: "boolean"}
    dont_standardize_advantages = True, #@param {type: "boolean"}

    # Training
    num_agent_train_steps_per_iter = 1, #@param {type: "integer"})
    n_iter = 100, #@param {type: "integer"})

    # batches & buffers
    batch_size = 1000, #@param {type: "integer"})
    eval_batch_size = 1000, #@param {type: "integer"}
    train_batch_size = 1000, #@param {type: "integer"}
    max_replay_buffer_size = 1000000, #@param {type: "integer"}

    #@markdown network
    n_layers = 2, #@param {type: "integer"}
    size = 64, #@param {type: "integer"}
    learning_rate = 5e-3, #@param {type: "number"}

    #@markdown logging
    video_log_freq = -1, #@param {type: "integer"}
    scalar_log_freq = 1, #@param {type: "integer"}

    #@markdown gpu & run-time settings
    no_gpu = False, #@param {type: "boolean"}
    which_gpu = 0, #@param {type: "integer"}
    seed = 2, #@param {type: "integer"}
    logdir = 'test',
)

# %% [markdown]
# ## Implementing policy gradients
# We will first compute a very naive policy gradient calculation by taking the whole discounted return of a trajectory. Fill out the method <code>_discounted_return</code> in <code>pg_agent.py</code>. Your error should be 1e-6 or lower.

# %%
### Test return computation
pg_args = dict(pg_base_args_dict)

env_str = 'CartPole'
pg_args['env_name'] = '{}-v0'.format(env_str)
pgtrainer = PG_Trainer(pg_args)
pgagent = pgtrainer.rl_trainer.agent

T = 10
np.random.seed(0)
rewards = np.random.normal(size=T)
discounted_returns = pgagent._discounted_return(rewards)

expected_return = 6.49674307
return_error = rel_error(discounted_returns, expected_return)
print("Error in return estimate is", return_error)
# Out:
# ########################
# logging outputs to  test
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# CartPole-v0
# Error in return estimate is 1.3988372177636252e-10

# %% [markdown]
# Next, we'll consider a return estimate with lower variance by taking the discounted reward-to-go at each timestep instead of the entire discounted return. More precisely, instead of taking $\sum_{t'=0}^T \gamma^{t'} r_{t'}$ as the return estimate for all timesteps $t$, we will instead use $\sum_{t'=t}^T \gamma^{t' - t} r_{t'}$ for the return estimate at timestep $t$. Fill out the method <code>_discounted_cumsum</code> in <code>pg_agent.py</code>.   Your error should be 1e-6 or lower.

# %%
### Test reward to go computations
pg_args = dict(pg_base_args_dict)

env_str = 'CartPole'
pg_args['env_name'] = '{}-v0'.format(env_str)
pgtrainer = PG_Trainer(pg_args)
pgagent = pgtrainer.rl_trainer.agent

T = 10
np.random.seed(0)
rewards = np.random.normal(size=T)
discounted_cumsum = pgagent._discounted_cumsum(rewards)
expected_cumsum = np.array([6.49674307, 4.98177971, 4.82276053, 4.04633952, 1.90046981, 0.03464402,
 1.06518095, 0.12115003, 0.28684973, 0.4105985])

return_error = rel_error(discounted_cumsum, expected_cumsum)
print("Error in return estimate is", return_error)
# Out:
# ########################
# logging outputs to  test
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# CartPole-v0
# Error in return estimate is 1.0143655677664199e-08

# %% [markdown]
# Finally, we'll use our return estimates to compute a policy gradient. Fill out the surrogate loss computation in the <code>update</code> method in MLPPolicyPG class in <code>policies/MLP_policy.py</code>.

# %%
### Test policy gradient (check gradients match what we expect)
torch.manual_seed(0)
ac_dim = 2
ob_dim = 3
batch_size = 5

policy = MLPPolicyPG(
            ac_dim=ac_dim,
            ob_dim=ob_dim,
            n_layers=1,
            size=2,
            learning_rate=0.25)

np.random.seed(0)
obs = np.random.normal(size=(batch_size, ob_dim))
acts = np.random.normal(size=(batch_size, ac_dim))
advs = 1000 * np.random.normal(size=(batch_size,))

first_weight_before = np.array(ptu.to_numpy(next(policy.mean_net.parameters())))
print("Weight before update", first_weight_before)

for i in range(5):
    loss = policy.update(obs, acts, advs)['Training Loss']

print(loss)
expected_loss = -6142.9116
loss_error = rel_error(loss, expected_loss)
print("Loss Error", loss_error, "should be on the order of 1e-6 or lower")

first_weight_after = ptu.to_numpy(next(policy.mean_net.parameters()))
print('Weight after update', first_weight_after)

weight_change = first_weight_after - first_weight_before
print("Change in weights", weight_change)

expected_change = np.array([[ 1.035012, 1.0455959, 0.11085394],
                            [-1.1532364, -0.5915445, 0.557522]])
updated_weight_error = rel_error(weight_change, expected_change)
print("Weight Update Error", updated_weight_error, "should be on the order of 1e-6 or lower")
# Out:
# Weight before update [[-0.00432253  0.30971587 -0.47518533]
#  [-0.42489457 -0.22236899  0.15482074]]
# -6142.9126
# Loss Error 8.120385198316438e-08 should be on the order of 1e-6 or lower
# Weight after update [[ 1.0306895   1.3553118  -0.36433142]
#  [-1.5781313  -0.81391037  0.7123427 ]]
# Change in weights [[ 1.035012    1.0455959   0.11085391]
#  [-1.1532367  -0.5915414   0.55752194]]
# Weight Update Error 2.6122426803972157e-06 should be on the order of 1e-6 or lower

# %% [markdown]
# We can compare the two return estimators on a simple environment and compare how well they do.

# %%
pg_args = dict(pg_base_args_dict)

env_str = 'CartPole'
pg_args['env_name'] = '{}-v0'.format(env_str)
pg_args['reward_to_go'] = False
pg_args['n_iter'] = 100

# Delete all previous logs
remove_folder('logs/policy_gradient/{}/full_returns/'.format(env_str))

for seed in range(3):
    print("Running policy gradient experiment with seed", seed)
    pg_args['seed'] = seed
    pg_args['logdir'] = 'logs/policy_gradient/{}/full_returns/seed{}'.format(env_str, seed)
    pgtrainer = PG_Trainer(pg_args)
    pgtrainer.run_training_loop()
# Out:
# Folder logs/policy_gradient/CartPole/full_returns/ does not exist yet. No old results to delete
# Running policy gradient experiment with seed 0
# ########################
# logging outputs to  logs/policy_gradient/CartPole/full_returns/seed0
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# CartPole-v0
#
#
# ********** Iteration 0 ************
#
# Collecting data to be used for training...
# At timestep:     1012 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 29.285715103149414
# Eval_StdReturn : 16.32451629638672
# Eval_MaxReturn : 86.0
# Eval_MinReturn : 10.0
# Eval_AverageEpLen : 29.285714285714285
# Train_AverageReturn : 22.0
# Train_StdReturn : 10.642409324645996
# Train_MaxReturn : 51.0
# Train_MinReturn : 9.0
# Train_AverageEpLen : 22.0
# Train_EnvstepsSoFar : 1012
# TimeSinceStart : 0.915996789932251
# Training Loss : 9.748507499694824
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 1 ************
#
# Collecting data to be used for training...
# At timestep:     1016 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 28.2500
# Eval_StdReturn : 13.697880744934082
# Eval_MaxReturn : 72.0
# Eval_MinReturn : 12.0
# Eval_AverageEpLen : 28.25
# Train_AverageReturn : 23.627906799316406
# Train_StdReturn : 11.442522048950195
# Train_MaxReturn : 58.0
# Train_MinReturn : 13.0
# Train_AverageEpLen : 23.627906976744185
# Train_EnvstepsSoFar : 2028
# TimeSinceStart : 2.132784843444824
# Training Loss : 9.987648010253906
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 2 ************
#
# Collecting data to be used for training...
# At timestep:     1079 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 27.027027130126953
# Eval_StdReturn : 13.28377628326416
# Eval_MaxReturn : 63.0
# Eval_MinReturn : 9.0
# Eval_AverageEpLen : 27.027027027027028
# Train_AverageReturn : 29.16216278076172
# Train_StdReturn : 17.249385833740234
# Train_MaxReturn : 98.0
# Train_MinReturn : 8.0
# Train_AverageEpLen : 29.16216216216216
# Train_EnvstepsSoFar : 3107
# TimeSinceStart : 3.330192804336548
# Training Loss : 10.928593635559082
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 3 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 31.84375
# Eval_StdReturn : 14.809433937072754
# Eval_MaxReturn : 88.0
# Eval_MinReturn : 11.0
# Eval_AverageEpLen : 31.84375
# Train_AverageReturn : 29.41176414489746
# Train_StdReturn : 14.167314529418945
# Train_MaxReturn : 75.0
# Train_MinReturn : 11.0
# Train_AverageEpLen : 29.41176470588235
# Train_EnvstepsSoFar : 4107
# TimeSinceStart : 4.41122579574585
# Training Loss : 10.72243881225586
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 4 ************
#
# Collecting data to be used for training...
# At timestep:     1058 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 40.31999969482422
# Eval_StdReturn : 27.21575927734375
# Eval_MaxReturn : 125.0
# Eval_MinReturn : 15.0
# Eval_AverageEpLen : 40.32
# Train_AverageReturn : 32.06060791015625
# Train_StdReturn : 22.581756591796875
# Train_MaxReturn : 98.0
# Train_MinReturn : 11.0
# Train_AverageEpLen : 32.06060606060606
# Train_EnvstepsSoFar : 5165
# TimeSinceStart : 5.3574018478393555
# Training Loss : 11.185359001159668
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 5 ************
#
# Collecting data to be used for training...
# At timestep:     1042 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 26.128204345703125
# Eval_StdReturn : 14.0277738571167
# Eval_MaxReturn : 73.0
# Eval_MinReturn : 10.0
# Eval_AverageEpLen : 26.128205128205128
# Train_AverageReturn : 30.647058486938477
# Train_StdReturn : 16.591781616210938
# Train_MaxReturn : 84.0
# Train_MinReturn : 10.0
# Train_AverageEpLen : 30.647058823529413
# Train_EnvstepsSoFar : 6207
# TimeSinceStart : 6.266180038452148
# Training Loss : 10.851187705993652
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 6 ************
#
# Collecting data to be used for training...
# At timestep:     1012 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 25.049999237060547
# Eval_StdReturn : 15.287168502807617
# Eval_MaxReturn : 84.0
# Eval_MinReturn : 10.0
# Eval_AverageEpLen : 25.05
# Train_AverageReturn : 24.095237731933594
# Train_StdReturn : 10.919204711914062
# Train_MaxReturn : 57.0
# Train_MinReturn : 9.0
# Train_AverageEpLen : 24.095238095238095
# Train_EnvstepsSoFar : 7219
# TimeSinceStart : 7.193159818649292
# Training Loss : 9.761499404907227
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 7 ************
#
# Collecting data to be used for training...
# At timestep:     1050 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 21.84782600402832
# Eval_StdReturn : 7.703661918640137
# Eval_MaxReturn : 49.0
# Eval_MinReturn : 9.0
# Eval_AverageEpLen : 21.847826086956523
# Train_AverageReturn : 24.418603897094727
# Train_StdReturn : 17.236024856567383
# Train_MaxReturn : 104.0
# Train_MinReturn : 10.0
# Train_AverageEpLen : 24.41860465116279
# Train_EnvstepsSoFar : 8269
# TimeSinceStart : 8.287901878356934
# Training Loss : 9.838366508483887
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 8 ************
#
# Collecting data to be used for training...
# At timestep:     1060 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 20.219999313354492
# Eval_StdReturn : 9.61933422088623
# Eval_MaxReturn : 71.0
# Eval_MinReturn : 9.0
# Eval_AverageEpLen : 20.22
# Train_AverageReturn : 20.384614944458008
# Train_StdReturn : 12.580745697021484
# Train_MaxReturn : 86.0
# Train_MinReturn : 10.0
# Train_AverageEpLen : 20.384615384615383
# Train_EnvstepsSoFar : 9329
# TimeSinceStart : 9.194105863571167
# Training Loss : 8.916958808898926
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 9 ************
#
# Collecting data to be used for training...
# At timestep:     1014 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 23.581396102905273
# Eval_StdReturn : 10.796710014343262
# Eval_MaxReturn : 58.0
# Eval_MinReturn : 9.0
# Eval_AverageEpLen : 23.58139534883721
# Train_AverageReturn : 22.04347801208496
# Train_StdReturn : 10.46725082397461
# Train_MaxReturn : 57.0
# Train_MinReturn : 10.0
# Train_AverageEpLen : 22.043478260869566
# Train_EnvstepsSoFar : 10343
# TimeSinceStart : 10.053515911102295
# Training Loss : 9.301703453063965
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 10 ************
#
# Collecting data to be used for training...
# At timestep:     1016 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 26.736841201782227
# Eval_StdReturn : 17.958555221557617
# Eval_MaxReturn : 88.0
# Eval_MinReturn : 10.0
# Eval_AverageEpLen : 26.736842105263158
# Train_AverageReturn : 19.921567916870117
# Train_StdReturn : 6.927759170532227
# Train_MaxReturn : 38.0
# Train_MinReturn : 9.0
# Train_AverageEpLen : 19.92156862745098
# Train_EnvstepsSoFar : 11359
# TimeSinceStart : 10.905659914016724
# Training Loss : 8.595572471618652
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 11 ************
#
# Collecting data to be used for training...
# At timestep:     1010 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 23.744186401367188
# Eval_StdReturn : 9.298894882202148
# Eval_MaxReturn : 52.0
# Eval_MinReturn : 11.0
# Eval_AverageEpLen : 23.74418604651163
# Train_AverageReturn : 22.44444465637207
# Train_StdReturn : 9.083698272705078
# Train_MaxReturn : 56.0
# Train_MinReturn : 11.0
# Train_AverageEpLen : 22.444444444444443
# Train_EnvstepsSoFar : 12369
# TimeSinceStart : 12.002454996109009
# Training Loss : 9.202675819396973
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 12 ************
#
# Collecting data to be used for training...
# At timestep:     1027 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 24.9761905670166
# Eval_StdReturn : 15.09255313873291
# Eval_MaxReturn : 81.0
# Eval_MinReturn : 11.0
# Eval_AverageEpLen : 24.976190476190474
# Train_AverageReturn : 24.452381134033203
# Train_StdReturn : 11.658232688903809
# Train_MaxReturn : 64.0
# Train_MinReturn : 10.0
# Train_AverageEpLen : 24.452380952380953
# Train_EnvstepsSoFar : 13396
# TimeSinceStart : 14.014611959457397
# Training Loss : 9.670610427856445
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 13 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 31.176469802856445
# Eval_StdReturn : 17.550716400146484
# Eval_MaxReturn : 90.0
# Eval_MinReturn : 11.0
# Eval_AverageEpLen : 31.176470588235293
# Train_AverageReturn : 28.714284896850586
# Train_StdReturn : 17.815837860107422
# Train_MaxReturn : 88.0
# Train_MinReturn : 10.0
# Train_AverageEpLen : 28.714285714285715
# Train_EnvstepsSoFar : 14401
# TimeSinceStart : 14.863624811172485
# Training Loss : 10.350377082824707
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 14 ************
#
# Collecting data to be used for training...
# At timestep:     1011 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 33.19355010986328
# Eval_StdReturn : 15.567583084106445
# Eval_MaxReturn : 65.0
# Eval_MinReturn : 14.0
# Eval_AverageEpLen : 33.193548387096776
# Train_AverageReturn : 29.735294342041016
# Train_StdReturn : 15.810102462768555
# Train_MaxReturn : 92.0
# Train_MinReturn : 9.0
# Train_AverageEpLen : 29.735294117647058
# Train_EnvstepsSoFar : 15412
# TimeSinceStart : 15.740815877914429
# Training Loss : 10.250404357910156
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 15 ************
#
# Collecting data to be used for training...
# At timestep:     1029 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 35.89655303955078
# Eval_StdReturn : 16.942794799804688
# Eval_MaxReturn : 72.0
# Eval_MinReturn : 11.0
# Eval_AverageEpLen : 35.89655172413793
# Train_AverageReturn : 39.57692337036133
# Train_StdReturn : 17.78973960876465
# Train_MaxReturn : 95.0
# Train_MinReturn : 15.0
# Train_AverageEpLen : 39.57692307692308
# Train_EnvstepsSoFar : 16441
# TimeSinceStart : 16.649106979370117
# Training Loss : 11.268746376037598
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 16 ************
#
# Collecting data to be used for training...
# At timestep:     1110 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 49.0000/ 1000
# Eval_StdReturn : 26.56169891357422
# Eval_MaxReturn : 120.0
# Eval_MinReturn : 22.0
# Eval_AverageEpLen : 49.0
# Train_AverageReturn : 44.400001525878906
# Train_StdReturn : 35.090736389160156
# Train_MaxReturn : 137.0
# Train_MinReturn : 10.0
# Train_AverageEpLen : 44.4
# Train_EnvstepsSoFar : 17551
# TimeSinceStart : 17.548240900039673
# Training Loss : 11.600893020629883
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 17 ************
#
# Collecting data to be used for training...
# At timestep:     1001 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 55.52631759643555
# Eval_StdReturn : 36.80727767944336
# Eval_MaxReturn : 177.0
# Eval_MinReturn : 11.0
# Eval_AverageEpLen : 55.526315789473685
# Train_AverageReturn : 43.5217399597168
# Train_StdReturn : 23.8580379486084
# Train_MaxReturn : 138.0
# Train_MinReturn : 14.0
# Train_AverageEpLen : 43.52173913043478
# Train_EnvstepsSoFar : 18552
# TimeSinceStart : 18.58245873451233
# Training Loss : 11.457797050476074
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 18 ************
#
# Collecting data to be used for training...
# At timestep:     1002 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 47.272727966308594
# Eval_StdReturn : 21.0738582611084
# Eval_MaxReturn : 100.0
# Eval_MinReturn : 20.0
# Eval_AverageEpLen : 47.27272727272727
# Train_AverageReturn : 41.75
# Train_StdReturn : 22.666513442993164
# Train_MaxReturn : 123.0
# Train_MinReturn : 18.0
# Train_AverageEpLen : 41.75
# Train_EnvstepsSoFar : 19554
# TimeSinceStart : 19.498903036117554
# Training Loss : 11.096564292907715
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 19 ************
#
# Collecting data to be used for training...
# At timestep:     1077 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 35.7931022644043
# Eval_StdReturn : 18.41921615600586
# Eval_MaxReturn : 83.0
# Eval_MinReturn : 15.0
# Eval_AverageEpLen : 35.793103448275865
# Train_AverageReturn : 51.28571319580078
# Train_StdReturn : 33.38825225830078
# Train_MaxReturn : 133.0
# Train_MinReturn : 15.0
# Train_AverageEpLen : 51.285714285714285
# Train_EnvstepsSoFar : 20631
# TimeSinceStart : 20.500369787216187
# Training Loss : 11.529394149780273
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 20 ************
#
# Collecting data to be used for training...
# At timestep:     1015 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 42.04166793823242
# Eval_StdReturn : 14.76617431640625
# Eval_MaxReturn : 74.0
# Eval_MinReturn : 15.0
# Eval_AverageEpLen : 42.041666666666664
# Train_AverageReturn : 36.25
# Train_StdReturn : 13.083864212036133
# Train_MaxReturn : 65.0
# Train_MinReturn : 11.0
# Train_AverageEpLen : 36.25
# Train_EnvstepsSoFar : 21646
# TimeSinceStart : 21.36229181289673
# Training Loss : 10.678284645080566
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 21 ************
#
# Collecting data to be used for training...
# At timestep:     1042 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 35.89285659790039
# Eval_StdReturn : 16.303680419921875
# Eval_MaxReturn : 91.0
# Eval_MinReturn : 16.0
# Eval_AverageEpLen : 35.892857142857146
# Train_AverageReturn : 37.21428680419922
# Train_StdReturn : 14.069615364074707
# Train_MaxReturn : 78.0
# Train_MinReturn : 17.0
# Train_AverageEpLen : 37.214285714285715
# Train_EnvstepsSoFar : 22688
# TimeSinceStart : 22.57807683944702
# Training Loss : 10.77242660522461
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 22 ************
#
# Collecting data to be used for training...
# At timestep:     1019 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 40.599998474121094
# Eval_StdReturn : 25.285568237304688
# Eval_MaxReturn : 128.0
# Eval_MinReturn : 21.0
# Eval_AverageEpLen : 40.6
# Train_AverageReturn : 36.39285659790039
# Train_StdReturn : 17.50783348083496
# Train_MaxReturn : 106.0
# Train_MinReturn : 12.0
# Train_AverageEpLen : 36.392857142857146
# Train_EnvstepsSoFar : 23707
# TimeSinceStart : 24.77009081840515
# Training Loss : 10.389925956726074
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 23 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 41.66666793823242
# Eval_StdReturn : 19.400745391845703
# Eval_MaxReturn : 83.0
# Eval_MinReturn : 18.0
# Eval_AverageEpLen : 41.666666666666664
# Train_AverageReturn : 35.89285659790039
# Train_StdReturn : 19.317533493041992
# Train_MaxReturn : 104.0
# Train_MinReturn : 16.0
# Train_AverageEpLen : 35.892857142857146
# Train_EnvstepsSoFar : 24712
# TimeSinceStart : 26.363645792007446
# Training Loss : 10.532182693481445
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 24 ************
#
# Collecting data to be used for training...
# At timestep:     1008 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 44.130435943603516
# Eval_StdReturn : 15.255232810974121
# Eval_MaxReturn : 71.0
# Eval_MinReturn : 16.0
# Eval_AverageEpLen : 44.130434782608695
# Train_AverageReturn : 37.33333206176758
# Train_StdReturn : 17.68657112121582
# Train_MaxReturn : 103.0
# Train_MinReturn : 11.0
# Train_AverageEpLen : 37.333333333333336
# Train_EnvstepsSoFar : 25720
# TimeSinceStart : 27.592190980911255
# Training Loss : 10.478879928588867
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 25 ************
#
# Collecting data to be used for training...
# At timestep:     1037 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 43.54166793823242
# Eval_StdReturn : 17.387685775756836
# Eval_MaxReturn : 83.0
# Eval_MinReturn : 15.0
# Eval_AverageEpLen : 43.541666666666664
# Train_AverageReturn : 51.849998474121094
# Train_StdReturn : 39.05288314819336
# Train_MaxReturn : 174.0
# Train_MinReturn : 14.0
# Train_AverageEpLen : 51.85
# Train_EnvstepsSoFar : 26757
# TimeSinceStart : 29.4318368434906
# Training Loss : 11.09473705291748
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 26 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 41.70833206176758
# Eval_StdReturn : 15.616442680358887
# Eval_MaxReturn : 78.0
# Eval_MinReturn : 24.0
# Eval_AverageEpLen : 41.708333333333336
# Train_AverageReturn : 38.653846740722656
# Train_StdReturn : 17.946378707885742
# Train_MaxReturn : 107.0
# Train_MinReturn : 16.0
# Train_AverageEpLen : 38.65384615384615
# Train_EnvstepsSoFar : 27762
# TimeSinceStart : 30.482479095458984
# Training Loss : 10.619898796081543
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 27 ************
#
# Collecting data to be used for training...
# At timestep:     1021 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 42.040000915527344
# Eval_StdReturn : 17.512235641479492
# Eval_MaxReturn : 80.0
# Eval_MinReturn : 17.0
# Eval_AverageEpLen : 42.04
# Train_AverageReturn : 46.40909194946289
# Train_StdReturn : 22.266279220581055
# Train_MaxReturn : 106.0
# Train_MinReturn : 15.0
# Train_AverageEpLen : 46.40909090909091
# Train_EnvstepsSoFar : 28783
# TimeSinceStart : 31.4616539478302
# Training Loss : 11.114814758300781
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 28 ************
#
# Collecting data to be used for training...
# At timestep:     1081 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 45.5217399597168
# Eval_StdReturn : 19.92566680908203
# Eval_MaxReturn : 99.0
# Eval_MinReturn : 20.0
# Eval_AverageEpLen : 45.52173913043478
# Train_AverageReturn : 54.04999923706055
# Train_StdReturn : 30.408016204833984
# Train_MaxReturn : 138.0
# Train_MinReturn : 17.0
# Train_AverageEpLen : 54.05
# Train_EnvstepsSoFar : 29864
# TimeSinceStart : 32.57888889312744
# Training Loss : 11.040985107421875
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 29 ************
#
# Collecting data to be used for training...
# At timestep:     1012 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 52.68421173095703
# Eval_StdReturn : 29.943897247314453
# Eval_MaxReturn : 161.0
# Eval_MinReturn : 16.0
# Eval_AverageEpLen : 52.68421052631579
# Train_AverageReturn : 48.19047546386719
# Train_StdReturn : 15.734763145446777
# Train_MaxReturn : 86.0
# Train_MinReturn : 27.0
# Train_AverageEpLen : 48.19047619047619
# Train_EnvstepsSoFar : 30876
# TimeSinceStart : 33.69723391532898
# Training Loss : 10.9463529586792
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 30 ************
#
# Collecting data to be used for training...
# At timestep:     1045 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 66.5000
# Eval_StdReturn : 35.00892639160156
# Eval_MaxReturn : 175.0
# Eval_MinReturn : 33.0
# Eval_AverageEpLen : 66.5
# Train_AverageReturn : 45.434783935546875
# Train_StdReturn : 16.314373016357422
# Train_MaxReturn : 79.0
# Train_MinReturn : 22.0
# Train_AverageEpLen : 45.43478260869565
# Train_EnvstepsSoFar : 31921
# TimeSinceStart : 34.643624782562256
# Training Loss : 10.755820274353027
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 31 ************
#
# Collecting data to be used for training...
# At timestep:     1008 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 64.0625
# Eval_StdReturn : 37.327049255371094
# Eval_MaxReturn : 168.0
# Eval_MinReturn : 27.0
# Eval_AverageEpLen : 64.0625
# Train_AverageReturn : 59.29411697387695
# Train_StdReturn : 23.957719802856445
# Train_MaxReturn : 121.0
# Train_MinReturn : 28.0
# Train_AverageEpLen : 59.294117647058826
# Train_EnvstepsSoFar : 32929
# TimeSinceStart : 35.59019184112549
# Training Loss : 11.54281234741211
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 32 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 61.764705657958984
# Eval_StdReturn : 27.967479705810547
# Eval_MaxReturn : 141.0
# Eval_MinReturn : 25.0
# Eval_AverageEpLen : 61.76470588235294
# Train_AverageReturn : 55.83333206176758
# Train_StdReturn : 26.955209732055664
# Train_MaxReturn : 157.0
# Train_MinReturn : 26.0
# Train_AverageEpLen : 55.833333333333336
# Train_EnvstepsSoFar : 33934
# TimeSinceStart : 36.64864993095398
# Training Loss : 11.143712997436523
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 33 ************
#
# Collecting data to be used for training...
# At timestep:     1122 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 65.5625
# Eval_StdReturn : 38.634456634521484
# Eval_MaxReturn : 172.0
# Eval_MinReturn : 21.0
# Eval_AverageEpLen : 65.5625
# Train_AverageReturn : 86.30769348144531
# Train_StdReturn : 38.31124496459961
# Train_MaxReturn : 154.0
# Train_MinReturn : 16.0
# Train_AverageEpLen : 86.3076923076923
# Train_EnvstepsSoFar : 35056
# TimeSinceStart : 37.76370096206665
# Training Loss : 11.609509468078613
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 34 ************
#
# Collecting data to be used for training...
# At timestep:     1053 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 74.42857360839844
# Eval_StdReturn : 26.029420852661133
# Eval_MaxReturn : 132.0
# Eval_MinReturn : 36.0
# Eval_AverageEpLen : 74.42857142857143
# Train_AverageReturn : 81.0
# Train_StdReturn : 33.53528594970703
# Train_MaxReturn : 125.0
# Train_MinReturn : 31.0
# Train_AverageEpLen : 81.0
# Train_EnvstepsSoFar : 36109
# TimeSinceStart : 39.341325998306274
# Training Loss : 11.519268989562988
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 35 ************
#
# Collecting data to be used for training...
# At timestep:     1078 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 75.64286041259766
# Eval_StdReturn : 21.95322036743164
# Eval_MaxReturn : 135.0
# Eval_MinReturn : 52.0
# Eval_AverageEpLen : 75.64285714285714
# Train_AverageReturn : 63.411766052246094
# Train_StdReturn : 28.832290649414062
# Train_MaxReturn : 146.0
# Train_MinReturn : 28.0
# Train_AverageEpLen : 63.411764705882355
# Train_EnvstepsSoFar : 37187
# TimeSinceStart : 40.24293279647827
# Training Loss : 11.340380668640137
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 36 ************
#
# Collecting data to be used for training...
# At timestep:     1021 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 101.69999694824219
# Eval_StdReturn : 32.4839973449707
# Eval_MaxReturn : 154.0
# Eval_MinReturn : 45.0
# Eval_AverageEpLen : 101.7
# Train_AverageReturn : 72.92857360839844
# Train_StdReturn : 23.057270050048828
# Train_MaxReturn : 106.0
# Train_MinReturn : 25.0
# Train_AverageEpLen : 72.92857142857143
# Train_EnvstepsSoFar : 38208
# TimeSinceStart : 41.09536099433899
# Training Loss : 11.56374740600586
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 37 ************
#
# Collecting data to be used for training...
# At timestep:     1053 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 84.66666412353516
# Eval_StdReturn : 29.519296646118164
# Eval_MaxReturn : 154.0
# Eval_MinReturn : 36.0
# Eval_AverageEpLen : 84.66666666666667
# Train_AverageReturn : 87.75
# Train_StdReturn : 51.410316467285156
# Train_MaxReturn : 181.0
# Train_MinReturn : 33.0
# Train_AverageEpLen : 87.75
# Train_EnvstepsSoFar : 39261
# TimeSinceStart : 41.92179083824158
# Training Loss : 11.431988716125488
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 38 ************
#
# Collecting data to be used for training...
# At timestep:     1072 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 70.0000
# Eval_StdReturn : 25.52123260498047
# Eval_MaxReturn : 116.0
# Eval_MinReturn : 28.0
# Eval_AverageEpLen : 70.0
# Train_AverageReturn : 107.19999694824219
# Train_StdReturn : 50.69674301147461
# Train_MaxReturn : 200.0
# Train_MinReturn : 51.0
# Train_AverageEpLen : 107.2
# Train_EnvstepsSoFar : 40333
# TimeSinceStart : 42.81067109107971
# Training Loss : 11.579239845275879
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 39 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 82.64286041259766
# Eval_StdReturn : 45.736209869384766
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 34.0
# Eval_AverageEpLen : 82.64285714285714
# Train_AverageReturn : 100.5
# Train_StdReturn : 51.892677307128906
# Train_MaxReturn : 200.0
# Train_MinReturn : 36.0
# Train_AverageEpLen : 100.5
# Train_EnvstepsSoFar : 41338
# TimeSinceStart : 43.67454481124878
# Training Loss : 11.626072883605957
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 40 ************
#
# Collecting data to be used for training...
# At timestep:     1069 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 101.9000015258789
# Eval_StdReturn : 47.382381439208984
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 52.0
# Eval_AverageEpLen : 101.9
# Train_AverageReturn : 89.08333587646484
# Train_StdReturn : 21.441619873046875
# Train_MaxReturn : 121.0
# Train_MinReturn : 52.0
# Train_AverageEpLen : 89.08333333333333
# Train_EnvstepsSoFar : 42407
# TimeSinceStart : 44.56295990943909
# Training Loss : 11.43665599822998
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 41 ************
#
# Collecting data to be used for training...
# At timestep:     1055 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 110.4000015258789
# Eval_StdReturn : 43.909454345703125
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 39.0
# Eval_AverageEpLen : 110.4
# Train_AverageReturn : 87.91666412353516
# Train_StdReturn : 45.71735382080078
# Train_MaxReturn : 164.0
# Train_MinReturn : 17.0
# Train_AverageEpLen : 87.91666666666667
# Train_EnvstepsSoFar : 43462
# TimeSinceStart : 45.44133973121643
# Training Loss : 11.287755966186523
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 42 ************
#
# Collecting data to be used for training...
# At timestep:     1072 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 109.5999984741211
# Eval_StdReturn : 46.40732955932617
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 53.0
# Eval_AverageEpLen : 109.6
# Train_AverageReturn : 119.11111450195312
# Train_StdReturn : 55.6146354675293
# Train_MaxReturn : 200.0
# Train_MinReturn : 39.0
# Train_AverageEpLen : 119.11111111111111
# Train_EnvstepsSoFar : 44534
# TimeSinceStart : 46.38178086280823
# Training Loss : 11.392969131469727
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 43 ************
#
# Collecting data to be used for training...
# At timestep:     1067 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 94.90908813476562
# Eval_StdReturn : 31.63558006286621
# Eval_MaxReturn : 154.0
# Eval_MinReturn : 47.0
# Eval_AverageEpLen : 94.9090909090909
# Train_AverageReturn : 118.55555725097656
# Train_StdReturn : 33.41360855102539
# Train_MaxReturn : 177.0
# Train_MinReturn : 81.0
# Train_AverageEpLen : 118.55555555555556
# Train_EnvstepsSoFar : 45601
# TimeSinceStart : 47.407634973526
# Training Loss : 11.232108116149902
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 44 ************
#
# Collecting data to be used for training...
# At timestep:     1179 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 93.18181610107422
# Eval_StdReturn : 43.01335144042969
# Eval_MaxReturn : 170.0
# Eval_MinReturn : 36.0
# Eval_AverageEpLen : 93.18181818181819
# Train_AverageReturn : 107.18181610107422
# Train_StdReturn : 57.57969665527344
# Train_MaxReturn : 200.0
# Train_MinReturn : 36.0
# Train_AverageEpLen : 107.18181818181819
# Train_EnvstepsSoFar : 46780
# TimeSinceStart : 49.55376100540161
# Training Loss : 11.453987121582031
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 45 ************
#
# Collecting data to be used for training...
# At timestep:     1069 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 133.500
# Eval_StdReturn : 26.258331298828125
# Eval_MaxReturn : 178.0
# Eval_MinReturn : 94.0
# Eval_AverageEpLen : 133.5
# Train_AverageReturn : 97.18181610107422
# Train_StdReturn : 40.099464416503906
# Train_MaxReturn : 167.0
# Train_MinReturn : 32.0
# Train_AverageEpLen : 97.18181818181819
# Train_EnvstepsSoFar : 47849
# TimeSinceStart : 50.88761591911316
# Training Loss : 11.109260559082031
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 46 ************
#
# Collecting data to be used for training...
# At timestep:     1131 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 96.36363983154297
# Eval_StdReturn : 27.641447067260742
# Eval_MaxReturn : 161.0
# Eval_MinReturn : 53.0
# Eval_AverageEpLen : 96.36363636363636
# Train_AverageReturn : 102.81818389892578
# Train_StdReturn : 31.5791015625
# Train_MaxReturn : 171.0
# Train_MinReturn : 53.0
# Train_AverageEpLen : 102.81818181818181
# Train_EnvstepsSoFar : 48980
# TimeSinceStart : 51.75201988220215
# Training Loss : 11.12025260925293
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 47 ************
#
# Collecting data to be used for training...
# At timestep:     1036 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 101.69999694824219
# Eval_StdReturn : 45.23726272583008
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 52.0
# Eval_AverageEpLen : 101.7
# Train_AverageReturn : 103.5999984741211
# Train_StdReturn : 30.233095169067383
# Train_MaxReturn : 157.0
# Train_MinReturn : 61.0
# Train_AverageEpLen : 103.6
# Train_EnvstepsSoFar : 50016
# TimeSinceStart : 52.57258892059326
# Training Loss : 11.020126342773438
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 48 ************
#
# Collecting data to be used for training...
# At timestep:     1010 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 98.81818389892578
# Eval_StdReturn : 31.42037010192871
# Eval_MaxReturn : 188.0
# Eval_MinReturn : 61.0
# Eval_AverageEpLen : 98.81818181818181
# Train_AverageReturn : 112.22222137451172
# Train_StdReturn : 56.16993713378906
# Train_MaxReturn : 200.0
# Train_MinReturn : 41.0
# Train_AverageEpLen : 112.22222222222223
# Train_EnvstepsSoFar : 51026
# TimeSinceStart : 53.39412498474121
# Training Loss : 11.117839813232422
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 49 ************
#
# Collecting data to be used for training...
# At timestep:     1081 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 83.41666412353516
# Eval_StdReturn : 31.645057678222656
# Eval_MaxReturn : 162.0
# Eval_MinReturn : 35.0
# Eval_AverageEpLen : 83.41666666666667
# Train_AverageReturn : 83.15384674072266
# Train_StdReturn : 32.58797836303711
# Train_MaxReturn : 146.0
# Train_MinReturn : 33.0
# Train_AverageEpLen : 83.15384615384616
# Train_EnvstepsSoFar : 52107
# TimeSinceStart : 54.21835899353027
# Training Loss : 10.874619483947754
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 50 ************
#
# Collecting data to be used for training...
# At timestep:     1029 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 103.80000305175781
# Eval_StdReturn : 39.974491119384766
# Eval_MaxReturn : 176.0
# Eval_MinReturn : 56.0
# Eval_AverageEpLen : 103.8
# Train_AverageReturn : 93.54545593261719
# Train_StdReturn : 26.7152099609375
# Train_MaxReturn : 159.0
# Train_MinReturn : 62.0
# Train_AverageEpLen : 93.54545454545455
# Train_EnvstepsSoFar : 53136
# TimeSinceStart : 55.0302677154541
# Training Loss : 10.761917114257812
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 51 ************
#
# Collecting data to be used for training...
# At timestep:     1041 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 92.63636016845703
# Eval_StdReturn : 33.85603713989258
# Eval_MaxReturn : 160.0
# Eval_MinReturn : 38.0
# Eval_AverageEpLen : 92.63636363636364
# Train_AverageReturn : 94.63636016845703
# Train_StdReturn : 23.066200256347656
# Train_MaxReturn : 126.0
# Train_MinReturn : 51.0
# Train_AverageEpLen : 94.63636363636364
# Train_EnvstepsSoFar : 54177
# TimeSinceStart : 55.84552979469299
# Training Loss : 10.71338939666748
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 52 ************
#
# Collecting data to be used for training...
# At timestep:     1055 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 79.53845977783203
# Eval_StdReturn : 22.134605407714844
# Eval_MaxReturn : 121.0
# Eval_MinReturn : 47.0
# Eval_AverageEpLen : 79.53846153846153
# Train_AverageReturn : 81.15384674072266
# Train_StdReturn : 30.094329833984375
# Train_MaxReturn : 145.0
# Train_MinReturn : 32.0
# Train_AverageEpLen : 81.15384615384616
# Train_EnvstepsSoFar : 55232
# TimeSinceStart : 56.68635892868042
# Training Loss : 10.629600524902344
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 53 ************
#
# Collecting data to be used for training...
# At timestep:     1057 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 95.90908813476562
# Eval_StdReturn : 23.643007278442383
# Eval_MaxReturn : 144.0
# Eval_MinReturn : 68.0
# Eval_AverageEpLen : 95.9090909090909
# Train_AverageReturn : 88.08333587646484
# Train_StdReturn : 29.772634506225586
# Train_MaxReturn : 171.0
# Train_MinReturn : 54.0
# Train_AverageEpLen : 88.08333333333333
# Train_EnvstepsSoFar : 56289
# TimeSinceStart : 57.53478813171387
# Training Loss : 10.48952579498291
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 54 ************
#
# Collecting data to be used for training...
# At timestep:     1029 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 110.0999984741211
# Eval_StdReturn : 34.24748229980469
# Eval_MaxReturn : 182.0
# Eval_MinReturn : 75.0
# Eval_AverageEpLen : 110.1
# Train_AverageReturn : 93.54545593261719
# Train_StdReturn : 30.158260345458984
# Train_MaxReturn : 159.0
# Train_MinReturn : 48.0
# Train_AverageEpLen : 93.54545454545455
# Train_EnvstepsSoFar : 57318
# TimeSinceStart : 58.390254974365234
# Training Loss : 10.50048542022705
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 55 ************
#
# Collecting data to be used for training...
# At timestep:     1068 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 113.77777862548828
# Eval_StdReturn : 23.827051162719727
# Eval_MaxReturn : 162.0
# Eval_MinReturn : 77.0
# Eval_AverageEpLen : 113.77777777777777
# Train_AverageReturn : 89.0
# Train_StdReturn : 28.27543067932129
# Train_MaxReturn : 144.0
# Train_MinReturn : 54.0
# Train_AverageEpLen : 89.0
# Train_EnvstepsSoFar : 58386
# TimeSinceStart : 59.22524690628052
# Training Loss : 10.509204864501953
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 56 ************
#
# Collecting data to be used for training...
# At timestep:     1060 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 115.000
# Eval_StdReturn : 35.71492004394531
# Eval_MaxReturn : 173.0
# Eval_MinReturn : 58.0
# Eval_AverageEpLen : 115.0
# Train_AverageReturn : 81.53845977783203
# Train_StdReturn : 27.071460723876953
# Train_MaxReturn : 144.0
# Train_MinReturn : 46.0
# Train_AverageEpLen : 81.53846153846153
# Train_EnvstepsSoFar : 59446
# TimeSinceStart : 60.059706687927246
# Training Loss : 10.332776069641113
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 57 ************
#
# Collecting data to be used for training...
# At timestep:     1033 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 88.58333587646484
# Eval_StdReturn : 22.998035430908203
# Eval_MaxReturn : 124.0
# Eval_MinReturn : 59.0
# Eval_AverageEpLen : 88.58333333333333
# Train_AverageReturn : 93.90908813476562
# Train_StdReturn : 45.360084533691406
# Train_MaxReturn : 200.0
# Train_MinReturn : 51.0
# Train_AverageEpLen : 93.9090909090909
# Train_EnvstepsSoFar : 60479
# TimeSinceStart : 60.91866374015808
# Training Loss : 10.040366172790527
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 58 ************
#
# Collecting data to be used for training...
# At timestep:     1041 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 84.5000
# Eval_StdReturn : 26.228166580200195
# Eval_MaxReturn : 128.0
# Eval_MinReturn : 30.0
# Eval_AverageEpLen : 84.5
# Train_AverageReturn : 94.63636016845703
# Train_StdReturn : 27.919599533081055
# Train_MaxReturn : 168.0
# Train_MinReturn : 61.0
# Train_AverageEpLen : 94.63636363636364
# Train_EnvstepsSoFar : 61520
# TimeSinceStart : 61.73247790336609
# Training Loss : 10.414929389953613
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 59 ************
#
# Collecting data to be used for training...
# At timestep:     1004 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 87.2500
# Eval_StdReturn : 29.137962341308594
# Eval_MaxReturn : 157.0
# Eval_MinReturn : 53.0
# Eval_AverageEpLen : 87.25
# Train_AverageReturn : 83.66666412353516
# Train_StdReturn : 21.707653045654297
# Train_MaxReturn : 132.0
# Train_MinReturn : 57.0
# Train_AverageEpLen : 83.66666666666667
# Train_EnvstepsSoFar : 62524
# TimeSinceStart : 62.565680742263794
# Training Loss : 10.434540748596191
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 60 ************
#
# Collecting data to be used for training...
# At timestep:     1045 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 81.46154022216797
# Eval_StdReturn : 37.360233306884766
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 50.0
# Eval_AverageEpLen : 81.46153846153847
# Train_AverageReturn : 87.08333587646484
# Train_StdReturn : 34.44187927246094
# Train_MaxReturn : 151.0
# Train_MinReturn : 49.0
# Train_AverageEpLen : 87.08333333333333
# Train_EnvstepsSoFar : 63569
# TimeSinceStart : 63.58857583999634
# Training Loss : 10.335333824157715
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 61 ************
#
# Collecting data to be used for training...
# At timestep:     1061 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 91.38461303710938
# Eval_StdReturn : 37.446449279785156
# Eval_MaxReturn : 190.0
# Eval_MinReturn : 31.0
# Eval_AverageEpLen : 91.38461538461539
# Train_AverageReturn : 96.45454406738281
# Train_StdReturn : 37.23967361450195
# Train_MaxReturn : 200.0
# Train_MinReturn : 66.0
# Train_AverageEpLen : 96.45454545454545
# Train_EnvstepsSoFar : 64630
# TimeSinceStart : 64.61874389648438
# Training Loss : 10.252517700195312
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 62 ************
#
# Collecting data to be used for training...
# At timestep:     1073 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 97.09091186523438
# Eval_StdReturn : 47.607208251953125
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 56.0
# Eval_AverageEpLen : 97.0909090909091
# Train_AverageReturn : 89.41666412353516
# Train_StdReturn : 49.6763801574707
# Train_MaxReturn : 200.0
# Train_MinReturn : 42.0
# Train_AverageEpLen : 89.41666666666667
# Train_EnvstepsSoFar : 65703
# TimeSinceStart : 65.55122685432434
# Training Loss : 10.41189956665039
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 63 ************
#
# Collecting data to be used for training...
# At timestep:     1064 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 116.22222137451172
# Eval_StdReturn : 50.909019470214844
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 44.0
# Eval_AverageEpLen : 116.22222222222223
# Train_AverageReturn : 96.7272720336914
# Train_StdReturn : 37.736141204833984
# Train_MaxReturn : 200.0
# Train_MinReturn : 59.0
# Train_AverageEpLen : 96.72727272727273
# Train_EnvstepsSoFar : 66767
# TimeSinceStart : 66.4651870727539
# Training Loss : 10.184977531433105
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 64 ************
#
# Collecting data to be used for training...
# At timestep:     1044 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 123.55555725097656
# Eval_StdReturn : 37.57987594604492
# Eval_MaxReturn : 175.0
# Eval_MinReturn : 36.0
# Eval_AverageEpLen : 123.55555555555556
# Train_AverageReturn : 94.90908813476562
# Train_StdReturn : 28.311431884765625
# Train_MaxReturn : 156.0
# Train_MinReturn : 61.0
# Train_AverageEpLen : 94.9090909090909
# Train_EnvstepsSoFar : 67811
# TimeSinceStart : 67.36526584625244
# Training Loss : 10.452993392944336
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 65 ************
#
# Collecting data to be used for training...
# At timestep:     1027 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 126.500
# Eval_StdReturn : 56.22943878173828
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 68.0
# Eval_AverageEpLen : 126.5
# Train_AverageReturn : 93.36363983154297
# Train_StdReturn : 24.886186599731445
# Train_MaxReturn : 152.0
# Train_MinReturn : 70.0
# Train_AverageEpLen : 93.36363636363636
# Train_EnvstepsSoFar : 68838
# TimeSinceStart : 68.16333389282227
# Training Loss : 10.455167770385742
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 66 ************
#
# Collecting data to be used for training...
# At timestep:     1041 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 126.000
# Eval_StdReturn : 53.0994873046875
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 43.0
# Eval_AverageEpLen : 126.0
# Train_AverageReturn : 94.63636016845703
# Train_StdReturn : 37.17348098754883
# Train_MaxReturn : 189.0
# Train_MinReturn : 30.0
# Train_AverageEpLen : 94.63636363636364
# Train_EnvstepsSoFar : 69879
# TimeSinceStart : 69.10490584373474
# Training Loss : 10.257110595703125
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 67 ************
#
# Collecting data to be used for training...
# At timestep:     1051 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 128.750
# Eval_StdReturn : 38.79674530029297
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 72.0
# Eval_AverageEpLen : 128.75
# Train_AverageReturn : 131.375
# Train_StdReturn : 39.51245880126953
# Train_MaxReturn : 191.0
# Train_MinReturn : 66.0
# Train_AverageEpLen : 131.375
# Train_EnvstepsSoFar : 70930
# TimeSinceStart : 70.0378029346466
# Training Loss : 10.97035026550293
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 68 ************
#
# Collecting data to be used for training...
# At timestep:     1121 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 190.000
# Eval_StdReturn : 14.329456329345703
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 166.0
# Eval_AverageEpLen : 190.0
# Train_AverageReturn : 124.55555725097656
# Train_StdReturn : 38.032474517822266
# Train_MaxReturn : 200.0
# Train_MinReturn : 84.0
# Train_AverageEpLen : 124.55555555555556
# Train_EnvstepsSoFar : 72051
# TimeSinceStart : 71.04226684570312
# Training Loss : 10.761639595031738
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 69 ************
#
# Collecting data to be used for training...
# At timestep:     1173 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 157.14285278320312
# Eval_StdReturn : 30.267515182495117
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 120.0
# Eval_AverageEpLen : 157.14285714285714
# Train_AverageReturn : 167.57142639160156
# Train_StdReturn : 36.593746185302734
# Train_MaxReturn : 200.0
# Train_MinReturn : 103.0
# Train_AverageEpLen : 167.57142857142858
# Train_EnvstepsSoFar : 73224
# TimeSinceStart : 72.10258388519287
# Training Loss : 10.785236358642578
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 70 ************
#
# ...
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 77 ************
#
# Collecting data to be used for training...
# At timestep:     1059 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 48.761905670166016
# Eval_StdReturn : 12.2703857421875
# Eval_MaxReturn : 78.0
# Eval_MinReturn : 33.0
# Eval_AverageEpLen : 48.76190476190476
# Train_AverageReturn : 48.1363639831543
# Train_StdReturn : 18.572452545166016
# Train_MaxReturn : 96.0
# Train_MinReturn : 23.0
# Train_AverageEpLen : 48.13636363636363
# Train_EnvstepsSoFar : 79965
# TimeSinceStart : 94.1298623085022
# Training Loss : 6.179939270019531
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 78 ************
#
# Collecting data to be used for training...
# At timestep:     1040 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 45.34782791137695
# Eval_StdReturn : 13.48302936553955
# Eval_MaxReturn : 81.0
# Eval_MinReturn : 28.0
# Eval_AverageEpLen : 45.34782608695652
# Train_AverageReturn : 45.21739196777344
# Train_StdReturn : 12.683287620544434
# Train_MaxReturn : 81.0
# Train_MinReturn : 29.0
# Train_AverageEpLen : 45.21739130434783
# Train_EnvstepsSoFar : 81005
# TimeSinceStart : 95.1820023059845
# Training Loss : 5.956185340881348
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 79 ************
#
# Collecting data to be used for training...
# At timestep:     1043 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 38.88461685180664
# Eval_StdReturn : 12.801223754882812
# Eval_MaxReturn : 92.0
# Eval_MinReturn : 27.0
# Eval_AverageEpLen : 38.88461538461539
# Train_AverageReturn : 40.11538314819336
# Train_StdReturn : 8.872285842895508
# Train_MaxReturn : 60.0
# Train_MinReturn : 27.0
# Train_AverageEpLen : 40.11538461538461
# Train_EnvstepsSoFar : 82048
# TimeSinceStart : 96.13049912452698
# Training Loss : 5.899107933044434
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 80 ************
#
# Collecting data to be used for training...
# At timestep:     1051 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 42.0000
# Eval_StdReturn : 12.606215476989746
# Eval_MaxReturn : 73.0
# Eval_MinReturn : 27.0
# Eval_AverageEpLen : 42.0
# Train_AverageReturn : 47.772727966308594
# Train_StdReturn : 13.937952995300293
# Train_MaxReturn : 88.0
# Train_MinReturn : 30.0
# Train_AverageEpLen : 47.77272727272727
# Train_EnvstepsSoFar : 83099
# TimeSinceStart : 97.13177704811096
# Training Loss : 5.9198899269104
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 81 ************
#
# Collecting data to be used for training...
# At timestep:     1002 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 37.0000
# Eval_StdReturn : 8.03118896484375
# Eval_MaxReturn : 60.0
# Eval_MinReturn : 24.0
# Eval_AverageEpLen : 37.0
# Train_AverageReturn : 43.565216064453125
# Train_StdReturn : 17.695064544677734
# Train_MaxReturn : 107.0
# Train_MinReturn : 26.0
# Train_AverageEpLen : 43.56521739130435
# Train_EnvstepsSoFar : 84101
# TimeSinceStart : 98.0985860824585
# Training Loss : 5.693748474121094
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 82 ************
#
# Collecting data to be used for training...
# At timestep:     1057 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 41.7500
# Eval_StdReturn : 13.410971641540527
# Eval_MaxReturn : 78.0
# Eval_MinReturn : 25.0
# Eval_AverageEpLen : 41.75
# Train_AverageReturn : 42.279998779296875
# Train_StdReturn : 14.19160270690918
# Train_MaxReturn : 90.0
# Train_MinReturn : 25.0
# Train_AverageEpLen : 42.28
# Train_EnvstepsSoFar : 85158
# TimeSinceStart : 99.03978228569031
# Training Loss : 5.584967613220215
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 83 ************
#
# Collecting data to be used for training...
# At timestep:     1017 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 38.74074172973633
# Eval_StdReturn : 10.444181442260742
# Eval_MaxReturn : 58.0
# Eval_MinReturn : 24.0
# Eval_AverageEpLen : 38.74074074074074
# Train_AverageReturn : 37.66666793823242
# Train_StdReturn : 10.756566047668457
# Train_MaxReturn : 58.0
# Train_MinReturn : 23.0
# Train_AverageEpLen : 37.666666666666664
# Train_EnvstepsSoFar : 86175
# TimeSinceStart : 100.04581809043884
# Training Loss : 4.876346588134766
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 84 ************
#
# Collecting data to be used for training...
# At timestep:     1025 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 37.03703689575195
# Eval_StdReturn : 10.758223533630371
# Eval_MaxReturn : 58.0
# Eval_MinReturn : 22.0
# Eval_AverageEpLen : 37.03703703703704
# Train_AverageReturn : 42.70833206176758
# Train_StdReturn : 9.947693824768066
# Train_MaxReturn : 64.0
# Train_MinReturn : 26.0
# Train_AverageEpLen : 42.708333333333336
# Train_EnvstepsSoFar : 87200
# TimeSinceStart : 100.98938918113708
# Training Loss : 5.394992828369141
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 85 ************
#
# Collecting data to be used for training...
# At timestep:     1036 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 33.93333435058594
# Eval_StdReturn : 6.786915302276611
# Eval_MaxReturn : 52.0
# Eval_MinReturn : 22.0
# Eval_AverageEpLen : 33.93333333333333
# Train_AverageReturn : 34.53333282470703
# Train_StdReturn : 8.00305461883545
# Train_MaxReturn : 57.0
# Train_MinReturn : 23.0
# Train_AverageEpLen : 34.53333333333333
# Train_EnvstepsSoFar : 88236
# TimeSinceStart : 102.12334322929382
# Training Loss : 4.902271270751953
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 86 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 34.82758712768555
# Eval_StdReturn : 9.101227760314941
# Eval_MaxReturn : 65.0
# Eval_MinReturn : 23.0
# Eval_AverageEpLen : 34.827586206896555
# Train_AverageReturn : 37.22222137451172
# Train_StdReturn : 8.052298545837402
# Train_MaxReturn : 59.0
# Train_MinReturn : 24.0
# Train_AverageEpLen : 37.22222222222222
# Train_EnvstepsSoFar : 89241
# TimeSinceStart : 103.08884930610657
# Training Loss : 5.182760238647461
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 87 ************
#
# Collecting data to be used for training...
# At timestep:     1024 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 34.33333206176758
# Eval_StdReturn : 7.272474765777588
# Eval_MaxReturn : 51.0
# Eval_MinReturn : 23.0
# Eval_AverageEpLen : 34.333333333333336
# Train_AverageReturn : 36.57143020629883
# Train_StdReturn : 9.56342887878418
# Train_MaxReturn : 55.0
# Train_MinReturn : 21.0
# Train_AverageEpLen : 36.57142857142857
# Train_EnvstepsSoFar : 90265
# TimeSinceStart : 104.07943224906921
# Training Loss : 5.2338080406188965
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 88 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 31.5625
# Eval_StdReturn : 7.717421531677246
# Eval_MaxReturn : 52.0
# Eval_MinReturn : 21.0
# Eval_AverageEpLen : 31.5625
# Train_AverageReturn : 32.41935348510742
# Train_StdReturn : 6.241247653961182
# Train_MaxReturn : 55.0
# Train_MinReturn : 23.0
# Train_AverageEpLen : 32.41935483870968
# Train_EnvstepsSoFar : 91270
# TimeSinceStart : 105.07203722000122
# Training Loss : 4.8337082862854
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 89 ************
#
# Collecting data to be used for training...
# At timestep:     1024 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 29.02857208251953
# Eval_StdReturn : 6.626723766326904
# Eval_MaxReturn : 49.0
# Eval_MinReturn : 21.0
# Eval_AverageEpLen : 29.02857142857143
# Train_AverageReturn : 32.0
# Train_StdReturn : 6.363961219787598
# Train_MaxReturn : 48.0
# Train_MinReturn : 22.0
# Train_AverageEpLen : 32.0
# Train_EnvstepsSoFar : 92294
# TimeSinceStart : 106.00764226913452
# Training Loss : 4.841511249542236
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 90 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 30.558822631835938
# Eval_StdReturn : 6.1270432472229
# Eval_MaxReturn : 43.0
# Eval_MinReturn : 21.0
# Eval_AverageEpLen : 30.558823529411764
# Train_AverageReturn : 31.40625
# Train_StdReturn : 7.466003894805908
# Train_MaxReturn : 47.0
# Train_MinReturn : 19.0
# Train_AverageEpLen : 31.40625
# Train_EnvstepsSoFar : 93299
# TimeSinceStart : 106.91323328018188
# Training Loss : 5.248834133148193
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 91 ************
#
# Collecting data to be used for training...
# At timestep:     1003 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 30.393939971923828
# Eval_StdReturn : 6.710188865661621
# Eval_MaxReturn : 45.0
# Eval_MinReturn : 19.0
# Eval_AverageEpLen : 30.393939393939394
# Train_AverageReturn : 31.34375
# Train_StdReturn : 7.078176975250244
# Train_MaxReturn : 47.0
# Train_MinReturn : 21.0
# Train_AverageEpLen : 31.34375
# Train_EnvstepsSoFar : 94302
# TimeSinceStart : 107.88527917861938
# Training Loss : 4.448338508605957
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 92 ************
#
# Collecting data to be used for training...
# At timestep:     1007 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 32.290321350097656
# Eval_StdReturn : 5.826488971710205
# Eval_MaxReturn : 46.0
# Eval_MinReturn : 23.0
# Eval_AverageEpLen : 32.29032258064516
# Train_AverageReturn : 33.56666564941406
# Train_StdReturn : 6.108373641967773
# Train_MaxReturn : 45.0
# Train_MinReturn : 20.0
# Train_AverageEpLen : 33.56666666666667
# Train_EnvstepsSoFar : 95309
# TimeSinceStart : 109.02800822257996
# Training Loss : 5.120711803436279
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 93 ************
#
# Collecting data to be used for training...
# At timestep:     1012 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 28.5000
# Eval_StdReturn : 6.5042724609375
# Eval_MaxReturn : 49.0
# Eval_MinReturn : 20.0
# Eval_AverageEpLen : 28.5
# Train_AverageReturn : 30.66666603088379
# Train_StdReturn : 6.79869270324707
# Train_MaxReturn : 50.0
# Train_MinReturn : 20.0
# Train_AverageEpLen : 30.666666666666668
# Train_EnvstepsSoFar : 96321
# TimeSinceStart : 110.00923919677734
# Training Loss : 4.846698760986328
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 94 ************
#
# Collecting data to be used for training...
# At timestep:     1015 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 32.74193572998047
# Eval_StdReturn : 6.579380035400391
# Eval_MaxReturn : 48.0
# Eval_MinReturn : 22.0
# Eval_AverageEpLen : 32.74193548387097
# Train_AverageReturn : 29.852941513061523
# Train_StdReturn : 6.117151737213135
# Train_MaxReturn : 44.0
# Train_MinReturn : 17.0
# Train_AverageEpLen : 29.852941176470587
# Train_EnvstepsSoFar : 97336
# TimeSinceStart : 110.99324536323547
# Training Loss : 4.723265171051025
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 95 ************
#
# Collecting data to be used for training...
# At timestep:     1017 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 30.41176414489746
# Eval_StdReturn : 6.005476474761963
# Eval_MaxReturn : 42.0
# Eval_MinReturn : 19.0
# Eval_AverageEpLen : 30.41176470588235
# Train_AverageReturn : 30.81818199157715
# Train_StdReturn : 6.662670612335205
# Train_MaxReturn : 46.0
# Train_MinReturn : 22.0
# Train_AverageEpLen : 30.818181818181817
# Train_EnvstepsSoFar : 98353
# TimeSinceStart : 111.97969818115234
# Training Loss : 4.741652488708496
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 96 ************
#
# Collecting data to be used for training...
# At timestep:     1022 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 30.545454025268555
# Eval_StdReturn : 6.629095077514648
# Eval_MaxReturn : 44.0
# Eval_MinReturn : 17.0
# Eval_AverageEpLen : 30.545454545454547
# Train_AverageReturn : 29.200000762939453
# Train_StdReturn : 5.181285381317139
# Train_MaxReturn : 40.0
# Train_MinReturn : 19.0
# Train_AverageEpLen : 29.2
# Train_EnvstepsSoFar : 99375
# TimeSinceStart : 113.04338812828064
# Training Loss : 4.685555458068848
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 97 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 30.606060028076172
# Eval_StdReturn : 5.720454216003418
# Eval_MaxReturn : 43.0
# Eval_MinReturn : 21.0
# Eval_AverageEpLen : 30.606060606060606
# Train_AverageReturn : 32.41935348510742
# Train_StdReturn : 7.495263576507568
# Train_MaxReturn : 49.0
# Train_MinReturn : 20.0
# Train_AverageEpLen : 32.41935483870968
# Train_EnvstepsSoFar : 100380
# TimeSinceStart : 114.04254841804504
# Training Loss : 4.661776065826416
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 98 ************
#
# Collecting data to be used for training...
# At timestep:     1036 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 32.83871078491211
# Eval_StdReturn : 6.227393627166748
# Eval_MaxReturn : 49.0
# Eval_MinReturn : 24.0
# Eval_AverageEpLen : 32.83870967741935
# Train_AverageReturn : 31.393939971923828
# Train_StdReturn : 5.799369812011719
# Train_MaxReturn : 45.0
# Train_MinReturn : 21.0
# Train_AverageEpLen : 31.393939393939394
# Train_EnvstepsSoFar : 101416
# TimeSinceStart : 115.81290006637573
# Training Loss : 4.275518417358398
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 99 ************
#
# Collecting data to be used for training...
# At timestep:     1008 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 36.39285659790039
# Eval_StdReturn : 8.574626922607422
# Eval_MaxReturn : 57.0
# Eval_MinReturn : 26.0
# Eval_AverageEpLen : 36.392857142857146
# Train_AverageReturn : 32.51612854003906
# Train_StdReturn : 7.665890693664551
# Train_MaxReturn : 51.0
# Train_MinReturn : 23.0
# Train_AverageEpLen : 32.516129032258064
# Train_EnvstepsSoFar : 102424
# TimeSinceStart : 117.56576633453369
# Training Loss : 4.199160099029541
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...

# %%
pg_args = dict(pg_base_args_dict)

env_str = 'CartPole'
pg_args['env_name'] = '{}-v0'.format(env_str)
pg_args['reward_to_go'] = True
pg_args['n_iter'] = 100

# Delete all previous logs
remove_folder('logs/policy_gradient/{}/return_to_go/'.format(env_str))

for seed in range(3):
    print("Running policy gradient experiment with seed", seed)
    pg_args['seed'] = seed
    pg_args['logdir'] = 'logs/policy_gradient/{}/return_to_go/seed{}'.format(env_str, seed)
    pgtrainer = PG_Trainer(pg_args)
    pgtrainer.run_training_loop()
# Out:
# Folder logs/policy_gradient/CartPole/return_to_go/ does not exist yet. No old results to delete
# Running policy gradient experiment with seed 0
# ########################
# logging outputs to  logs/policy_gradient/CartPole/return_to_go/seed0
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# CartPole-v0
#
#
# ********** Iteration 0 ************
#
# Collecting data to be used for training...
# At timestep:     1012 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 27.578947067260742
# Eval_StdReturn : 15.315337181091309
# Eval_MaxReturn : 69.0
# Eval_MinReturn : 11.0
# Eval_AverageEpLen : 27.57894736842105
# Train_AverageReturn : 22.0
# Train_StdReturn : 10.642409324645996
# Train_MaxReturn : 51.0
# Train_MinReturn : 9.0
# Train_AverageEpLen : 22.0
# Train_EnvstepsSoFar : 1012
# TimeSinceStart : 0.9216792583465576
# Training Loss : 6.256053924560547
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 1 ************
#
# Collecting data to be used for training...
# At timestep:     1026 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 36.31034469604492
# Eval_StdReturn : 20.996065139770508
# Eval_MaxReturn : 90.0
# Eval_MinReturn : 11.0
# Eval_AverageEpLen : 36.310344827586206
# Train_AverageReturn : 27.0
# Train_StdReturn : 15.096182823181152
# Train_MaxReturn : 75.0
# Train_MinReturn : 10.0
# Train_AverageEpLen : 27.0
# Train_EnvstepsSoFar : 2038
# TimeSinceStart : 2.2924420833587646
# Training Loss : 6.966986656188965
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 2 ************
#
# Collecting data to be used for training...
# At timestep:     1017 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 34.7931022644043
# Eval_StdReturn : 13.884696006774902
# Eval_MaxReturn : 68.0
# Eval_MinReturn : 18.0
# Eval_AverageEpLen : 34.793103448275865
# Train_AverageReturn : 37.66666793823242
# Train_StdReturn : 21.108186721801758
# Train_MaxReturn : 100.0
# Train_MinReturn : 12.0
# Train_AverageEpLen : 37.666666666666664
# Train_EnvstepsSoFar : 3055
# TimeSinceStart : 3.244861125946045
# Training Loss : 8.056185722351074
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 3 ************
#
# Collecting data to be used for training...
# At timestep:     1037 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 50.0476188659668
# Eval_StdReturn : 22.697757720947266
# Eval_MaxReturn : 90.0
# Eval_MinReturn : 11.0
# Eval_AverageEpLen : 50.04761904761905
# Train_AverageReturn : 43.20833206176758
# Train_StdReturn : 24.842805862426758
# Train_MaxReturn : 112.0
# Train_MinReturn : 15.0
# Train_AverageEpLen : 43.208333333333336
# Train_EnvstepsSoFar : 4092
# TimeSinceStart : 4.806479215621948
# Training Loss : 8.361367225646973
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 4 ************
#
# Collecting data to be used for training...
# At timestep:     1012 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 73.64286041259766
# Eval_StdReturn : 34.79246139526367
# Eval_MaxReturn : 158.0
# Eval_MinReturn : 28.0
# Eval_AverageEpLen : 73.64285714285714
# Train_AverageReturn : 48.19047546386719
# Train_StdReturn : 19.318431854248047
# Train_MaxReturn : 85.0
# Train_MinReturn : 19.0
# Train_AverageEpLen : 48.19047619047619
# Train_EnvstepsSoFar : 5104
# TimeSinceStart : 5.8231201171875
# Training Loss : 8.359642028808594
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 5 ************
#
# Collecting data to be used for training...
# At timestep:     1007 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 55.83333206176758
# Eval_StdReturn : 30.592756271362305
# Eval_MaxReturn : 119.0
# Eval_MinReturn : 21.0
# Eval_AverageEpLen : 55.833333333333336
# Train_AverageReturn : 50.349998474121094
# Train_StdReturn : 34.302005767822266
# Train_MaxReturn : 116.0
# Train_MinReturn : 17.0
# Train_AverageEpLen : 50.35
# Train_EnvstepsSoFar : 6111
# TimeSinceStart : 6.9342710971832275
# Training Loss : 8.55781078338623
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 6 ************
#
# Collecting data to be used for training...
# At timestep:     1020 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 68.80000305175781
# Eval_StdReturn : 42.089111328125
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 23.0
# Eval_AverageEpLen : 68.8
# Train_AverageReturn : 63.75
# Train_StdReturn : 27.102813720703125
# Train_MaxReturn : 109.0
# Train_MinReturn : 24.0
# Train_AverageEpLen : 63.75
# Train_EnvstepsSoFar : 7131
# TimeSinceStart : 8.184960126876831
# Training Loss : 8.91220474243164
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 7 ************
#
# Collecting data to be used for training...
# At timestep:     1002 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 82.46154022216797
# Eval_StdReturn : 25.536144256591797
# Eval_MaxReturn : 160.0
# Eval_MinReturn : 57.0
# Eval_AverageEpLen : 82.46153846153847
# Train_AverageReturn : 62.625
# Train_StdReturn : 35.30027389526367
# Train_MaxReturn : 133.0
# Train_MinReturn : 23.0
# Train_AverageEpLen : 62.625
# Train_EnvstepsSoFar : 8133
# TimeSinceStart : 9.145653009414673
# Training Loss : 8.810626983642578
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 8 ************
#
# Collecting data to be used for training...
# At timestep:     1025 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 95.2727279663086
# Eval_StdReturn : 60.83971405029297
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 31.0
# Eval_AverageEpLen : 95.27272727272727
# Train_AverageReturn : 68.33333587646484
# Train_StdReturn : 16.381561279296875
# Train_MaxReturn : 105.0
# Train_MinReturn : 44.0
# Train_AverageEpLen : 68.33333333333333
# Train_EnvstepsSoFar : 9158
# TimeSinceStart : 10.378716945648193
# Training Loss : 8.658377647399902
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 9 ************
#
# Collecting data to be used for training...
# At timestep:     1010 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 124.44444274902344
# Eval_StdReturn : 36.44512176513672
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 65.0
# Eval_AverageEpLen : 124.44444444444444
# Train_AverageReturn : 91.81818389892578
# Train_StdReturn : 52.8648681640625
# Train_MaxReturn : 200.0
# Train_MinReturn : 43.0
# Train_AverageEpLen : 91.81818181818181
# Train_EnvstepsSoFar : 10168
# TimeSinceStart : 11.794749021530151
# Training Loss : 9.382179260253906
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 10 ************
#
# Collecting data to be used for training...
# At timestep:     1174 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 128.750
# Eval_StdReturn : 51.09733200073242
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 29.0
# Eval_AverageEpLen : 128.75
# Train_AverageReturn : 146.75
# Train_StdReturn : 45.43608093261719
# Train_MaxReturn : 200.0
# Train_MinReturn : 89.0
# Train_AverageEpLen : 146.75
# Train_EnvstepsSoFar : 11342
# TimeSinceStart : 12.950050115585327
# Training Loss : 9.982255935668945
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 11 ************
#
# Collecting data to be used for training...
# At timestep:     1047 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 169.500
# Eval_StdReturn : 33.713253021240234
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 112.0
# Eval_AverageEpLen : 169.5
# Train_AverageReturn : 149.57142639160156
# Train_StdReturn : 39.601070404052734
# Train_MaxReturn : 200.0
# Train_MinReturn : 93.0
# Train_AverageEpLen : 149.57142857142858
# Train_EnvstepsSoFar : 12389
# TimeSinceStart : 14.036648988723755
# Training Loss : 10.067048072814941
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 12 ************
#
# Collecting data to be used for training...
# At timestep:     1109 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 185.000
# Eval_StdReturn : 23.3737735748291
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 138.0
# Eval_AverageEpLen : 185.0
# Train_AverageReturn : 158.42857360839844
# Train_StdReturn : 28.489883422851562
# Train_MaxReturn : 200.0
# Train_MinReturn : 117.0
# Train_AverageEpLen : 158.42857142857142
# Train_EnvstepsSoFar : 13498
# TimeSinceStart : 15.585062265396118
# Training Loss : 9.84910774230957
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 13 ************
#
# Collecting data to be used for training...
# At timestep:     1043 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 192.8333282470703
# Eval_StdReturn : 9.788030624389648
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 179.0
# Eval_AverageEpLen : 192.83333333333334
# Train_AverageReturn : 149.0
# Train_StdReturn : 32.872047424316406
# Train_MaxReturn : 191.0
# Train_MinReturn : 78.0
# Train_AverageEpLen : 149.0
# Train_EnvstepsSoFar : 14541
# TimeSinceStart : 16.658573150634766
# Training Loss : 9.738073348999023
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 14 ************
#
# Collecting data to be used for training...
# At timestep:     1061 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 178.3333282470703
# Eval_StdReturn : 32.00347137451172
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 119.0
# Eval_AverageEpLen : 178.33333333333334
# Train_AverageReturn : 176.8333282470703
# Train_StdReturn : 27.491918563842773
# Train_MaxReturn : 200.0
# Train_MinReturn : 136.0
# Train_AverageEpLen : 176.83333333333334
# Train_EnvstepsSoFar : 15602
# TimeSinceStart : 17.66694927215576
# Training Loss : 9.779611587524414
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 15 ************
#
# Collecting data to be used for training...
# At timestep:     1041 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 171.1666717529297
# Eval_StdReturn : 31.561668395996094
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 106.0
# Eval_AverageEpLen : 171.16666666666666
# Train_AverageReturn : 148.7142791748047
# Train_StdReturn : 49.134552001953125
# Train_MaxReturn : 200.0
# Train_MinReturn : 47.0
# Train_AverageEpLen : 148.71428571428572
# Train_EnvstepsSoFar : 16643
# TimeSinceStart : 18.71315908432007
# Training Loss : 9.78067398071289
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 16 ************
#
# Collecting data to be used for training...
# At timestep:     1080 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 169.8333282470703
# Eval_StdReturn : 25.28778839111328
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 139.0
# Eval_AverageEpLen : 169.83333333333334
# Train_AverageReturn : 180.0
# Train_StdReturn : 29.280254364013672
# Train_MaxReturn : 200.0
# Train_MinReturn : 118.0
# Train_AverageEpLen : 180.0
# Train_EnvstepsSoFar : 17723
# TimeSinceStart : 19.734223127365112
# Training Loss : 9.425920486450195
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 17 ************
#
# Collecting data to be used for training...
# At timestep:     1136 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 154.85714721679688
# Eval_StdReturn : 43.05620574951172
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 84.0
# Eval_AverageEpLen : 154.85714285714286
# Train_AverageReturn : 162.2857208251953
# Train_StdReturn : 27.618391036987305
# Train_MaxReturn : 200.0
# Train_MinReturn : 125.0
# Train_AverageEpLen : 162.28571428571428
# Train_EnvstepsSoFar : 18859
# TimeSinceStart : 20.672564029693604
# Training Loss : 9.482621192932129
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 18 ************
#
# Collecting data to be used for training...
# At timestep:     1088 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 138.500
# Eval_StdReturn : 44.73533248901367
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 39.0
# Eval_AverageEpLen : 138.5
# Train_AverageReturn : 136.0
# Train_StdReturn : 18.214006423950195
# Train_MaxReturn : 165.0
# Train_MinReturn : 107.0
# Train_AverageEpLen : 136.0
# Train_EnvstepsSoFar : 19947
# TimeSinceStart : 22.004167079925537
# Training Loss : 9.117754936218262
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 19 ************
#
# Collecting data to be used for training...
# At timestep:     1047 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 104.000
# Eval_StdReturn : 25.16346549987793
# Eval_MaxReturn : 132.0
# Eval_MinReturn : 50.0
# Eval_AverageEpLen : 104.0
# Train_AverageReturn : 130.875
# Train_StdReturn : 21.612712860107422
# Train_MaxReturn : 165.0
# Train_MinReturn : 103.0
# Train_AverageEpLen : 130.875
# Train_EnvstepsSoFar : 20994
# TimeSinceStart : 23.37210512161255
# Training Loss : 8.809990882873535
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 20 ************
#
# Collecting data to be used for training...
# At timestep:     1100 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 89.41666412353516
# Eval_StdReturn : 34.138099670410156
# Eval_MaxReturn : 126.0
# Eval_MinReturn : 43.0
# Eval_AverageEpLen : 89.41666666666667
# Train_AverageReturn : 122.22222137451172
# Train_StdReturn : 26.657405853271484
# Train_MaxReturn : 162.0
# Train_MinReturn : 69.0
# Train_AverageEpLen : 122.22222222222223
# Train_EnvstepsSoFar : 22094
# TimeSinceStart : 25.21758008003235
# Training Loss : 8.893975257873535
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 21 ************
#
# Collecting data to be used for training...
# At timestep:     1057 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 109.9000015258789
# Eval_StdReturn : 19.09162139892578
# Eval_MaxReturn : 123.0
# Eval_MinReturn : 55.0
# Eval_AverageEpLen : 109.9
# Train_AverageReturn : 96.09091186523438
# Train_StdReturn : 29.361244201660156
# Train_MaxReturn : 135.0
# Train_MinReturn : 51.0
# Train_AverageEpLen : 96.0909090909091
# Train_EnvstepsSoFar : 23151
# TimeSinceStart : 26.19727325439453
# Training Loss : 8.240012168884277
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 22 ************
#
# Collecting data to be used for training...
# At timestep:     1014 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 97.90908813476562
# Eval_StdReturn : 26.868213653564453
# Eval_MaxReturn : 127.0
# Eval_MinReturn : 42.0
# Eval_AverageEpLen : 97.9090909090909
# Train_AverageReturn : 92.18181610107422
# Train_StdReturn : 32.05625534057617
# Train_MaxReturn : 137.0
# Train_MinReturn : 41.0
# Train_AverageEpLen : 92.18181818181819
# Train_EnvstepsSoFar : 24165
# TimeSinceStart : 27.202819108963013
# Training Loss : 8.196667671203613
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 23 ************
#
# Collecting data to be used for training...
# At timestep:     1083 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 89.5000
# Eval_StdReturn : 33.86861801147461
# Eval_MaxReturn : 120.0
# Eval_MinReturn : 33.0
# Eval_AverageEpLen : 89.5
# Train_AverageReturn : 98.45454406738281
# Train_StdReturn : 28.30792808532715
# Train_MaxReturn : 127.0
# Train_MinReturn : 33.0
# Train_AverageEpLen : 98.45454545454545
# Train_EnvstepsSoFar : 25248
# TimeSinceStart : 28.262410163879395
# Training Loss : 8.368048667907715
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 24 ************
#
# Collecting data to be used for training...
# At timestep:     1016 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 102.000
# Eval_StdReturn : 18.718975067138672
# Eval_MaxReturn : 122.0
# Eval_MinReturn : 54.0
# Eval_AverageEpLen : 102.0
# Train_AverageReturn : 92.36363983154297
# Train_StdReturn : 26.867595672607422
# Train_MaxReturn : 121.0
# Train_MinReturn : 41.0
# Train_AverageEpLen : 92.36363636363636
# Train_EnvstepsSoFar : 26264
# TimeSinceStart : 29.208611249923706
# Training Loss : 7.945452690124512
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 25 ************
#
# Collecting data to be used for training...
# At timestep:     1020 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 99.09091186523438
# Eval_StdReturn : 27.4141788482666
# Eval_MaxReturn : 131.0
# Eval_MinReturn : 48.0
# Eval_AverageEpLen : 99.0909090909091
# Train_AverageReturn : 92.7272720336914
# Train_StdReturn : 30.710054397583008
# Train_MaxReturn : 124.0
# Train_MinReturn : 39.0
# Train_AverageEpLen : 92.72727272727273
# Train_EnvstepsSoFar : 27284
# TimeSinceStart : 30.67431616783142
# Training Loss : 8.085884094238281
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 26 ************
#
# Collecting data to be used for training...
# At timestep:     1031 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 105.4000015258789
# Eval_StdReturn : 14.270248413085938
# Eval_MaxReturn : 121.0
# Eval_MinReturn : 74.0
# Eval_AverageEpLen : 105.4
# Train_AverageReturn : 103.0999984741211
# Train_StdReturn : 30.217378616333008
# Train_MaxReturn : 146.0
# Train_MinReturn : 51.0
# Train_AverageEpLen : 103.1
# Train_EnvstepsSoFar : 28315
# TimeSinceStart : 32.38745713233948
# Training Loss : 8.143121719360352
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 27 ************
#
# Collecting data to be used for training...
# At timestep:     1127 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 84.0000
# Eval_StdReturn : 26.242460250854492
# Eval_MaxReturn : 129.0
# Eval_MinReturn : 51.0
# Eval_AverageEpLen : 84.0
# Train_AverageReturn : 93.91666412353516
# Train_StdReturn : 27.369260787963867
# Train_MaxReturn : 128.0
# Train_MinReturn : 34.0
# Train_AverageEpLen : 93.91666666666667
# Train_EnvstepsSoFar : 29442
# TimeSinceStart : 33.912272930145264
# Training Loss : 7.983991622924805
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 28 ************
#
# Collecting data to be used for training...
# At timestep:     1023 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 114.88888549804688
# Eval_StdReturn : 10.48220157623291
# Eval_MaxReturn : 134.0
# Eval_MinReturn : 100.0
# Eval_AverageEpLen : 114.88888888888889
# Train_AverageReturn : 102.30000305175781
# Train_StdReturn : 12.704723358154297
# Train_MaxReturn : 117.0
# Train_MinReturn : 77.0
# Train_AverageEpLen : 102.3
# Train_EnvstepsSoFar : 30465
# TimeSinceStart : 35.26992702484131
# Training Loss : 8.034558296203613
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 29 ************
#
# Collecting data to be used for training...
# At timestep:     1073 / 10001000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 121.55555725097656
# Eval_StdReturn : 12.455352783203125
# Eval_MaxReturn : 144.0
# Eval_MinReturn : 103.0
# Eval_AverageEpLen : 121.55555555555556
# Train_AverageReturn : 119.22222137451172
# Train_StdReturn : 8.189123153686523
# Train_MaxReturn : 132.0
# Train_MinReturn : 108.0
# Train_AverageEpLen : 119.22222222222223
# Train_EnvstepsSoFar : 31538
# TimeSinceStart : 36.91761898994446
# Training Loss : 8.0447359085083
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 30 ************
#
# Collecting data to be used for training...
# At timestep:     1127 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 142.85714721679688
# Eval_StdReturn : 25.77057456970215
# Eval_MaxReturn : 193.0
# Eval_MinReturn : 110.0
# Eval_AverageEpLen : 142.85714285714286
# Train_AverageReturn : 125.22222137451172
# Train_StdReturn : 15.309967041015625
# Train_MaxReturn : 142.0
# Train_MinReturn : 103.0
# Train_AverageEpLen : 125.22222222222223
# Train_EnvstepsSoFar : 32665
# TimeSinceStart : 38.86394214630127
# Training Loss : 8.460410118103027
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 31 ************
#
# Collecting data to be used for training...
# At timestep:     1134 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 155.42857360839844
# Eval_StdReturn : 17.186847686767578
# Eval_MaxReturn : 182.0
# Eval_MinReturn : 122.0
# Eval_AverageEpLen : 155.42857142857142
# Train_AverageReturn : 141.75
# Train_StdReturn : 10.437313079833984
# Train_MaxReturn : 155.0
# Train_MinReturn : 123.0
# Train_AverageEpLen : 141.75
# Train_EnvstepsSoFar : 33799
# TimeSinceStart : 40.833776235580444
# Training Loss : 8.515644073486328
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 32 ************
#
# Collecting data to be used for training...
# At timestep:     1028 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 170.000
# Eval_StdReturn : 30.02776527404785
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 110.0
# Eval_AverageEpLen : 170.0
# Train_AverageReturn : 146.85714721679688
# Train_StdReturn : 11.764699935913086
# Train_MaxReturn : 166.0
# Train_MinReturn : 132.0
# Train_AverageEpLen : 146.85714285714286
# Train_EnvstepsSoFar : 34827
# TimeSinceStart : 42.29120326042175
# Training Loss : 8.483648300170898
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 33 ************
#
# Collecting data to be used for training...
# At timestep:     1063 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 179.500
# Eval_StdReturn : 26.06242561340332
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 140.0
# Eval_AverageEpLen : 179.5
# Train_AverageReturn : 151.85714721679688
# Train_StdReturn : 15.39414119720459
# Train_MaxReturn : 172.0
# Train_MinReturn : 134.0
# Train_AverageEpLen : 151.85714285714286
# Train_EnvstepsSoFar : 35890
# TimeSinceStart : 43.65927505493164
# Training Loss : 8.523860931396484
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 34 ************
#
# Collecting data to be used for training...
# At timestep:     1028 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 184.8333282470703
# Eval_StdReturn : 16.856420516967773
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 154.0
# Eval_AverageEpLen : 184.83333333333334
# Train_AverageReturn : 171.3333282470703
# Train_StdReturn : 25.675323486328125
# Train_MaxReturn : 200.0
# Train_MinReturn : 133.0
# Train_AverageEpLen : 171.33333333333334
# Train_EnvstepsSoFar : 36918
# TimeSinceStart : 44.931788206100464
# Training Loss : 8.57982349395752
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 35 ************
#
# Collecting data to be used for training...
# At timestep:     1142 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 190.3333282470703
# Train_StdReturn : 21.615324020385742
# Train_MaxReturn : 200.0
# Train_MinReturn : 142.0
# Train_AverageEpLen : 190.33333333333334
# Train_EnvstepsSoFar : 38060
# TimeSinceStart : 46.23089790344238
# Training Loss : 8.961383819580078
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 36 ************
#
# Collecting data to be used for training...
# At timestep:     1176 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 196.0
# Train_StdReturn : 6.855654716491699
# Train_MaxReturn : 200.0
# Train_MinReturn : 181.0
# Train_AverageEpLen : 196.0
# Train_EnvstepsSoFar : 39236
# TimeSinceStart : 47.495985984802246
# Training Loss : 8.77636432647705
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 37 ************
#
# Collecting data to be used for training...
# At timestep:     1198 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 199.6666717529297
# Train_StdReturn : 0.745356023311615
# Train_MaxReturn : 200.0
# Train_MinReturn : 198.0
# Train_AverageEpLen : 199.66666666666666
# Train_EnvstepsSoFar : 40434
# TimeSinceStart : 48.81577110290527
# Training Loss : 8.923415184020996
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 38 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 41434
# TimeSinceStart : 49.931809186935425
# Training Loss : 8.957883834838867
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 39 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 42434
# TimeSinceStart : 51.10388898849487
# Training Loss : 8.528759002685547
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 40 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 43434
# TimeSinceStart : 52.20513892173767
# Training Loss : 9.006901741027832
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 41 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 44434
# TimeSinceStart : 53.43329691886902
# Training Loss : 9.091992378234863
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 42 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 45434
# TimeSinceStart : 54.65635299682617
# Training Loss : 8.559118270874023
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 43 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 46434
# TimeSinceStart : 55.75876522064209
# Training Loss : 8.924735069274902
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 44 ************
#
# Collecting data to be used for training...
# At timestep:     1186 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 197.6666717529297
# Train_StdReturn : 5.217492580413818
# Train_MaxReturn : 200.0
# Train_MinReturn : 186.0
# Train_AverageEpLen : 197.66666666666666
# Train_EnvstepsSoFar : 47620
# TimeSinceStart : 57.065197229385376
# Training Loss : 8.914989471435547
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 45 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 194.3333282470703
# Eval_StdReturn : 10.979778289794922
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 170.0
# Eval_AverageEpLen : 194.33333333333334
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 48620
# TimeSinceStart : 58.35759997367859
# Training Loss : 9.00706672668457
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 46 ************
#
# Collecting data to be used for training...
# At timestep:     1189 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 198.1666717529297
# Train_StdReturn : 4.099457740783691
# Train_MaxReturn : 200.0
# Train_MinReturn : 189.0
# Train_AverageEpLen : 198.16666666666666
# Train_EnvstepsSoFar : 49809
# TimeSinceStart : 59.79331827163696
# Training Loss : 9.110485076904297
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 47 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 50809
# TimeSinceStart : 61.110013008117676
# Training Loss : 9.039423942565918
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 48 ************
#
# Collecting data to be used for training...
# At timestep:     1111 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 192.8333282470703
# Eval_StdReturn : 16.02515411376953
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 157.0
# Eval_AverageEpLen : 192.83333333333334
# Train_AverageReturn : 185.1666717529297
# Train_StdReturn : 33.16834259033203
# Train_MaxReturn : 200.0
# Train_MinReturn : 111.0
# Train_AverageEpLen : 185.16666666666666
# Train_EnvstepsSoFar : 51920
# TimeSinceStart : 62.67205500602722
# Training Loss : 9.133001327514648
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 49 ************
#
# Collecting data to be used for training...
# At timestep:     1199 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 191.3333282470703
# Eval_StdReturn : 12.47219181060791
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 170.0
# Eval_AverageEpLen : 191.33333333333334
# Train_AverageReturn : 199.8333282470703
# Train_StdReturn : 0.3726779818534851
# Train_MaxReturn : 200.0
# Train_MinReturn : 199.0
# Train_AverageEpLen : 199.83333333333334
# Train_EnvstepsSoFar : 53119
# TimeSinceStart : 66.09389424324036
# Training Loss : 9.412109375
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 50 ************
#
# Collecting data to be used for training...
# At timestep:     1171 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 195.1666717529297
# Train_StdReturn : 10.807662963867188
# Train_MaxReturn : 200.0
# Train_MinReturn : 171.0
# Train_AverageEpLen : 195.16666666666666
# Train_EnvstepsSoFar : 54290
# TimeSinceStart : 68.05814099311829
# Training Loss : 9.134928703308105
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 51 ************
#
# Collecting data to be used for training...
# At timestep:     1099 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 165.2857208251953
# Eval_StdReturn : 47.5235710144043
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 88.0
# Eval_AverageEpLen : 165.28571428571428
# Train_AverageReturn : 183.1666717529297
# Train_StdReturn : 26.333860397338867
# Train_MaxReturn : 200.0
# Train_MinReturn : 130.0
# Train_AverageEpLen : 183.16666666666666
# Train_EnvstepsSoFar : 55389
# TimeSinceStart : 69.40933108329773
# Training Loss : 9.126344680786133
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 52 ************
#
# Collecting data to be used for training...
# At timestep:     1183 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 197.3333282470703
# Eval_StdReturn : 5.527708053588867
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 185.0
# Eval_AverageEpLen : 197.33333333333334
# Train_AverageReturn : 197.1666717529297
# Train_StdReturn : 6.335525989532471
# Train_MaxReturn : 200.0
# Train_MinReturn : 183.0
# Train_AverageEpLen : 197.16666666666666
# Train_EnvstepsSoFar : 56572
# TimeSinceStart : 70.64868831634521
# Training Loss : 8.927558898925781
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 53 ************
#
# Collecting data to be used for training...
# At timestep:     1129 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 158.2857208251953
# Eval_StdReturn : 43.14664077758789
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 81.0
# Eval_AverageEpLen : 158.28571428571428
# Train_AverageReturn : 188.1666717529297
# Train_StdReturn : 22.674631118774414
# Train_MaxReturn : 200.0
# Train_MinReturn : 138.0
# Train_AverageEpLen : 188.16666666666666
# Train_EnvstepsSoFar : 57701
# TimeSinceStart : 71.85885119438171
# Training Loss : 9.07132625579834
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 54 ************
#
# Collecting data to be used for training...
# At timestep:     1014 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 178.1666717529297
# Eval_StdReturn : 22.799243927001953
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 132.0
# Eval_AverageEpLen : 178.16666666666666
# Train_AverageReturn : 169.0
# Train_StdReturn : 48.768157958984375
# Train_MaxReturn : 200.0
# Train_MinReturn : 70.0
# Train_AverageEpLen : 169.0
# Train_EnvstepsSoFar : 58715
# TimeSinceStart : 72.97245812416077
# Training Loss : 8.573555946350098
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 55 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 168.85714721679688
# Eval_StdReturn : 31.966182708740234
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 120.0
# Eval_AverageEpLen : 168.85714285714286
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 59715
# TimeSinceStart : 74.13481116294861
# Training Loss : 8.912053108215332
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 56 ************
#
# Collecting data to be used for training...
# At timestep:     1175 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 188.000
# Eval_StdReturn : 19.899747848510742
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 146.0
# Eval_AverageEpLen : 188.0
# Train_AverageReturn : 167.85714721679688
# Train_StdReturn : 50.20082092285156
# Train_MaxReturn : 200.0
# Train_MinReturn : 87.0
# Train_AverageEpLen : 167.85714285714286
# Train_EnvstepsSoFar : 60890
# TimeSinceStart : 75.55000925064087
# Training Loss : 8.57256031036377
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 57 ************
#
# Collecting data to be used for training...
# At timestep:     1195 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 182.500
# Eval_StdReturn : 25.12468910217285
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 140.0
# Eval_AverageEpLen : 182.5
# Train_AverageReturn : 199.1666717529297
# Train_StdReturn : 1.8633898496627808
# Train_MaxReturn : 200.0
# Train_MinReturn : 195.0
# Train_AverageEpLen : 199.16666666666666
# Train_EnvstepsSoFar : 62085
# TimeSinceStart : 76.78558421134949
# Training Loss : 8.492654800415039
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 58 ************
#
# Collecting data to be used for training...
# At timestep:     1087 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 178.3333282470703
# Eval_StdReturn : 24.910951614379883
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 133.0
# Eval_AverageEpLen : 178.33333333333334
# Train_AverageReturn : 181.1666717529297
# Train_StdReturn : 42.112613677978516
# Train_MaxReturn : 200.0
# Train_MinReturn : 87.0
# Train_AverageEpLen : 181.16666666666666
# Train_EnvstepsSoFar : 63172
# TimeSinceStart : 77.91050291061401
# Training Loss : 8.62319278717041
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 59 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 172.000
# Eval_StdReturn : 38.73413848876953
# Eval_MaxReturn : 196.0
# Eval_MinReturn : 86.0
# Eval_AverageEpLen : 172.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 64172
# TimeSinceStart : 78.93566107749939
# Training Loss : 8.952890396118164
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 60 ************
#
# Collecting data to be used for training...
# At timestep:     1096 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 172.500
# Eval_StdReturn : 21.746646881103516
# Eval_MaxReturn : 198.0
# Eval_MinReturn : 139.0
# Eval_AverageEpLen : 172.5
# Train_AverageReturn : 182.6666717529297
# Train_StdReturn : 21.257678985595703
# Train_MaxReturn : 200.0
# Train_MinReturn : 138.0
# Train_AverageEpLen : 182.66666666666666
# Train_EnvstepsSoFar : 65268
# TimeSinceStart : 79.91967010498047
# Training Loss : 8.372591018676758
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 61 ************
#
# Collecting data to be used for training...
# At timestep:     1113 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 171.6666717529297
# Eval_StdReturn : 4.818943977355957
# Eval_MaxReturn : 181.0
# Eval_MinReturn : 166.0
# Eval_AverageEpLen : 171.66666666666666
# Train_AverageReturn : 185.5
# Train_StdReturn : 11.236102104187012
# Train_MaxReturn : 199.0
# Train_MinReturn : 169.0
# Train_AverageEpLen : 185.5
# Train_EnvstepsSoFar : 66381
# TimeSinceStart : 81.11534690856934
# Training Loss : 8.553945541381836
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 62 ************
#
# Collecting data to be used for training...
# At timestep:     1055 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 172.3333282470703
# Eval_StdReturn : 12.697331428527832
# Eval_MaxReturn : 187.0
# Eval_MinReturn : 147.0
# Eval_AverageEpLen : 172.33333333333334
# Train_AverageReturn : 175.8333282470703
# Train_StdReturn : 8.78287410736084
# Train_MaxReturn : 194.0
# Train_MinReturn : 165.0
# Train_AverageEpLen : 175.83333333333334
# Train_EnvstepsSoFar : 67436
# TimeSinceStart : 82.15959620475769
# Training Loss : 8.335963249206543
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 63 ************
#
# Collecting data to be used for training...
# At timestep:     1065 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 174.6666717529297
# Eval_StdReturn : 21.304668426513672
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 134.0
# Eval_AverageEpLen : 174.66666666666666
# Train_AverageReturn : 152.14285278320312
# Train_StdReturn : 54.67939758300781
# Train_MaxReturn : 184.0
# Train_MinReturn : 21.0
# Train_AverageEpLen : 152.14285714285714
# Train_EnvstepsSoFar : 68501
# TimeSinceStart : 83.19861912727356
# Training Loss : 8.311871528625488
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 64 ************
#
# Collecting data to be used for training...
# At timestep:     1126 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 174.3333282470703
# Eval_StdReturn : 40.68442153930664
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 86.0
# Eval_AverageEpLen : 174.33333333333334
# Train_AverageReturn : 187.6666717529297
# Train_StdReturn : 10.624918937683105
# Train_MaxReturn : 200.0
# Train_MinReturn : 167.0
# Train_AverageEpLen : 187.66666666666666
# Train_EnvstepsSoFar : 69627
# TimeSinceStart : 84.45508098602295
# Training Loss : 8.567466735839844
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 65 ************
#
# Collecting data to be used for training...
# At timestep:     1174 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 196.6666717529297
# Eval_StdReturn : 7.453559875488281
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 180.0
# Eval_AverageEpLen : 196.66666666666666
# Train_AverageReturn : 167.7142791748047
# Train_StdReturn : 44.49627685546875
# Train_MaxReturn : 200.0
# Train_MinReturn : 89.0
# Train_AverageEpLen : 167.71428571428572
# Train_EnvstepsSoFar : 70801
# TimeSinceStart : 85.65922117233276
# Training Loss : 8.149275779724121
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 66 ************
#
# Collecting data to be used for training...
# At timestep:     1151 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 171.1666717529297
# Eval_StdReturn : 40.118228912353516
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 92.0
# Eval_AverageEpLen : 171.16666666666666
# Train_AverageReturn : 191.8333282470703
# Train_StdReturn : 18.26122283935547
# Train_MaxReturn : 200.0
# Train_MinReturn : 151.0
# Train_AverageEpLen : 191.83333333333334
# Train_EnvstepsSoFar : 71952
# TimeSinceStart : 86.74164605140686
# Training Loss : 8.08228874206543
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 67 ************
#
# Collecting data to be used for training...
# At timestep:     1189 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 198.1666717529297
# Train_StdReturn : 4.099457740783691
# Train_MaxReturn : 200.0
# Train_MinReturn : 189.0
# Train_AverageEpLen : 198.16666666666666
# Train_EnvstepsSoFar : 73141
# TimeSinceStart : 87.89042806625366
# Training Loss : 8.077061653137207
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 68 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 172.1666717529297
# Eval_StdReturn : 43.12159729003906
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 86.0
# Eval_AverageEpLen : 172.16666666666666
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 74141
# TimeSinceStart : 88.97118711471558
# Training Loss : 8.371787071228027
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 69 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 75141
# TimeSinceStart : 90.00417113304138
# Training Loss : 8.103306770324707
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 70 ************
#
# Collecting data to be used for training...
# At timestep:     1128 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 188.0
# Train_StdReturn : 26.832815170288086
# Train_MaxReturn : 200.0
# Train_MinReturn : 128.0
# Train_AverageEpLen : 188.0
# Train_EnvstepsSoFar : 76269
# TimeSinceStart : 91.12697911262512
# Training Loss : 8.152382850646973
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 71 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# ...
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 77 ************
#
# Collecting data to be used for training...
# At timestep:     1051 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 100.500
# Eval_StdReturn : 23.001087188720703
# Eval_MaxReturn : 121.0
# Eval_MinReturn : 35.0
# Eval_AverageEpLen : 100.5
# Train_AverageReturn : 105.0999984741211
# Train_StdReturn : 26.609960556030273
# Train_MaxReturn : 134.0
# Train_MinReturn : 30.0
# Train_AverageEpLen : 105.1
# Train_EnvstepsSoFar : 83293
# TimeSinceStart : 97.58531999588013
# Training Loss : 6.417284965515137
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 78 ************
#
# Collecting data to be used for training...
# At timestep:     1087 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 88.33333587646484
# Eval_StdReturn : 27.62346076965332
# Eval_MaxReturn : 121.0
# Eval_MinReturn : 29.0
# Eval_AverageEpLen : 88.33333333333333
# Train_AverageReturn : 98.81818389892578
# Train_StdReturn : 26.051761627197266
# Train_MaxReturn : 127.0
# Train_MinReturn : 42.0
# Train_AverageEpLen : 98.81818181818181
# Train_EnvstepsSoFar : 84380
# TimeSinceStart : 98.74412512779236
# Training Loss : 6.224637985229492
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 79 ************
#
# Collecting data to be used for training...
# At timestep:     1100 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 106.9000015258789
# Eval_StdReturn : 5.9405388832092285
# Eval_MaxReturn : 113.0
# Eval_MinReturn : 96.0
# Eval_AverageEpLen : 106.9
# Train_AverageReturn : 91.66666412353516
# Train_StdReturn : 28.639522552490234
# Train_MaxReturn : 119.0
# Train_MinReturn : 40.0
# Train_AverageEpLen : 91.66666666666667
# Train_EnvstepsSoFar : 85480
# TimeSinceStart : 99.99080991744995
# Training Loss : 6.449061393737793
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 80 ************
#
# Collecting data to be used for training...
# At timestep:     1071 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 111.66666412353516
# Eval_StdReturn : 8.151346206665039
# Eval_MaxReturn : 127.0
# Eval_MinReturn : 102.0
# Eval_AverageEpLen : 111.66666666666667
# Train_AverageReturn : 107.0999984741211
# Train_StdReturn : 6.236185073852539
# Train_MaxReturn : 118.0
# Train_MinReturn : 99.0
# Train_AverageEpLen : 107.1
# Train_EnvstepsSoFar : 86551
# TimeSinceStart : 101.26604986190796
# Training Loss : 6.338111400604248
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 81 ************
#
# Collecting data to be used for training...
# At timestep:     1041 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 115.000
# Eval_StdReturn : 6.912147045135498
# Eval_MaxReturn : 128.0
# Eval_MinReturn : 102.0
# Eval_AverageEpLen : 115.0
# Train_AverageReturn : 115.66666412353516
# Train_StdReturn : 5.96284818649292
# Train_MaxReturn : 124.0
# Train_MinReturn : 107.0
# Train_AverageEpLen : 115.66666666666667
# Train_EnvstepsSoFar : 87592
# TimeSinceStart : 102.61838698387146
# Training Loss : 6.3447265625
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 82 ************
#
# Collecting data to be used for training...
# At timestep:     1046 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 123.55555725097656
# Eval_StdReturn : 10.92510986328125
# Eval_MaxReturn : 142.0
# Eval_MinReturn : 107.0
# Eval_AverageEpLen : 123.55555555555556
# Train_AverageReturn : 116.22222137451172
# Train_StdReturn : 7.00440788269043
# Train_MaxReturn : 129.0
# Train_MinReturn : 107.0
# Train_AverageEpLen : 116.22222222222223
# Train_EnvstepsSoFar : 88638
# TimeSinceStart : 103.69692087173462
# Training Loss : 6.085250377655029
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 83 ************
#
# Collecting data to be used for training...
# At timestep:     1059 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 120.77777862548828
# Eval_StdReturn : 10.453896522521973
# Eval_MaxReturn : 135.0
# Eval_MinReturn : 105.0
# Eval_AverageEpLen : 120.77777777777777
# Train_AverageReturn : 117.66666412353516
# Train_StdReturn : 8.550503730773926
# Train_MaxReturn : 131.0
# Train_MinReturn : 106.0
# Train_AverageEpLen : 117.66666666666667
# Train_EnvstepsSoFar : 89697
# TimeSinceStart : 104.8240180015564
# Training Loss : 6.458822250366211
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 84 ************
#
# Collecting data to be used for training...
# At timestep:     1013 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 123.22222137451172
# Eval_StdReturn : 9.040375709533691
# Eval_MaxReturn : 136.0
# Eval_MinReturn : 109.0
# Eval_AverageEpLen : 123.22222222222223
# Train_AverageReturn : 112.55555725097656
# Train_StdReturn : 5.559998512268066
# Train_MaxReturn : 121.0
# Train_MinReturn : 103.0
# Train_AverageEpLen : 112.55555555555556
# Train_EnvstepsSoFar : 90710
# TimeSinceStart : 105.98453307151794
# Training Loss : 6.114260196685791
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 85 ************
#
# Collecting data to be used for training...
# At timestep:     1087 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 123.88888549804688
# Eval_StdReturn : 7.109374523162842
# Eval_MaxReturn : 133.0
# Eval_MinReturn : 109.0
# Eval_AverageEpLen : 123.88888888888889
# Train_AverageReturn : 120.77777862548828
# Train_StdReturn : 7.0518364906311035
# Train_MaxReturn : 129.0
# Train_MinReturn : 110.0
# Train_AverageEpLen : 120.77777777777777
# Train_EnvstepsSoFar : 91797
# TimeSinceStart : 107.16130113601685
# Training Loss : 6.407732009887695
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 86 ************
#
# Collecting data to be used for training...
# At timestep:     1043 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 117.000
# Eval_StdReturn : 6.863753318786621
# Eval_MaxReturn : 128.0
# Eval_MinReturn : 104.0
# Eval_AverageEpLen : 117.0
# Train_AverageReturn : 115.88888549804688
# Train_StdReturn : 7.014975547790527
# Train_MaxReturn : 132.0
# Train_MinReturn : 108.0
# Train_AverageEpLen : 115.88888888888889
# Train_EnvstepsSoFar : 92840
# TimeSinceStart : 108.29075694084167
# Training Loss : 6.340376377105713
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 87 ************
#
# Collecting data to be used for training...
# At timestep:     1078 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 115.11111450195312
# Eval_StdReturn : 7.263981819152832
# Eval_MaxReturn : 127.0
# Eval_MinReturn : 104.0
# Eval_AverageEpLen : 115.11111111111111
# Train_AverageReturn : 119.77777862548828
# Train_StdReturn : 9.246954917907715
# Train_MaxReturn : 135.0
# Train_MinReturn : 110.0
# Train_AverageEpLen : 119.77777777777777
# Train_EnvstepsSoFar : 93918
# TimeSinceStart : 109.3572449684143
# Training Loss : 5.783600807189941
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 88 ************
#
# Collecting data to be used for training...
# At timestep:     1043 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 109.80000305175781
# Eval_StdReturn : 9.130169868469238
# Eval_MaxReturn : 123.0
# Eval_MinReturn : 96.0
# Eval_AverageEpLen : 109.8
# Train_AverageReturn : 104.30000305175781
# Train_StdReturn : 21.410511016845703
# Train_MaxReturn : 121.0
# Train_MinReturn : 42.0
# Train_AverageEpLen : 104.3
# Train_EnvstepsSoFar : 94961
# TimeSinceStart : 111.02885580062866
# Training Loss : 5.937998294830322
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 89 ************
#
# Collecting data to be used for training...
# At timestep:     1061 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 109.000
# Eval_StdReturn : 8.820430755615234
# Eval_MaxReturn : 128.0
# Eval_MinReturn : 100.0
# Eval_AverageEpLen : 109.0
# Train_AverageReturn : 117.88888549804688
# Train_StdReturn : 8.047697067260742
# Train_MaxReturn : 131.0
# Train_MinReturn : 103.0
# Train_AverageEpLen : 117.88888888888889
# Train_EnvstepsSoFar : 96022
# TimeSinceStart : 112.31362295150757
# Training Loss : 5.985374450683594
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 90 ************
#
# Collecting data to be used for training...
# At timestep:     1092 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 111.22222137451172
# Eval_StdReturn : 9.964133262634277
# Eval_MaxReturn : 132.0
# Eval_MinReturn : 101.0
# Eval_AverageEpLen : 111.22222222222223
# Train_AverageReturn : 109.19999694824219
# Train_StdReturn : 5.095095634460449
# Train_MaxReturn : 115.0
# Train_MinReturn : 101.0
# Train_AverageEpLen : 109.2
# Train_EnvstepsSoFar : 97114
# TimeSinceStart : 113.81429100036621
# Training Loss : 6.097095012664795
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 91 ************
#
# Collecting data to be used for training...
# At timestep:     1066 / 1000/ 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 113.55555725097656
# Eval_StdReturn : 10.034507751464844
# Eval_MaxReturn : 129.0
# Eval_MinReturn : 98.0
# Eval_AverageEpLen : 113.55555555555556
# Train_AverageReturn : 106.5999984741211
# Train_StdReturn : 5.7827324867248535
# Train_MaxReturn : 114.0
# Train_MinReturn : 96.0
# Train_AverageEpLen : 106.6
# Train_EnvstepsSoFar : 98180
# TimeSinceStart : 115.16980004310608
# Training Loss : 6.0082621574401855
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 92 ************
#
# Collecting data to be used for training...
# At timestep:     1007 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 115.11111450195312
# Eval_StdReturn : 8.748897552490234
# Eval_MaxReturn : 136.0
# Eval_MinReturn : 103.0
# Eval_AverageEpLen : 115.11111111111111
# Train_AverageReturn : 111.88888549804688
# Train_StdReturn : 8.999313354492188
# Train_MaxReturn : 125.0
# Train_MinReturn : 100.0
# Train_AverageEpLen : 111.88888888888889
# Train_EnvstepsSoFar : 99187
# TimeSinceStart : 116.34117197990417
# Training Loss : 5.622731685638428
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 93 ************
#
# Collecting data to be used for training...
# At timestep:     1023 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 119.55555725097656
# Eval_StdReturn : 7.617393970489502
# Eval_MaxReturn : 128.0
# Eval_MinReturn : 102.0
# Eval_AverageEpLen : 119.55555555555556
# Train_AverageReturn : 113.66666412353516
# Train_StdReturn : 6.73300313949585
# Train_MaxReturn : 124.0
# Train_MinReturn : 102.0
# Train_AverageEpLen : 113.66666666666667
# Train_EnvstepsSoFar : 100210
# TimeSinceStart : 117.44512796401978
# Training Loss : 5.76061487197876
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 94 ************
#
# Collecting data to be used for training...
# At timestep:     1021 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 120.44444274902344
# Eval_StdReturn : 10.393492698669434
# Eval_MaxReturn : 143.0
# Eval_MinReturn : 110.0
# Eval_AverageEpLen : 120.44444444444444
# Train_AverageReturn : 113.44444274902344
# Train_StdReturn : 9.58135986328125
# Train_MaxReturn : 128.0
# Train_MinReturn : 103.0
# Train_AverageEpLen : 113.44444444444444
# Train_EnvstepsSoFar : 101231
# TimeSinceStart : 118.60904312133789
# Training Loss : 5.9516987800598145
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 95 ************
#
# Collecting data to be used for training...
# At timestep:     1115 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 127.000
# Eval_StdReturn : 10.828204154968262
# Eval_MaxReturn : 154.0
# Eval_MinReturn : 117.0
# Eval_AverageEpLen : 127.0
# Train_AverageReturn : 123.88888549804688
# Train_StdReturn : 6.740333557128906
# Train_MaxReturn : 136.0
# Train_MinReturn : 112.0
# Train_AverageEpLen : 123.88888888888889
# Train_EnvstepsSoFar : 102346
# TimeSinceStart : 119.7802369594574
# Training Loss : 6.170619964599609
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 96 ************
#
# Collecting data to be used for training...
# At timestep:     1029 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 133.750
# Eval_StdReturn : 7.066647052764893
# Eval_MaxReturn : 147.0
# Eval_MinReturn : 123.0
# Eval_AverageEpLen : 133.75
# Train_AverageReturn : 128.625
# Train_StdReturn : 9.109576225280762
# Train_MaxReturn : 144.0
# Train_MinReturn : 114.0
# Train_AverageEpLen : 128.625
# Train_EnvstepsSoFar : 103375
# TimeSinceStart : 121.03551506996155
# Training Loss : 5.742018699645996
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 97 ************
#
# Collecting data to be used for training...
# At timestep:     1064 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 145.875
# Eval_StdReturn : 11.569761276245117
# Eval_MaxReturn : 168.0
# Eval_MinReturn : 130.0
# Eval_AverageEpLen : 145.875
# Train_AverageReturn : 133.0
# Train_StdReturn : 14.534441947937012
# Train_MaxReturn : 160.0
# Train_MinReturn : 117.0
# Train_AverageEpLen : 133.0
# Train_EnvstepsSoFar : 104439
# TimeSinceStart : 122.2484838962555
# Training Loss : 6.321371555328369
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 98 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 142.875
# Eval_StdReturn : 9.292974472045898
# Eval_MaxReturn : 157.0
# Eval_MinReturn : 132.0
# Eval_AverageEpLen : 142.875
# Train_AverageReturn : 142.85714721679688
# Train_StdReturn : 8.998866081237793
# Train_MaxReturn : 156.0
# Train_MinReturn : 133.0
# Train_AverageEpLen : 142.85714285714286
# Train_EnvstepsSoFar : 105439
# TimeSinceStart : 123.3681070804596
# Training Loss : 5.868318557739258
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 99 ************
#
# Collecting data to be used for training...
# At timestep:     1004 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 138.625
# Eval_StdReturn : 4.12121057510376
# Eval_MaxReturn : 147.0
# Eval_MinReturn : 133.0
# Eval_AverageEpLen : 138.625
# Train_AverageReturn : 143.42857360839844
# Train_StdReturn : 13.499811172485352
# Train_MaxReturn : 164.0
# Train_MinReturn : 128.0
# Train_AverageEpLen : 143.42857142857142
# Train_EnvstepsSoFar : 106443
# TimeSinceStart : 124.49931001663208
# Training Loss : 6.343075752258301
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...

# %% [markdown]
# We should see the reward to go estimator outperforming the full returns estimator, with some runs reaching the maximum reward of 200. There will likely however be high variance between runs.

# %%
### Visualize Policy Gradient results on CartPole
# %load_ext tensorboard
# %tensorboard --logdir logs/policy_gradient/CartPole
# Out:
#       <iframe id="tensorboard-frame-58c87c7f3309b94f" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-58c87c7f3309b94f");
#           const url = new URL("/", window.location);
#           const port = 6009;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# We can also compare our estimators on a more complex task, though you will probably see that they don't perform well (not getting much above 200 returns). Note that on this more complex task, we use a much larger batch size to reduce variance in the policy gradients.

# %%
pg_args = dict(pg_base_args_dict)

env_str = 'Hopper'
pg_args['env_name'] = '{}-v2'.format(env_str)
pg_args['learning_rate'] = 0.01
pg_args['reward_to_go'] = False
pg_args['batch_size'] = 10000
pg_args['train_batch_size'] = 10000
pg_args['n_iter'] = 100

# Delete all previous logs
remove_folder('logs/policy_gradient/{}/full_returns/'.format(env_str))

for seed in range(3):
    print("Running policy gradient experiment with seed", seed)
    pg_args['seed'] = seed
    pg_args['logdir'] = 'logs/policy_gradient/{}/full_returns/seed{}'.format(env_str, seed)
    pgtrainer = PG_Trainer(pg_args)
    pgtrainer.run_training_loop()
# Out:
# Folder logs/policy_gradient/Hopper/full_returns/ does not exist yet. No old results to delete
# Running policy gradient experiment with seed 0
# ########################
# logging outputs to  logs/policy_gradient/Hopper/full_returns/seed0
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# Hopper-v2
#
#
# ********** Iteration 0 ************
#
# Collecting data to be used for training...
# At timestep:     10004 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 61.34284210205078
# Eval_StdReturn : 57.76802444458008
# Eval_MaxReturn : 203.4663543701172
# Eval_MinReturn : 7.391658306121826
# Eval_AverageEpLen : 39.96153846153846
# Train_AverageReturn : 9.657980918884277
# Train_StdReturn : 5.853752613067627
# Train_MaxReturn : 87.45542907714844
# Train_MinReturn : 3.010934352874756
# Train_AverageEpLen : 13.215323645970939
# Train_EnvstepsSoFar : 10004
# TimeSinceStart : 12.066728830337524
# Training Loss : 34.30583572387695
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 1 ************
#
# Collecting data to be used for training...
# At timestep:     10020 / 10000104 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 72.8387222290039
# Eval_StdReturn : 11.639814376831055
# Eval_MaxReturn : 97.1689453125
# Eval_MinReturn : 56.68820571899414
# Eval_AverageEpLen : 45.65217391304348
# Train_AverageReturn : 54.50438690185547
# Train_StdReturn : 46.97917175292969
# Train_MaxReturn : 214.85650634765625
# Train_MinReturn : 5.630634784698486
# Train_AverageEpLen : 37.95454545454545
# Train_EnvstepsSoFar : 20024
# TimeSinceStart : 23.262439966201782
# Training Loss : 90.11448669433594
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 2 ************
#
# Collecting data to be used for training...
# At timestep:     10026 / 100001340 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 62.79875183105469
# Eval_StdReturn : 9.179817199707031
# Eval_MaxReturn : 83.30668640136719
# Eval_MinReturn : 52.27299499511719
# Eval_AverageEpLen : 38.074074074074076
# Train_AverageReturn : 75.83659362792969
# Train_StdReturn : 19.883373260498047
# Train_MaxReturn : 161.705810546875
# Train_MinReturn : 12.983553886413574
# Train_AverageEpLen : 47.97129186602871
# Train_EnvstepsSoFar : 30050
# TimeSinceStart : 34.761162996292114
# Training Loss : 99.64437866210938
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 3 ************
#
# Collecting data to be used for training...
# At timestep:     10019 / 100003599 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 52.26776123046875
# Eval_StdReturn : 5.455423355102539
# Eval_MaxReturn : 68.46729278564453
# Eval_MinReturn : 44.55207061767578
# Eval_AverageEpLen : 31.09090909090909
# Train_AverageReturn : 60.45672607421875
# Train_StdReturn : 8.498207092285156
# Train_MaxReturn : 108.87381744384766
# Train_MinReturn : 46.84237289428711
# Train_AverageEpLen : 37.10740740740741
# Train_EnvstepsSoFar : 40069
# TimeSinceStart : 46.425028800964355
# Training Loss : 101.54632568359375
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 4 ************
#
# Collecting data to be used for training...
# At timestep:     10004 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 63.14884567260742
# Eval_StdReturn : 14.536174774169922
# Eval_MaxReturn : 114.81082916259766
# Eval_MinReturn : 46.10413360595703
# Eval_AverageEpLen : 36.06896551724138
# Train_AverageReturn : 53.69095993041992
# Train_StdReturn : 6.895584583282471
# Train_MaxReturn : 111.23048400878906
# Train_MinReturn : 41.2711181640625
# Train_AverageEpLen : 31.85987261146497
# Train_EnvstepsSoFar : 50073
# TimeSinceStart : 58.132428884506226
# Training Loss : 102.34545135498047
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 5 ************
#
# Collecting data to be used for training...
# At timestep:     10021 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 66.40575408935547
# Eval_StdReturn : 14.012947082519531
# Eval_MaxReturn : 102.32241821289062
# Eval_MinReturn : 47.63692855834961
# Eval_AverageEpLen : 38.370370370370374
# Train_AverageReturn : 57.791053771972656
# Train_StdReturn : 9.75520133972168
# Train_MaxReturn : 95.34403228759766
# Train_MinReturn : 43.168800354003906
# Train_AverageEpLen : 33.29235880398671
# Train_EnvstepsSoFar : 60094
# TimeSinceStart : 69.34950995445251
# Training Loss : 107.87123107910156
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 6 ************
#
# Collecting data to be used for training...
# At timestep:     10002 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 75.18193817138672
# Eval_StdReturn : 18.406028747558594
# Eval_MaxReturn : 144.75587463378906
# Eval_MinReturn : 52.41751480102539
# Eval_AverageEpLen : 42.75
# Train_AverageReturn : 73.60010528564453
# Train_StdReturn : 17.074445724487305
# Train_MaxReturn : 141.6881866455078
# Train_MinReturn : 44.51664733886719
# Train_AverageEpLen : 41.84937238493724
# Train_EnvstepsSoFar : 70096
# TimeSinceStart : 80.16506767272949
# Training Loss : 117.74435424804688
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 7 ************
#
# Collecting data to be used for training...
# At timestep:     10027 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 69.56655883789062
# Eval_StdReturn : 16.2469482421875
# Eval_MaxReturn : 127.05127716064453
# Eval_MinReturn : 51.87830352783203
# Eval_AverageEpLen : 40.8
# Train_AverageReturn : 73.12443542480469
# Train_StdReturn : 19.10350799560547
# Train_MaxReturn : 150.74452209472656
# Train_MinReturn : 40.20240020751953
# Train_AverageEpLen : 41.95397489539749
# Train_EnvstepsSoFar : 80123
# TimeSinceStart : 90.89697790145874
# Training Loss : 118.0258560180664
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 8 ************
#
# Collecting data to be used for training...
# At timestep:     10021 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 65.86367797851562
# Eval_StdReturn : 14.051860809326172
# Eval_MaxReturn : 108.71044158935547
# Eval_MinReturn : 48.884952545166016
# Eval_AverageEpLen : 38.03703703703704
# Train_AverageReturn : 68.00953674316406
# Train_StdReturn : 18.114444732666016
# Train_MaxReturn : 157.70809936523438
# Train_MinReturn : 45.17577362060547
# Train_AverageEpLen : 39.76587301587302
# Train_EnvstepsSoFar : 90144
# TimeSinceStart : 101.8061318397522
# Training Loss : 116.12735748291016
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 9 ************
#
# Collecting data to be used for training...
# At timestep:     10019 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 58.55392074584961
# Eval_StdReturn : 9.80224323272705
# Eval_MaxReturn : 94.20258331298828
# Eval_MinReturn : 40.70354080200195
# Eval_AverageEpLen : 34.827586206896555
# Train_AverageReturn : 63.33518600463867
# Train_StdReturn : 14.923974990844727
# Train_MaxReturn : 146.57936096191406
# Train_MinReturn : 43.53887176513672
# Train_AverageEpLen : 37.10740740740741
# Train_EnvstepsSoFar : 100163
# TimeSinceStart : 112.36351275444031
# Training Loss : 114.5214614868164
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 10 ************
#
# Collecting data to be used for training...
# At timestep:     10020 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 69.89344787597656
# Eval_StdReturn : 15.411808967590332
# Eval_MaxReturn : 107.07992553710938
# Eval_MinReturn : 46.55685043334961
# Eval_AverageEpLen : 39.57692307692308
# Train_AverageReturn : 62.408966064453125
# Train_StdReturn : 14.828570365905762
# Train_MaxReturn : 163.44375610351562
# Train_MinReturn : 3.8587586879730225
# Train_AverageEpLen : 36.974169741697416
# Train_EnvstepsSoFar : 110183
# TimeSinceStart : 122.91044473648071
# Training Loss : 114.06008911132812
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 11 ************
#
# Collecting data to be used for training...
# At timestep:     10038 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 77.67560577392578
# Eval_StdReturn : 27.553897857666016
# Eval_MaxReturn : 130.55270385742188
# Eval_MinReturn : 44.040863037109375
# Eval_AverageEpLen : 44.04347826086956
# Train_AverageReturn : 70.12300872802734
# Train_StdReturn : 20.35663604736328
# Train_MaxReturn : 149.27801513671875
# Train_MinReturn : 0.23891663551330566
# Train_AverageEpLen : 39.99203187250996
# Train_EnvstepsSoFar : 120221
# TimeSinceStart : 133.93064975738525
# Training Loss : 118.89676666259766
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 12 ************
#
# Collecting data to be used for training...
# At timestep:     10019 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 90.35311889648438
# Eval_StdReturn : 60.9752082824707
# Eval_MaxReturn : 342.9666748046875
# Eval_MinReturn : 47.60049819946289
# Eval_AverageEpLen : 48.19047619047619
# Train_AverageReturn : 73.99136352539062
# Train_StdReturn : 25.364967346191406
# Train_MaxReturn : 234.69850158691406
# Train_MinReturn : 40.196537017822266
# Train_AverageEpLen : 41.400826446280995
# Train_EnvstepsSoFar : 130240
# TimeSinceStart : 144.6769518852234
# Training Loss : 120.18022918701172
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 13 ************
#
# Collecting data to be used for training...
# At timestep:     10003 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 109.33789825439453
# Eval_StdReturn : 63.698341369628906
# Eval_MaxReturn : 349.2409362792969
# Eval_MinReturn : 65.48703002929688
# Eval_AverageEpLen : 60.411764705882355
# Train_AverageReturn : 73.16106414794922
# Train_StdReturn : 28.928529739379883
# Train_MaxReturn : 385.1426696777344
# Train_MinReturn : 42.2227668762207
# Train_AverageEpLen : 40.82857142857143
# Train_EnvstepsSoFar : 140243
# TimeSinceStart : 155.64128994941711
# Training Loss : 120.22494506835938
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 14 ************
#
# Collecting data to be used for training...
# At timestep:     10015 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 146.5906524658203
# Eval_StdReturn : 41.70470428466797
# Eval_MaxReturn : 176.61187744140625
# Eval_MinReturn : 18.832046508789062
# Eval_AverageEpLen : 73.71428571428571
# Train_AverageReturn : 97.89380645751953
# Train_StdReturn : 42.41375732421875
# Train_MaxReturn : 404.00482177734375
# Train_MinReturn : 49.41884994506836
# Train_AverageEpLen : 52.98941798941799
# Train_EnvstepsSoFar : 150258
# TimeSinceStart : 167.53289771080017
# Training Loss : 127.96818542480469
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 15 ************
#
# Collecting data to be used for training...
# At timestep:     10050 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 89.6613998413086
# Eval_StdReturn : 70.5802001953125
# Eval_MaxReturn : 177.65016174316406
# Eval_MinReturn : 20.73590850830078
# Eval_AverageEpLen : 47.666666666666664
# Train_AverageReturn : 141.84503173828125
# Train_StdReturn : 40.10786819458008
# Train_MaxReturn : 211.1459503173828
# Train_MinReturn : 14.764145851135254
# Train_AverageEpLen : 71.78571428571429
# Train_EnvstepsSoFar : 160308
# TimeSinceStart : 179.29697489738464
# Training Loss : 134.86756896972656
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 16 ************
#
# Collecting data to be used for training...
# At timestep:     10017 / 1000010000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 53.85675811767578
# Eval_StdReturn : 48.20116424560547
# Eval_MaxReturn : 168.51922607421875
# Eval_MinReturn : 14.542953491210938
# Eval_AverageEpLen : 31.676470588235293
# Train_AverageReturn : 99.81343841552734
# Train_StdReturn : 70.736328125
# Train_MaxReturn : 181.1945037841797
# Train_MinReturn : 14.561469078063965
# Train_AverageEpLen : 52.171875
# Train_EnvstepsSoFar : 170325
# TimeSinceStart : 190.95552277565002
# Training Loss : 125.25718688964844
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 17 ************
#
# Collecting data to be used for training...
# At timestep:     10011 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 79.41666412353516
# Eval_StdReturn : 68.85411071777344
# Eval_MaxReturn : 327.7867736816406
# Eval_MinReturn : 23.173248291015625
# Eval_AverageEpLen : 43.75
# Train_AverageReturn : 54.73984909057617
# Train_StdReturn : 48.24892807006836
# Train_MaxReturn : 272.2548828125
# Train_MinReturn : 12.659337043762207
# Train_AverageEpLen : 31.984025559105433
# Train_EnvstepsSoFar : 180336
# TimeSinceStart : 202.07127404212952
# Training Loss : 106.49720001220703
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 18 ************
#
# Collecting data to be used for training...
# At timestep:     10054 / 1000010000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 130.9305419921875
# Eval_StdReturn : 46.757484436035156
# Eval_MaxReturn : 173.91014099121094
# Eval_MinReturn : 46.0289192199707
# Eval_AverageEpLen : 69.66666666666667
# Train_AverageReturn : 69.73844146728516
# Train_StdReturn : 47.61898422241211
# Train_MaxReturn : 197.83358764648438
# Train_MinReturn : 14.841601371765137
# Train_AverageEpLen : 39.8968253968254
# Train_EnvstepsSoFar : 190390
# TimeSinceStart : 215.2966628074646
# Training Loss : 114.88338470458984
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 19 ************
#
# Collecting data to be used for training...
# At timestep:     10007 / 100003836 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 178.8197479248047
# Eval_StdReturn : 14.884038925170898
# Eval_MaxReturn : 193.02593994140625
# Eval_MinReturn : 137.3157958984375
# Eval_AverageEpLen : 89.66666666666667
# Train_AverageReturn : 123.84510040283203
# Train_StdReturn : 53.09516906738281
# Train_MaxReturn : 189.81919860839844
# Train_MinReturn : 22.770030975341797
# Train_AverageEpLen : 65.40522875816994
# Train_EnvstepsSoFar : 200397
# TimeSinceStart : 227.279926776886
# Training Loss : 128.9395294189453
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 20 ************
#
# Collecting data to be used for training...
# At timestep:     10124 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 186.5203094482422
# Eval_StdReturn : 9.5005464553833
# Eval_MaxReturn : 198.04254150390625
# Eval_MinReturn : 163.19479370117188
# Eval_AverageEpLen : 92.18181818181819
# Train_AverageReturn : 168.76597595214844
# Train_StdReturn : 34.72297286987305
# Train_MaxReturn : 242.33877563476562
# Train_MinReturn : 37.680721282958984
# Train_AverageEpLen : 85.79661016949153
# Train_EnvstepsSoFar : 210521
# TimeSinceStart : 242.55194187164307
# Training Loss : 134.13780212402344
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 21 ************
#
# Collecting data to be used for training...
# At timestep:     10024 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 161.77586364746094
# Eval_StdReturn : 31.873241424560547
# Eval_MaxReturn : 208.13577270507812
# Eval_MinReturn : 91.60504150390625
# Eval_AverageEpLen : 83.91666666666667
# Train_AverageReturn : 182.6273956298828
# Train_StdReturn : 21.851411819458008
# Train_MaxReturn : 236.52513122558594
# Train_MinReturn : 46.24435806274414
# Train_AverageEpLen : 91.12727272727273
# Train_EnvstepsSoFar : 220545
# TimeSinceStart : 252.09158778190613
# Training Loss : 135.387451171875
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 22 ************
#
# Collecting data to be used for training...
# At timestep:     10000 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 151.78512573242188
# Eval_StdReturn : 37.332122802734375
# Eval_MaxReturn : 199.15621948242188
# Eval_MinReturn : 81.92900085449219
# Eval_AverageEpLen : 76.64285714285714
# Train_AverageReturn : 171.86077880859375
# Train_StdReturn : 31.202096939086914
# Train_MaxReturn : 207.5363006591797
# Train_MinReturn : 86.25834655761719
# Train_AverageEpLen : 86.20689655172414
# Train_EnvstepsSoFar : 230545
# TimeSinceStart : 261.45972776412964
# Training Loss : 134.7311553955078
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 23 ************
#
# Collecting data to be used for training...
# At timestep:     10055 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 108.78203582763672
# Eval_StdReturn : 33.75959777832031
# Eval_MaxReturn : 188.82015991210938
# Eval_MinReturn : 68.08303833007812
# Eval_AverageEpLen : 59.22222222222222
# Train_AverageReturn : 140.56089782714844
# Train_StdReturn : 39.65536880493164
# Train_MaxReturn : 217.15109252929688
# Train_MinReturn : 70.63813781738281
# Train_AverageEpLen : 73.39416058394161
# Train_EnvstepsSoFar : 240600
# TimeSinceStart : 270.36267495155334
# Training Loss : 132.0576934814453
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 24 ************
#
# Collecting data to be used for training...
# At timestep:     10024 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 103.791015625
# Eval_StdReturn : 23.201332092285156
# Eval_MaxReturn : 170.97604370117188
# Eval_MinReturn : 74.82231903076172
# Eval_AverageEpLen : 58.22222222222222
# Train_AverageReturn : 116.83049011230469
# Train_StdReturn : 34.78238296508789
# Train_MaxReturn : 199.56396484375
# Train_MinReturn : 61.461280822753906
# Train_AverageEpLen : 62.65
# Train_EnvstepsSoFar : 250624
# TimeSinceStart : 279.02028584480286
# Training Loss : 129.1002655029297
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 25 ************
#
# Collecting data to be used for training...
# At timestep:     10069 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 103.34889221191406
# Eval_StdReturn : 21.33516502380371
# Eval_MaxReturn : 164.55307006835938
# Eval_MinReturn : 69.27276611328125
# Eval_AverageEpLen : 58.0
# Train_AverageReturn : 103.9081039428711
# Train_StdReturn : 26.504215240478516
# Train_MaxReturn : 217.17080688476562
# Train_MinReturn : 68.71817016601562
# Train_AverageEpLen : 57.867816091954026
# Train_EnvstepsSoFar : 260693
# TimeSinceStart : 288.4148848056793
# Training Loss : 127.40421295166016
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 26 ************
#
# Collecting data to be used for training...
# At timestep:     10019 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 112.82647705078125
# Eval_StdReturn : 26.764699935913086
# Eval_MaxReturn : 182.71759033203125
# Eval_MinReturn : 73.72649383544922
# Eval_AverageEpLen : 61.23529411764706
# Train_AverageReturn : 100.33789825439453
# Train_StdReturn : 24.72645378112793
# Train_MaxReturn : 187.19239807128906
# Train_MinReturn : 58.78030014038086
# Train_AverageEpLen : 55.97206703910614
# Train_EnvstepsSoFar : 270712
# TimeSinceStart : 300.1204607486725
# Training Loss : 124.61724090576172
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 27 ************
#
# Collecting data to be used for training...
# At timestep:     10015 / 1000010000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 101.6514892578125
# Eval_StdReturn : 20.766742706298828
# Eval_MaxReturn : 172.762451171875
# Eval_MinReturn : 77.43428039550781
# Eval_AverageEpLen : 57.111111111111114
# Train_AverageReturn : 105.58372497558594
# Train_StdReturn : 23.216896057128906
# Train_MaxReturn : 198.54029846191406
# Train_MinReturn : 69.98956298828125
# Train_AverageEpLen : 58.567251461988306
# Train_EnvstepsSoFar : 280727
# TimeSinceStart : 311.24425983428955
# Training Loss : 124.29068756103516
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 28 ************
#
# Collecting data to be used for training...
# At timestep:     10062 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 102.41471099853516
# Eval_StdReturn : 11.715009689331055
# Eval_MaxReturn : 123.8824691772461
# Eval_MinReturn : 85.69705200195312
# Eval_AverageEpLen : 58.22222222222222
# Train_AverageReturn : 105.82957458496094
# Train_StdReturn : 21.627981185913086
# Train_MaxReturn : 213.19403076171875
# Train_MinReturn : 74.45520782470703
# Train_AverageEpLen : 59.188235294117646
# Train_EnvstepsSoFar : 290789
# TimeSinceStart : 320.6451418399811
# Training Loss : 122.97518157958984
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 29 ************
#
# Collecting data to be used for training...
# At timestep:     10014 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 114.94108581542969
# Eval_StdReturn : 27.49253273010254
# Eval_MaxReturn : 211.49961853027344
# Eval_MinReturn : 84.81382751464844
# Eval_AverageEpLen : 64.3125
# Train_AverageReturn : 109.09841918945312
# Train_StdReturn : 21.969310760498047
# Train_MaxReturn : 208.81106567382812
# Train_MinReturn : 74.8000259399414
# Train_AverageEpLen : 60.325301204819276
# Train_EnvstepsSoFar : 300803
# TimeSinceStart : 330.082478761673
# Training Loss : 122.12886047363281
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 30 ************
#
# Collecting data to be used for training...
# At timestep:     10013 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 115.29741668701172
# Eval_StdReturn : 15.100448608398438
# Eval_MaxReturn : 150.97686767578125
# Eval_MinReturn : 88.47526550292969
# Eval_AverageEpLen : 62.35294117647059
# Train_AverageReturn : 112.66350555419922
# Train_StdReturn : 20.54120635986328
# Train_MaxReturn : 221.68984985351562
# Train_MinReturn : 74.47538757324219
# Train_AverageEpLen : 61.80864197530864
# Train_EnvstepsSoFar : 310816
# TimeSinceStart : 339.0511429309845
# Training Loss : 120.72225952148438
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 31 ************
#
# Collecting data to be used for training...
# At timestep:     10029 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 112.45731353759766
# Eval_StdReturn : 16.53662872314453
# Eval_MaxReturn : 150.09432983398438
# Eval_MinReturn : 87.33071899414062
# Eval_AverageEpLen : 61.76470588235294
# Train_AverageReturn : 113.85464477539062
# Train_StdReturn : 16.2443790435791
# Train_MaxReturn : 175.12899780273438
# Train_MinReturn : 86.6904296875
# Train_AverageEpLen : 62.29192546583851
# Train_EnvstepsSoFar : 320845
# TimeSinceStart : 349.7797887325287
# Training Loss : 120.39460754394531
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 32 ************
#
# Collecting data to be used for training...
# At timestep:     10046 / 10000/ 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 124.95661163330078
# Eval_StdReturn : 26.34847068786621
# Eval_MaxReturn : 177.62786865234375
# Eval_MinReturn : 84.92816162109375
# Eval_AverageEpLen : 65.0625
# Train_AverageReturn : 117.18943786621094
# Train_StdReturn : 17.515832901000977
# Train_MaxReturn : 190.31251525878906
# Train_MinReturn : 80.65196228027344
# Train_AverageEpLen : 63.18238993710692
# Train_EnvstepsSoFar : 330891
# TimeSinceStart : 358.3003737926483
# Training Loss : 120.26919555664062
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 33 ************
#
# Collecting data to be used for training...
# At timestep:     10068 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 109.55646514892578
# Eval_StdReturn : 20.1720027923584
# Eval_MaxReturn : 160.6954345703125
# Eval_MinReturn : 80.77812957763672
# Eval_AverageEpLen : 59.529411764705884
# Train_AverageReturn : 117.23585510253906
# Train_StdReturn : 19.66366195678711
# Train_MaxReturn : 165.05442810058594
# Train_MinReturn : 17.618675231933594
# Train_AverageEpLen : 62.53416149068323
# Train_EnvstepsSoFar : 340959
# TimeSinceStart : 367.5890669822693
# Training Loss : 120.2851333618164
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 34 ************
#
# Collecting data to be used for training...
# At timestep:     10024 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 128.29466247558594
# Eval_StdReturn : 22.55349349975586
# Eval_MaxReturn : 165.4586944580078
# Eval_MinReturn : 92.24138641357422
# Eval_AverageEpLen : 65.3125
# Train_AverageReturn : 121.84083557128906
# Train_StdReturn : 22.966552734375
# Train_MaxReturn : 183.8336181640625
# Train_MinReturn : 27.70252227783203
# Train_AverageEpLen : 63.44303797468354
# Train_EnvstepsSoFar : 350983
# TimeSinceStart : 377.3318088054657
# Training Loss : 121.50369262695312
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 35 ************
#
# Collecting data to be used for training...
# At timestep:     10014 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 112.36940002441406
# Eval_StdReturn : 14.563244819641113
# Eval_MaxReturn : 141.7180633544922
# Eval_MinReturn : 93.18792724609375
# Eval_AverageEpLen : 59.64705882352941
# Train_AverageReturn : 119.50485229492188
# Train_StdReturn : 19.07646369934082
# Train_MaxReturn : 163.3001708984375
# Train_MinReturn : 80.82118225097656
# Train_AverageEpLen : 62.19875776397515
# Train_EnvstepsSoFar : 360997
# TimeSinceStart : 386.59426283836365
# Training Loss : 122.02176666259766
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 36 ************
#
# Collecting data to be used for training...
# At timestep:     10009 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 99.62884521484375
# Eval_StdReturn : 14.73607063293457
# Eval_MaxReturn : 127.97217559814453
# Eval_MinReturn : 78.40234375
# Eval_AverageEpLen : 54.68421052631579
# Train_AverageReturn : 110.49269104003906
# Train_StdReturn : 18.131977081298828
# Train_MaxReturn : 154.290283203125
# Train_MinReturn : 20.915451049804688
# Train_AverageEpLen : 58.87647058823529
# Train_EnvstepsSoFar : 371006
# TimeSinceStart : 395.8912088871002
# Training Loss : 121.7961196899414
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 37 ************
#
# Collecting data to be used for training...
# At timestep:     10005 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 96.24181365966797
# Eval_StdReturn : 9.73698616027832
# Eval_MaxReturn : 111.06218719482422
# Eval_MinReturn : 77.48859405517578
# Eval_AverageEpLen : 53.73684210526316
# Train_AverageReturn : 104.42805480957031
# Train_StdReturn : 15.946087837219238
# Train_MaxReturn : 144.2852020263672
# Train_MinReturn : 73.78618621826172
# Train_AverageEpLen : 56.52542372881356
# Train_EnvstepsSoFar : 381011
# TimeSinceStart : 405.3055808544159
# Training Loss : 121.50939178466797
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 38 ************
#
# Collecting data to be used for training...
# At timestep:     10045 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 92.84584045410156
# Eval_StdReturn : 11.608429908752441
# Eval_MaxReturn : 115.523193359375
# Eval_MinReturn : 75.27206420898438
# Eval_AverageEpLen : 52.35
# Train_AverageReturn : 98.59305572509766
# Train_StdReturn : 15.073060989379883
# Train_MaxReturn : 147.88644409179688
# Train_MinReturn : 65.5808334350586
# Train_AverageEpLen : 54.2972972972973
# Train_EnvstepsSoFar : 391056
# TimeSinceStart : 415.1715269088745
# Training Loss : 120.66940307617188
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 39 ************
#
# Collecting data to be used for training...
# At timestep:     10013 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 95.6008071899414
# Eval_StdReturn : 16.537883758544922
# Eval_MaxReturn : 137.58587646484375
# Eval_MinReturn : 74.51781463623047
# Eval_AverageEpLen : 53.1578947368421
# Train_AverageReturn : 99.75594329833984
# Train_StdReturn : 16.29804801940918
# Train_MaxReturn : 153.08822631835938
# Train_MinReturn : 69.53497314453125
# Train_AverageEpLen : 54.71584699453552
# Train_EnvstepsSoFar : 401069
# TimeSinceStart : 425.4615366458893
# Training Loss : 120.29017639160156
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 40 ************
#
# Collecting data to be used for training...
# At timestep:     10014 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 98.10131072998047
# Eval_StdReturn : 17.145870208740234
# Eval_MaxReturn : 137.61964416503906
# Eval_MinReturn : 75.00931549072266
# Eval_AverageEpLen : 54.0
# Train_AverageReturn : 98.41194152832031
# Train_StdReturn : 16.75372886657715
# Train_MaxReturn : 148.12063598632812
# Train_MinReturn : 70.29933166503906
# Train_AverageEpLen : 54.12972972972973
# Train_EnvstepsSoFar : 411083
# TimeSinceStart : 440.358434677124
# Training Loss : 120.39868927001953
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 41 ************
#
# Collecting data to be used for training...
# At timestep:     10030 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 97.98590850830078
# Eval_StdReturn : 14.463420867919922
# Eval_MaxReturn : 129.40342712402344
# Eval_MinReturn : 66.50553894042969
# Eval_AverageEpLen : 54.0
# Train_AverageReturn : 98.74771118164062
# Train_StdReturn : 15.385418891906738
# Train_MaxReturn : 146.82089233398438
# Train_MinReturn : 66.60588073730469
# Train_AverageEpLen : 54.21621621621622
# Train_EnvstepsSoFar : 421113
# TimeSinceStart : 455.81940484046936
# Training Loss : 120.1939926147461
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 42 ************
#
# Collecting data to be used for training...
# At timestep:     10046 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 94.08782196044922
# Eval_StdReturn : 15.53431224822998
# Eval_MaxReturn : 125.94741821289062
# Eval_MinReturn : 73.86564636230469
# Eval_AverageEpLen : 52.25
# Train_AverageReturn : 99.07605743408203
# Train_StdReturn : 17.62150001525879
# Train_MaxReturn : 148.23072814941406
# Train_MinReturn : 17.692453384399414
# Train_AverageEpLen : 54.3027027027027
# Train_EnvstepsSoFar : 431159
# TimeSinceStart : 466.4554109573364
# Training Loss : 119.5948486328125
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 43 ************
#
# Collecting data to be used for training...
# At timestep:     10043 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 103.65486145019531
# Eval_StdReturn : 15.924715995788574
# Eval_MaxReturn : 138.12489318847656
# Eval_MinReturn : 75.58454895019531
# Eval_AverageEpLen : 55.888888888888886
# Train_AverageReturn : 100.67804718017578
# Train_StdReturn : 15.600932121276855
# Train_MaxReturn : 142.73513793945312
# Train_MinReturn : 68.3345947265625
# Train_AverageEpLen : 54.87978142076503
# Train_EnvstepsSoFar : 441202
# TimeSinceStart : 477.6117477416992
# Training Loss : 119.65421295166016
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 44 ************
#
# Collecting data to be used for training...
# At timestep:     10027 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 100.7995376586914
# Eval_StdReturn : 11.36463737487793
# Eval_MaxReturn : 129.0852508544922
# Eval_MinReturn : 85.2243423461914
# Eval_AverageEpLen : 55.26315789473684
# Train_AverageReturn : 102.49691009521484
# Train_StdReturn : 13.610910415649414
# Train_MaxReturn : 146.53616333007812
# Train_MinReturn : 69.96730041503906
# Train_AverageEpLen : 55.705555555555556
# Train_EnvstepsSoFar : 451229
# TimeSinceStart : 487.77833676338196
# Training Loss : 119.93097686767578
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 45 ************
#
# Collecting data to be used for training...
# At timestep:     10013 / 100006675 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 107.58817291259766
# Eval_StdReturn : 11.030842781066895
# Eval_MaxReturn : 124.19007873535156
# Eval_MinReturn : 84.11552429199219
# Eval_AverageEpLen : 57.55555555555556
# Train_AverageReturn : 101.56597137451172
# Train_StdReturn : 16.447114944458008
# Train_MaxReturn : 145.05657958984375
# Train_MinReturn : 12.127363204956055
# Train_AverageEpLen : 55.32044198895028
# Train_EnvstepsSoFar : 461242
# TimeSinceStart : 497.87530279159546
# Training Loss : 119.39295196533203
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 46 ************
#
# Collecting data to be used for training...
# At timestep:     10015 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 110.31538391113281
# Eval_StdReturn : 20.58665657043457
# Eval_MaxReturn : 147.34640502929688
# Eval_MinReturn : 77.77082824707031
# Eval_AverageEpLen : 58.388888888888886
# Train_AverageReturn : 104.1553955078125
# Train_StdReturn : 15.339548110961914
# Train_MaxReturn : 141.91189575195312
# Train_MinReturn : 24.926292419433594
# Train_AverageEpLen : 56.264044943820224
# Train_EnvstepsSoFar : 471257
# TimeSinceStart : 508.01440691947937
# Training Loss : 120.09564208984375
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 47 ************
#
# Collecting data to be used for training...
# At timestep:     10019 / 100000000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 110.63421630859375
# Eval_StdReturn : 18.245485305786133
# Eval_MaxReturn : 131.29824829101562
# Eval_MinReturn : 52.52625274658203
# Eval_AverageEpLen : 58.88235294117647
# Train_AverageReturn : 110.82223510742188
# Train_StdReturn : 17.29018783569336
# Train_MaxReturn : 150.92543029785156
# Train_MinReturn : 24.81382179260254
# Train_AverageEpLen : 58.590643274853804
# Train_EnvstepsSoFar : 481276
# TimeSinceStart : 517.4255669116974
# Training Loss : 119.91602325439453
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 48 ************
#
# Collecting data to be used for training...
# At timestep:     10040 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 121.83859252929688
# Eval_StdReturn : 30.677106857299805
# Eval_MaxReturn : 148.2581329345703
# Eval_MinReturn : 11.1094388961792
# Eval_AverageEpLen : 62.8235294117647
# Train_AverageReturn : 117.19280242919922
# Train_StdReturn : 19.454627990722656
# Train_MaxReturn : 152.5042724609375
# Train_MinReturn : 11.950460433959961
# Train_AverageEpLen : 60.84848484848485
# Train_EnvstepsSoFar : 491316
# TimeSinceStart : 527.0352966785431
# Training Loss : 120.6751480102539
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 49 ************
#
# Collecting data to be used for training...
# At timestep:     10069 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 122.47776794433594
# Eval_StdReturn : 16.915454864501953
# Eval_MaxReturn : 168.12057495117188
# Eval_MinReturn : 98.63421630859375
# Eval_AverageEpLen : 62.6875
# Train_AverageReturn : 122.0416259765625
# Train_StdReturn : 24.37625503540039
# Train_MaxReturn : 167.82029724121094
# Train_MinReturn : 19.1813907623291
# Train_AverageEpLen : 62.54037267080745
# Train_EnvstepsSoFar : 501385
# TimeSinceStart : 536.611850976944
# Training Loss : 119.88941192626953
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 50 ************
#
# Collecting data to be used for training...
# At timestep:     10067 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 119.53504180908203
# Eval_StdReturn : 26.06810188293457
# Eval_MaxReturn : 162.27793884277344
# Eval_MinReturn : 38.98720932006836
# Eval_AverageEpLen : 62.294117647058826
# Train_AverageReturn : 122.8083267211914
# Train_StdReturn : 22.921283721923828
# Train_MaxReturn : 160.54568481445312
# Train_MinReturn : 11.112091064453125
# Train_AverageEpLen : 62.91875
# Train_EnvstepsSoFar : 511452
# TimeSinceStart : 546.137158870697
# Training Loss : 120.76402282714844
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 51 ************
#
# Collecting data to be used for training...
# At timestep:     10037 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 124.65339660644531
# Eval_StdReturn : 10.022685050964355
# Eval_MaxReturn : 138.2054901123047
# Eval_MinReturn : 100.88614654541016
# Eval_AverageEpLen : 64.0625
# Train_AverageReturn : 123.96580505371094
# Train_StdReturn : 19.32061767578125
# Train_MaxReturn : 160.43914794921875
# Train_MinReturn : 15.536090850830078
# Train_AverageEpLen : 63.5253164556962
# Train_EnvstepsSoFar : 521489
# TimeSinceStart : 560.9144368171692
# Training Loss : 121.65061950683594
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 52 ************
#
# Collecting data to be used for training...
# At timestep:     10009 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 116.81193542480469
# Eval_StdReturn : 11.805601119995117
# Eval_MaxReturn : 142.74044799804688
# Eval_MinReturn : 95.77776336669922
# Eval_AverageEpLen : 61.0
# Train_AverageReturn : 123.57300567626953
# Train_StdReturn : 18.841468811035156
# Train_MaxReturn : 166.49014282226562
# Train_MinReturn : 20.467723846435547
# Train_AverageEpLen : 63.348101265822784
# Train_EnvstepsSoFar : 531498
# TimeSinceStart : 571.2607979774475
# Training Loss : 121.73966979980469
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 53 ************
#
# Collecting data to be used for training...
# At timestep:     10049 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 118.85820770263672
# Eval_StdReturn : 18.15367317199707
# Eval_MaxReturn : 147.5828857421875
# Eval_MinReturn : 72.52143859863281
# Eval_AverageEpLen : 61.64705882352941
# Train_AverageReturn : 117.5302734375
# Train_StdReturn : 19.67841911315918
# Train_MaxReturn : 156.92654418945312
# Train_MinReturn : 14.164724349975586
# Train_AverageEpLen : 61.27439024390244
# Train_EnvstepsSoFar : 541547
# TimeSinceStart : 581.0468287467957
# Training Loss : 121.9658203125
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 54 ************
#
# Collecting data to be used for training...
# At timestep:     10026 / 100000000/ 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 106.31363677978516
# Eval_StdReturn : 26.72528839111328
# Eval_MaxReturn : 139.85496520996094
# Eval_MinReturn : 15.086146354675293
# Eval_AverageEpLen : 57.05555555555556
# Train_AverageReturn : 111.17737579345703
# Train_StdReturn : 14.717923164367676
# Train_MaxReturn : 145.17945861816406
# Train_MinReturn : 10.41646957397461
# Train_AverageEpLen : 58.976470588235294
# Train_EnvstepsSoFar : 551573
# TimeSinceStart : 591.2109429836273
# Training Loss : 121.83287048339844
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 55 ************
#
# Collecting data to be used for training...
# At timestep:     10030 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 113.39131927490234
# Eval_StdReturn : 14.698614120483398
# Eval_MaxReturn : 140.8932647705078
# Eval_MinReturn : 79.9730224609375
# Eval_AverageEpLen : 59.76470588235294
# Train_AverageReturn : 111.37029266357422
# Train_StdReturn : 15.540685653686523
# Train_MaxReturn : 154.35006713867188
# Train_MinReturn : 63.739559173583984
# Train_AverageEpLen : 59.0
# Train_EnvstepsSoFar : 561603
# TimeSinceStart : 601.5455980300903
# Training Loss : 121.99790954589844
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 56 ************
#
# Collecting data to be used for training...
# At timestep:     10007 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 107.70440673828125
# Eval_StdReturn : 36.09751892089844
# Eval_MaxReturn : 167.51339721679688
# Eval_MinReturn : 33.643760681152344
# Eval_AverageEpLen : 57.111111111111114
# Train_AverageReturn : 114.32040405273438
# Train_StdReturn : 18.843013763427734
# Train_MaxReturn : 152.08961486816406
# Train_MinReturn : 13.197233200073242
# Train_AverageEpLen : 60.28313253012048
# Train_EnvstepsSoFar : 571610
# TimeSinceStart : 611.825249671936
# Training Loss : 121.79922485351562
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 57 ************
#
# Collecting data to be used for training...
# At timestep:     10033 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 128.37826538085938
# Eval_StdReturn : 33.34978103637695
# Eval_MaxReturn : 166.3268585205078
# Eval_MinReturn : 43.00868606567383
# Eval_AverageEpLen : 64.5
# Train_AverageReturn : 120.78307342529297
# Train_StdReturn : 22.19010353088379
# Train_MaxReturn : 161.33279418945312
# Train_MinReturn : 25.387332916259766
# Train_AverageEpLen : 62.316770186335404
# Train_EnvstepsSoFar : 581643
# TimeSinceStart : 620.8830559253693
# Training Loss : 123.13471984863281
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 58 ************
#
# Collecting data to be used for training...
# At timestep:     10031 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 113.57012176513672
# Eval_StdReturn : 46.03175354003906
# Eval_MaxReturn : 175.8291473388672
# Eval_MinReturn : 38.52733612060547
# Eval_AverageEpLen : 58.88235294117647
# Train_AverageReturn : 120.8867416381836
# Train_StdReturn : 33.882171630859375
# Train_MaxReturn : 177.3383331298828
# Train_MinReturn : 17.151222229003906
# Train_AverageEpLen : 61.91975308641975
# Train_EnvstepsSoFar : 591674
# TimeSinceStart : 629.8353469371796
# Training Loss : 122.11724853515625
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 59 ************
#
# Collecting data to be used for training...
# At timestep:     10066 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 125.90570068359375
# Eval_StdReturn : 33.23521423339844
# Eval_MaxReturn : 158.5467987060547
# Eval_MinReturn : 47.5483512878418
# Eval_AverageEpLen : 64.0
# Train_AverageReturn : 118.4343032836914
# Train_StdReturn : 43.23301315307617
# Train_MaxReturn : 183.67385864257812
# Train_MinReturn : 24.477163314819336
# Train_AverageEpLen : 60.63855421686747
# Train_EnvstepsSoFar : 601740
# TimeSinceStart : 640.7264766693115
# Training Loss : 119.91162872314453
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 60 ************
#
# Collecting data to be used for training...
# At timestep:     10071 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 141.77249145507812
# Eval_StdReturn : 31.808645248413086
# Eval_MaxReturn : 178.27471923828125
# Eval_MinReturn : 44.19108200073242
# Eval_AverageEpLen : 69.13333333333334
# Train_AverageReturn : 121.94573211669922
# Train_StdReturn : 47.249176025390625
# Train_MaxReturn : 186.7530059814453
# Train_MinReturn : 11.378353118896484
# Train_AverageEpLen : 61.785276073619634
# Train_EnvstepsSoFar : 611811
# TimeSinceStart : 650.721688747406
# Training Loss : 120.05384063720703
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 61 ************
#
# Collecting data to be used for training...
# At timestep:     10077 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 118.17533111572266
# Eval_StdReturn : 67.13052368164062
# Eval_MaxReturn : 218.3529815673828
# Eval_MinReturn : 14.17755126953125
# Eval_AverageEpLen : 63.4375
# Train_AverageReturn : 139.9602508544922
# Train_StdReturn : 39.53156661987305
# Train_MaxReturn : 204.95059204101562
# Train_MinReturn : 31.651718139648438
# Train_AverageEpLen : 68.55102040816327
# Train_EnvstepsSoFar : 621888
# TimeSinceStart : 659.9012849330902
# Training Loss : 122.48783111572266
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 62 ************
#
# Collecting data to be used for training...
# At timestep:     10026 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 138.96824645996094
# Eval_StdReturn : 48.39910888671875
# Eval_MaxReturn : 234.6300048828125
# Eval_MinReturn : 39.38151550292969
# Eval_AverageEpLen : 78.92307692307692
# Train_AverageReturn : 137.1797637939453
# Train_StdReturn : 50.707218170166016
# Train_MaxReturn : 230.94337463378906
# Train_MinReturn : 5.675336837768555
# Train_AverageEpLen : 70.1118881118881
# Train_EnvstepsSoFar : 631914
# TimeSinceStart : 672.027096748352
# Training Loss : 116.95348358154297
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ...
# Training Loss : 118.2994384765625
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 79 ************
#
# Collecting data to be used for training...
# At timestep:     10030 / 1000010000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 84.87425231933594
# Eval_StdReturn : 17.164886474609375
# Eval_MaxReturn : 136.14341735839844
# Eval_MinReturn : 48.091339111328125
# Eval_AverageEpLen : 51.75
# Train_AverageReturn : 82.3962631225586
# Train_StdReturn : 3.123440742492676
# Train_MaxReturn : 104.51173400878906
# Train_MinReturn : 76.59196472167969
# Train_AverageEpLen : 49.166666666666664
# Train_EnvstepsSoFar : 802071
# TimeSinceStart : 893.8659570217133
# Training Loss : 117.91830444335938
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 80 ************
#
# Collecting data to be used for training...
# At timestep:     10038 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 85.56319427490234
# Eval_StdReturn : 19.98741912841797
# Eval_MaxReturn : 134.43260192871094
# Eval_MinReturn : 53.93441390991211
# Eval_AverageEpLen : 52.25
# Train_AverageReturn : 83.02790069580078
# Train_StdReturn : 10.470769882202148
# Train_MaxReturn : 130.15553283691406
# Train_MinReturn : 48.047027587890625
# Train_AverageEpLen : 49.940298507462686
# Train_EnvstepsSoFar : 812109
# TimeSinceStart : 901.8381459712982
# Training Loss : 117.76036071777344
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 81 ************
#
# Collecting data to be used for training...
# At timestep:     10053 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 69.8311538696289
# Eval_StdReturn : 23.777170181274414
# Eval_MaxReturn : 109.24360656738281
# Eval_MinReturn : 47.37114715576172
# Eval_AverageEpLen : 47.0
# Train_AverageReturn : 80.93597412109375
# Train_StdReturn : 21.94293212890625
# Train_MaxReturn : 160.82583618164062
# Train_MinReturn : 17.999481201171875
# Train_AverageEpLen : 50.517587939698494
# Train_EnvstepsSoFar : 822162
# TimeSinceStart : 909.944265127182
# Training Loss : 114.5902099609375
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 82 ************
#
# Collecting data to be used for training...
# At timestep:     10033 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 63.41729736328125
# Eval_StdReturn : 24.09345054626465
# Eval_MaxReturn : 113.35071563720703
# Eval_MinReturn : 23.897951126098633
# Eval_AverageEpLen : 44.125
# Train_AverageReturn : 72.17694091796875
# Train_StdReturn : 24.578773498535156
# Train_MaxReturn : 133.2743377685547
# Train_MinReturn : 21.12375259399414
# Train_AverageEpLen : 48.004784688995215
# Train_EnvstepsSoFar : 832195
# TimeSinceStart : 917.9754371643066
# Training Loss : 108.38864135742188
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 83 ************
#
# Collecting data to be used for training...
# At timestep:     10002 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 73.39541625976562
# Eval_StdReturn : 23.3077449798584
# Eval_MaxReturn : 118.18266296386719
# Eval_MinReturn : 49.951290130615234
# Eval_AverageEpLen : 49.57142857142857
# Train_AverageReturn : 67.54130554199219
# Train_StdReturn : 24.364534378051758
# Train_MaxReturn : 147.78094482421875
# Train_MinReturn : 15.974574089050293
# Train_AverageEpLen : 46.520930232558136
# Train_EnvstepsSoFar : 842197
# TimeSinceStart : 926.0438261032104
# Training Loss : 105.5088119506836
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 84 ************
#
# Collecting data to be used for training...
# At timestep:     10023 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 67.60527801513672
# Eval_StdReturn : 24.713180541992188
# Eval_MaxReturn : 121.53152465820312
# Eval_MinReturn : 48.58623504638672
# Eval_AverageEpLen : 47.40909090909091
# Train_AverageReturn : 68.55067443847656
# Train_StdReturn : 24.954105377197266
# Train_MaxReturn : 154.09213256835938
# Train_MinReturn : 34.90548324584961
# Train_AverageEpLen : 47.278301886792455
# Train_EnvstepsSoFar : 852220
# TimeSinceStart : 934.2886462211609
# Training Loss : 105.45975494384766
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 85 ************
#
# Collecting data to be used for training...
# At timestep:     10013 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 87.93426513671875
# Eval_StdReturn : 37.084354400634766
# Eval_MaxReturn : 162.18116760253906
# Eval_MinReturn : 44.527828216552734
# Eval_AverageEpLen : 53.578947368421055
# Train_AverageReturn : 68.09782409667969
# Train_StdReturn : 23.155122756958008
# Train_MaxReturn : 154.24749755859375
# Train_MinReturn : 41.43343734741211
# Train_AverageEpLen : 47.45497630331754
# Train_EnvstepsSoFar : 862233
# TimeSinceStart : 942.3539712429047
# Training Loss : 105.68356323242188
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 86 ************
#
# Collecting data to be used for training...
# At timestep:     10008 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 74.77178192138672
# Eval_StdReturn : 22.843124389648438
# Eval_MaxReturn : 121.78209686279297
# Eval_MinReturn : 43.29584884643555
# Eval_AverageEpLen : 50.5
# Train_AverageReturn : 74.91998291015625
# Train_StdReturn : 26.526216506958008
# Train_MaxReturn : 184.0365447998047
# Train_MinReturn : 46.363670349121094
# Train_AverageEpLen : 50.54545454545455
# Train_EnvstepsSoFar : 872241
# TimeSinceStart : 950.3130333423615
# Training Loss : 108.79620361328125
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 87 ************
#
# Collecting data to be used for training...
# At timestep:     10007 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 87.94820404052734
# Eval_StdReturn : 26.027711868286133
# Eval_MaxReturn : 157.98367309570312
# Eval_MinReturn : 61.72895812988281
# Eval_AverageEpLen : 58.55555555555556
# Train_AverageReturn : 80.36813354492188
# Train_StdReturn : 26.476139068603516
# Train_MaxReturn : 170.23895263671875
# Train_MinReturn : 42.82874298095703
# Train_AverageEpLen : 53.22872340425532
# Train_EnvstepsSoFar : 882248
# TimeSinceStart : 958.3730962276459
# Training Loss : 109.96234130859375
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 88 ************
#
# Collecting data to be used for training...
# At timestep:     10011 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 99.27114868164062
# Eval_StdReturn : 26.81960105895996
# Eval_MaxReturn : 165.5909881591797
# Eval_MinReturn : 59.92900085449219
# Eval_AverageEpLen : 62.64705882352941
# Train_AverageReturn : 88.23575592041016
# Train_StdReturn : 28.95543670654297
# Train_MaxReturn : 284.26129150390625
# Train_MinReturn : 40.97055435180664
# Train_AverageEpLen : 57.205714285714286
# Train_EnvstepsSoFar : 892259
# TimeSinceStart : 966.3381490707397
# Training Loss : 112.35162353515625
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 89 ************
#
# Collecting data to be used for training...
# At timestep:     10039 / 100000000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 113.79933166503906
# Eval_StdReturn : 28.916790008544922
# Eval_MaxReturn : 198.07440185546875
# Eval_MinReturn : 76.28227996826172
# Eval_AverageEpLen : 66.73333333333333
# Train_AverageReturn : 101.92527770996094
# Train_StdReturn : 24.02789878845215
# Train_MaxReturn : 165.15721130371094
# Train_MinReturn : 41.085819244384766
# Train_AverageEpLen : 63.537974683544306
# Train_EnvstepsSoFar : 902298
# TimeSinceStart : 974.3081731796265
# Training Loss : 116.369384765625
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 90 ************
#
# Collecting data to be used for training...
# At timestep:     10089 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 103.8033676147461
# Eval_StdReturn : 27.9434814453125
# Eval_MaxReturn : 141.90066528320312
# Eval_MinReturn : 51.50689697265625
# Eval_AverageEpLen : 61.11764705882353
# Train_AverageReturn : 117.77346801757812
# Train_StdReturn : 28.43064308166504
# Train_MaxReturn : 240.9261474609375
# Train_MinReturn : 60.34771728515625
# Train_AverageEpLen : 69.57931034482759
# Train_EnvstepsSoFar : 912387
# TimeSinceStart : 982.2736141681671
# Training Loss : 119.84333801269531
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 91 ************
#
# Collecting data to be used for training...
# At timestep:     10036 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 94.71548461914062
# Eval_StdReturn : 26.133386611938477
# Eval_MaxReturn : 159.37271118164062
# Eval_MinReturn : 70.380859375
# Eval_AverageEpLen : 56.666666666666664
# Train_AverageReturn : 106.57608795166016
# Train_StdReturn : 26.883106231689453
# Train_MaxReturn : 183.71556091308594
# Train_MinReturn : 42.7520637512207
# Train_AverageEpLen : 62.33540372670807
# Train_EnvstepsSoFar : 922423
# TimeSinceStart : 990.2167401313782
# Training Loss : 118.99314880371094
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 92 ************
#
# Collecting data to be used for training...
# At timestep:     10047 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 96.12887573242188
# Eval_StdReturn : 21.9251651763916
# Eval_MaxReturn : 143.0132293701172
# Eval_MinReturn : 64.44852447509766
# Eval_AverageEpLen : 57.05555555555556
# Train_AverageReturn : 93.36141204833984
# Train_StdReturn : 21.565324783325195
# Train_MaxReturn : 197.35243225097656
# Train_MinReturn : 46.285465240478516
# Train_AverageEpLen : 55.2032967032967
# Train_EnvstepsSoFar : 932470
# TimeSinceStart : 998.287474155426
# Training Loss : 117.34159088134766
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 93 ************
#
# Collecting data to be used for training...
# At timestep:     10008 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 80.63772583007812
# Eval_StdReturn : 24.079158782958984
# Eval_MaxReturn : 164.11216735839844
# Eval_MinReturn : 57.8886833190918
# Eval_AverageEpLen : 47.904761904761905
# Train_AverageReturn : 88.82632446289062
# Train_StdReturn : 23.45970344543457
# Train_MaxReturn : 187.71226501464844
# Train_MinReturn : 49.864410400390625
# Train_AverageEpLen : 52.95238095238095
# Train_EnvstepsSoFar : 942478
# TimeSinceStart : 1006.2505600452423
# Training Loss : 116.57414245605469
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 94 ************
#
# Collecting data to be used for training...
# At timestep:     10021 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 73.92491912841797
# Eval_StdReturn : 15.056530952453613
# Eval_MaxReturn : 117.39850616455078
# Eval_MinReturn : 50.142765045166016
# Eval_AverageEpLen : 44.73913043478261
# Train_AverageReturn : 79.88075256347656
# Train_StdReturn : 20.36801528930664
# Train_MaxReturn : 189.79969787597656
# Train_MinReturn : 45.389591217041016
# Train_AverageEpLen : 48.17788461538461
# Train_EnvstepsSoFar : 952499
# TimeSinceStart : 1014.2866940498352
# Training Loss : 115.18441009521484
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 95 ************
#
# Collecting data to be used for training...
# At timestep:     10048 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 66.13848114013672
# Eval_StdReturn : 8.873737335205078
# Eval_MaxReturn : 86.88410186767578
# Eval_MinReturn : 49.638851165771484
# Eval_AverageEpLen : 40.36
# Train_AverageReturn : 73.89720153808594
# Train_StdReturn : 15.899927139282227
# Train_MaxReturn : 164.98487854003906
# Train_MinReturn : 46.88099670410156
# Train_AverageEpLen : 44.857142857142854
# Train_EnvstepsSoFar : 962547
# TimeSinceStart : 1022.3542311191559
# Training Loss : 112.68293762207031
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 96 ************
#
# Collecting data to be used for training...
# At timestep:     10018 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 58.700618743896484
# Eval_StdReturn : 4.865888595581055
# Eval_MaxReturn : 71.66315460205078
# Eval_MinReturn : 52.04790496826172
# Eval_AverageEpLen : 35.82142857142857
# Train_AverageReturn : 65.21920776367188
# Train_StdReturn : 8.4456148147583
# Train_MaxReturn : 93.57017517089844
# Train_MinReturn : 48.02781677246094
# Train_AverageEpLen : 39.75396825396825
# Train_EnvstepsSoFar : 972565
# TimeSinceStart : 1030.543050289154
# Training Loss : 109.3937759399414
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 97 ************
#
# Collecting data to be used for training...
# At timestep:     10024 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 56.43861389160156
# Eval_StdReturn : 4.891231536865234
# Eval_MaxReturn : 70.1384048461914
# Eval_MinReturn : 49.520965576171875
# Eval_AverageEpLen : 34.4
# Train_AverageReturn : 59.77903366088867
# Train_StdReturn : 6.530491352081299
# Train_MaxReturn : 84.18605041503906
# Train_MinReturn : 41.0661735534668
# Train_AverageEpLen : 36.45090909090909
# Train_EnvstepsSoFar : 982589
# TimeSinceStart : 1038.7270901203156
# Training Loss : 105.89081573486328
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 98 ************
#
# Collecting data to be used for training...
# At timestep:     10030 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 53.64873504638672
# Eval_StdReturn : 4.208071708679199
# Eval_MaxReturn : 65.29704284667969
# Eval_MinReturn : 47.96156692504883
# Eval_AverageEpLen : 32.774193548387096
# Train_AverageReturn : 56.36170196533203
# Train_StdReturn : 5.704816818237305
# Train_MaxReturn : 76.03553009033203
# Train_MinReturn : 46.96929168701172
# Train_AverageEpLen : 34.34931506849315
# Train_EnvstepsSoFar : 992619
# TimeSinceStart : 1046.8907723426819
# Training Loss : 102.86589813232422
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 99 ************
#
# Collecting data to be used for training...
# At timestep:     10013 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 54.08275604248047
# Eval_StdReturn : 4.484805583953857
# Eval_MaxReturn : 67.78945922851562
# Eval_MinReturn : 47.67334747314453
# Eval_AverageEpLen : 32.96774193548387
# Train_AverageReturn : 54.23523712158203
# Train_StdReturn : 3.938204288482666
# Train_MaxReturn : 66.06488037109375
# Train_MinReturn : 41.18581771850586
# Train_AverageEpLen : 33.04620462046205
# Train_EnvstepsSoFar : 1002632
# TimeSinceStart : 1055.2884709835052
# Training Loss : 101.14115142822266
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...

# %%
pg_args = dict(pg_base_args_dict)

env_str = 'Hopper'
pg_args['env_name'] = '{}-v2'.format(env_str)
pg_args['learning_rate'] = 0.01
pg_args['reward_to_go'] = True
pg_args['batch_size'] = 10000
pg_args['train_batch_size'] = 10000
pg_args['n_iter'] = 100

# Delete all previous logs
remove_folder('logs/policy_gradient/{}/return_to_go/'.format(env_str))

for seed in range(3):
    print("Running policy gradient experiment with seed", seed)
    pg_args['seed'] = seed
    pg_args['logdir'] = 'logs/policy_gradient/{}/return_to_go/seed{}'.format(env_str, seed)
    pgtrainer = PG_Trainer(pg_args)
    pgtrainer.run_training_loop()
# Out:
# Folder logs/policy_gradient/Hopper/return_to_go/ does not exist yet. No old results to delete
# Running policy gradient experiment with seed 0
# ########################
# logging outputs to  logs/policy_gradient/Hopper/return_to_go/seed0
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# Hopper-v2
#
#
# ********** Iteration 0 ************
#
# Collecting data to be used for training...
# At timestep:     10004 / 1000010000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 97.36431121826172
# Eval_StdReturn : 56.1705207824707
# Eval_MaxReturn : 247.20233154296875
# Eval_MinReturn : 17.86540985107422
# Eval_AverageEpLen : 61.64705882352941
# Train_AverageReturn : 9.657980918884277
# Train_StdReturn : 5.853752613067627
# Train_MaxReturn : 87.45542907714844
# Train_MinReturn : 3.010934352874756
# Train_AverageEpLen : 13.215323645970939
# Train_EnvstepsSoFar : 10004
# TimeSinceStart : 10.305842161178589
# Training Loss : 18.090417861938477
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 1 ************
#
# Collecting data to be used for training...
# At timestep:     10028 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 74.83673095703125
# Eval_StdReturn : 12.586796760559082
# Eval_MaxReturn : 109.0075912475586
# Eval_MinReturn : 55.418758392333984
# Eval_AverageEpLen : 44.95652173913044
# Train_AverageReturn : 86.47572326660156
# Train_StdReturn : 52.808433532714844
# Train_MaxReturn : 252.57847595214844
# Train_MinReturn : 6.542728424072266
# Train_AverageEpLen : 54.5
# Train_EnvstepsSoFar : 20032
# TimeSinceStart : 22.673306226730347
# Training Loss : 102.84622192382812
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 2 ************
#
# Collecting data to be used for training...
# At timestep:     10022 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 88.26393127441406
# Eval_StdReturn : 14.384303092956543
# Eval_MaxReturn : 124.45768737792969
# Eval_MinReturn : 65.53836059570312
# Eval_AverageEpLen : 51.2
# Train_AverageReturn : 79.2903060913086
# Train_StdReturn : 17.705259323120117
# Train_MaxReturn : 178.68356323242188
# Train_MinReturn : 55.416194915771484
# Train_AverageEpLen : 47.72380952380952
# Train_EnvstepsSoFar : 30054
# TimeSinceStart : 36.540040016174316
# Training Loss : 98.99420928955078
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 3 ************
#
# Collecting data to be used for training...
# At timestep:     10010 / 1000010000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 122.05274963378906
# Eval_StdReturn : 34.17659378051758
# Eval_MaxReturn : 192.69754028320312
# Eval_MinReturn : 78.61380004882812
# Eval_AverageEpLen : 63.9375
# Train_AverageReturn : 87.70250701904297
# Train_StdReturn : 19.838712692260742
# Train_MaxReturn : 171.647216796875
# Train_MinReturn : 59.1412353515625
# Train_AverageEpLen : 50.55555555555556
# Train_EnvstepsSoFar : 40064
# TimeSinceStart : 46.18547320365906
# Training Loss : 106.54765319824219
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 4 ************
#
# Collecting data to be used for training...
# At timestep:     10053 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 204.439208984375
# Eval_StdReturn : 37.101280212402344
# Eval_MaxReturn : 253.41506958007812
# Eval_MinReturn : 127.92462158203125
# Eval_AverageEpLen : 101.27272727272727
# Train_AverageReturn : 117.80029296875
# Train_StdReturn : 33.66783142089844
# Train_MaxReturn : 235.24740600585938
# Train_MinReturn : 75.37960815429688
# Train_AverageEpLen : 63.22641509433962
# Train_EnvstepsSoFar : 50117
# TimeSinceStart : 62.221827268600464
# Training Loss : 124.14750671386719
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 5 ************
#
# Collecting data to be used for training...
# At timestep:     10069 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 171.0036163330078
# Eval_StdReturn : 37.316898345947266
# Eval_MaxReturn : 233.3486328125
# Eval_MinReturn : 117.33633422851562
# Eval_AverageEpLen : 86.58333333333333
# Train_AverageReturn : 208.6101531982422
# Train_StdReturn : 29.258203506469727
# Train_MaxReturn : 249.9329833984375
# Train_MinReturn : 90.5279769897461
# Train_AverageEpLen : 97.75728155339806
# Train_EnvstepsSoFar : 60186
# TimeSinceStart : 70.75262022018433
# Training Loss : 158.02334594726562
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 6 ************
#
# Collecting data to be used for training...
# At timestep:     10085 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 173.2112579345703
# Eval_StdReturn : 33.9420166015625
# Eval_MaxReturn : 214.286376953125
# Eval_MinReturn : 108.93885803222656
# Eval_AverageEpLen : 83.0
# Train_AverageReturn : 173.1794891357422
# Train_StdReturn : 36.9360237121582
# Train_MaxReturn : 234.86814880371094
# Train_MinReturn : 75.32490539550781
# Train_AverageEpLen : 84.74789915966386
# Train_EnvstepsSoFar : 70271
# TimeSinceStart : 79.64204430580139
# Training Loss : 147.0639190673828
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 7 ************
#
# Collecting data to be used for training...
# At timestep:     10055 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 206.24925231933594
# Eval_StdReturn : 4.504364490509033
# Eval_MaxReturn : 216.28648376464844
# Eval_MinReturn : 199.9722137451172
# Eval_AverageEpLen : 93.36363636363636
# Train_AverageReturn : 163.33384704589844
# Train_StdReturn : 40.198360443115234
# Train_MaxReturn : 223.3987274169922
# Train_MinReturn : 90.04806518554688
# Train_AverageEpLen : 79.8015873015873
# Train_EnvstepsSoFar : 80326
# TimeSinceStart : 89.56374716758728
# Training Loss : 145.29591369628906
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 8 ************
#
# Collecting data to be used for training...
# At timestep:     10014 / 100000000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 204.27978515625
# Eval_StdReturn : 4.998894214630127
# Eval_MaxReturn : 212.7727813720703
# Eval_MinReturn : 197.0357208251953
# Eval_AverageEpLen : 90.66666666666667
# Train_AverageReturn : 206.16334533691406
# Train_StdReturn : 4.555063724517822
# Train_MaxReturn : 219.765380859375
# Train_MinReturn : 186.33172607421875
# Train_AverageEpLen : 92.72222222222223
# Train_EnvstepsSoFar : 90340
# TimeSinceStart : 100.95118713378906
# Training Loss : 163.37661743164062
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 9 ************
#
# Collecting data to be used for training...
# At timestep:     10016 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 196.0691375732422
# Eval_StdReturn : 15.982402801513672
# Eval_MaxReturn : 213.99928283691406
# Eval_MinReturn : 157.10545349121094
# Eval_AverageEpLen : 87.66666666666667
# Train_AverageReturn : 206.9092254638672
# Train_StdReturn : 5.859963417053223
# Train_MaxReturn : 219.076904296875
# Train_MinReturn : 183.79141235351562
# Train_AverageEpLen : 91.88990825688073
# Train_EnvstepsSoFar : 100356
# TimeSinceStart : 114.4845712184906
# Training Loss : 164.42437744140625
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 10 ************
#
# Collecting data to be used for training...
# At timestep:     10017 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 158.4131622314453
# Eval_StdReturn : 15.579681396484375
# Eval_MaxReturn : 187.76133728027344
# Eval_MinReturn : 127.26519775390625
# Eval_AverageEpLen : 75.42857142857143
# Train_AverageReturn : 194.4456329345703
# Train_StdReturn : 15.909438133239746
# Train_MaxReturn : 217.528076171875
# Train_MinReturn : 144.60336303710938
# Train_AverageEpLen : 87.10434782608695
# Train_EnvstepsSoFar : 110373
# TimeSinceStart : 126.61037111282349
# Training Loss : 161.05641174316406
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 11 ************
#
# Collecting data to be used for training...
# At timestep:     10044 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 141.20445251464844
# Eval_StdReturn : 15.032516479492188
# Eval_MaxReturn : 166.6125946044922
# Eval_MinReturn : 111.88572692871094
# Eval_AverageEpLen : 70.06666666666666
# Train_AverageReturn : 156.4729766845703
# Train_StdReturn : 16.73090934753418
# Train_MaxReturn : 203.66421508789062
# Train_MinReturn : 119.04261016845703
# Train_AverageEpLen : 74.95522388059702
# Train_EnvstepsSoFar : 120417
# TimeSinceStart : 136.10811018943787
# Training Loss : 145.02505493164062
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 12 ************
#
# Collecting data to be used for training...
# At timestep:     10074 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 130.7698974609375
# Eval_StdReturn : 11.940099716186523
# Eval_MaxReturn : 149.49746704101562
# Eval_MinReturn : 108.64947509765625
# Eval_AverageEpLen : 66.0625
# Train_AverageReturn : 141.5410919189453
# Train_StdReturn : 14.627829551696777
# Train_MaxReturn : 179.27099609375
# Train_MinReturn : 104.64407348632812
# Train_AverageEpLen : 69.95833333333333
# Train_EnvstepsSoFar : 130491
# TimeSinceStart : 145.64791417121887
# Training Loss : 136.73004150390625
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 13 ************
#
# Collecting data to be used for training...
# At timestep:     10058 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 133.24615478515625
# Eval_StdReturn : 14.078652381896973
# Eval_MaxReturn : 161.38449096679688
# Eval_MinReturn : 116.93834686279297
# Eval_AverageEpLen : 67.6
# Train_AverageReturn : 136.882568359375
# Train_StdReturn : 13.49901008605957
# Train_MaxReturn : 170.76747131347656
# Train_MinReturn : 98.75271606445312
# Train_AverageEpLen : 68.421768707483
# Train_EnvstepsSoFar : 140549
# TimeSinceStart : 155.76490235328674
# Training Loss : 134.53164672851562
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 14 ************
#
# Collecting data to be used for training...
# At timestep:     10028 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 162.15367126464844
# Eval_StdReturn : 11.206938743591309
# Eval_MaxReturn : 179.86697387695312
# Eval_MinReturn : 137.81419372558594
# Eval_AverageEpLen : 76.28571428571429
# Train_AverageReturn : 144.7738037109375
# Train_StdReturn : 14.073593139648438
# Train_MaxReturn : 183.72341918945312
# Train_MinReturn : 99.31963348388672
# Train_AverageEpLen : 71.12056737588652
# Train_EnvstepsSoFar : 150577
# TimeSinceStart : 170.37622809410095
# Training Loss : 137.9234619140625
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 15 ************
#
# Collecting data to be used for training...
# At timestep:     10025 / 100001565 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 189.6348876953125
# Eval_StdReturn : 9.90785026550293
# Eval_MaxReturn : 206.9062042236328
# Eval_MinReturn : 169.28482055664062
# Eval_AverageEpLen : 85.66666666666667
# Train_AverageReturn : 159.19190979003906
# Train_StdReturn : 15.649161338806152
# Train_MaxReturn : 202.40350341796875
# Train_MinReturn : 127.09355926513672
# Train_AverageEpLen : 75.9469696969697
# Train_EnvstepsSoFar : 160602
# TimeSinceStart : 184.01282835006714
# Training Loss : 145.5066375732422
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 16 ************
#
# Collecting data to be used for training...
# At timestep:     10035 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 177.1311798095703
# Eval_StdReturn : 45.33552551269531
# Eval_MaxReturn : 196.17982482910156
# Eval_MinReturn : 27.003467559814453
# Eval_AverageEpLen : 83.33333333333333
# Train_AverageReturn : 190.3385772705078
# Train_StdReturn : 9.637472152709961
# Train_MaxReturn : 219.46754455566406
# Train_MinReturn : 161.78814697265625
# Train_AverageEpLen : 86.50862068965517
# Train_EnvstepsSoFar : 170637
# TimeSinceStart : 194.35344624519348
# Training Loss : 157.34658813476562
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 17 ************
#
# Collecting data to be used for training...
# At timestep:     10048 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 93.9599838256836
# Eval_StdReturn : 73.04443359375
# Eval_MaxReturn : 198.6975860595703
# Eval_MinReturn : 25.192562103271484
# Eval_AverageEpLen : 50.9
# Train_AverageReturn : 186.75665283203125
# Train_StdReturn : 27.969762802124023
# Train_MaxReturn : 220.0859832763672
# Train_MinReturn : 31.9249210357666
# Train_AverageEpLen : 86.62068965517241
# Train_EnvstepsSoFar : 180685
# TimeSinceStart : 203.9277822971344
# Training Loss : 154.2226104736328
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 18 ************
#
# Collecting data to be used for training...
# At timestep:     10013 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 85.29592895507812
# Eval_StdReturn : 63.58430480957031
# Eval_MaxReturn : 199.72869873046875
# Eval_MinReturn : 29.55921173095703
# Eval_AverageEpLen : 47.63636363636363
# Train_AverageReturn : 91.08614349365234
# Train_StdReturn : 73.13185119628906
# Train_MaxReturn : 201.62091064453125
# Train_MinReturn : 21.213111877441406
# Train_AverageEpLen : 48.371980676328505
# Train_EnvstepsSoFar : 190698
# TimeSinceStart : 213.72694206237793
# Training Loss : 120.62821197509766
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 19 ************
#
# Collecting data to be used for training...
# At timestep:     10012 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 172.83616638183594
# Eval_StdReturn : 55.16936492919922
# Eval_MaxReturn : 205.27647399902344
# Eval_MinReturn : 40.575172424316406
# Eval_AverageEpLen : 83.75
# Train_AverageReturn : 101.96998596191406
# Train_StdReturn : 73.07827758789062
# Train_MaxReturn : 203.4372100830078
# Train_MinReturn : 22.989086151123047
# Train_AverageEpLen : 53.82795698924731
# Train_EnvstepsSoFar : 200710
# TimeSinceStart : 223.37328815460205
# Training Loss : 122.95429229736328
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 20 ************
#
# Collecting data to be used for training...
# At timestep:     10037 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 198.70143127441406
# Eval_StdReturn : 4.258444786071777
# Eval_MaxReturn : 206.10308837890625
# Eval_MinReturn : 191.23361206054688
# Eval_AverageEpLen : 92.81818181818181
# Train_AverageReturn : 181.3395538330078
# Train_StdReturn : 41.869930267333984
# Train_MaxReturn : 205.78997802734375
# Train_MinReturn : 33.66324234008789
# Train_AverageEpLen : 87.27826086956522
# Train_EnvstepsSoFar : 210747
# TimeSinceStart : 233.644061088562
# Training Loss : 147.92294311523438
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 21 ************
#
# Collecting data to be used for training...
# At timestep:     10084 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 198.45208740234375
# Eval_StdReturn : 4.78769588470459
# Eval_MaxReturn : 207.99752807617188
# Eval_MinReturn : 190.23756408691406
# Eval_AverageEpLen : 91.36363636363636
# Train_AverageReturn : 195.01121520996094
# Train_StdReturn : 19.21082305908203
# Train_MaxReturn : 215.16482543945312
# Train_MinReturn : 58.90958023071289
# Train_AverageEpLen : 91.67272727272727
# Train_EnvstepsSoFar : 220831
# TimeSinceStart : 243.24266409873962
# Training Loss : 154.04733276367188
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 22 ************
#
# Collecting data to be used for training...
# At timestep:     10051 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 197.45745849609375
# Eval_StdReturn : 10.737997055053711
# Eval_MaxReturn : 211.17332458496094
# Eval_MinReturn : 171.08966064453125
# Eval_AverageEpLen : 91.0
# Train_AverageReturn : 198.16322326660156
# Train_StdReturn : 7.0099992752075195
# Train_MaxReturn : 214.23690795898438
# Train_MinReturn : 175.2529296875
# Train_AverageEpLen : 91.37272727272727
# Train_EnvstepsSoFar : 230882
# TimeSinceStart : 253.248211145401
# Training Loss : 156.94590759277344
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 23 ************
#
# Collecting data to be used for training...
# At timestep:     10052 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 190.188232421875
# Eval_StdReturn : 18.8946590423584
# Eval_MaxReturn : 206.81756591796875
# Eval_MinReturn : 141.8779296875
# Eval_AverageEpLen : 86.83333333333333
# Train_AverageReturn : 199.46080017089844
# Train_StdReturn : 10.884088516235352
# Train_MaxReturn : 223.3096923828125
# Train_MinReturn : 140.2542724609375
# Train_AverageEpLen : 90.55855855855856
# Train_EnvstepsSoFar : 240934
# TimeSinceStart : 262.7650990486145
# Training Loss : 158.9739532470703
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 24 ************
#
# Collecting data to be used for training...
# At timestep:     10026 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 187.97630310058594
# Eval_StdReturn : 15.287443161010742
# Eval_MaxReturn : 207.148681640625
# Eval_MinReturn : 164.63253784179688
# Eval_AverageEpLen : 85.25
# Train_AverageReturn : 195.38739013671875
# Train_StdReturn : 12.91682243347168
# Train_MaxReturn : 223.93069458007812
# Train_MinReturn : 146.10902404785156
# Train_AverageEpLen : 88.72566371681415
# Train_EnvstepsSoFar : 250960
# TimeSinceStart : 271.7671549320221
# Training Loss : 158.9990997314453
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 25 ************
#
# Collecting data to be used for training...
# At timestep:     10050 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 189.77403259277344
# Eval_StdReturn : 18.106077194213867
# Eval_MaxReturn : 214.2027130126953
# Eval_MinReturn : 150.71156311035156
# Eval_AverageEpLen : 86.08333333333333
# Train_AverageReturn : 186.21083068847656
# Train_StdReturn : 14.663506507873535
# Train_MaxReturn : 215.06536865234375
# Train_MinReturn : 141.0052947998047
# Train_AverageEpLen : 85.16949152542372
# Train_EnvstepsSoFar : 261010
# TimeSinceStart : 279.87194323539734
# Training Loss : 157.19406127929688
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 26 ************
#
# Collecting data to be used for training...
# At timestep:     10050 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 187.88523864746094
# Eval_StdReturn : 19.519786834716797
# Eval_MaxReturn : 217.70263671875
# Eval_MinReturn : 152.5970001220703
# Eval_AverageEpLen : 85.66666666666667
# Train_AverageReturn : 186.03079223632812
# Train_StdReturn : 16.46132469177246
# Train_MaxReturn : 217.64073181152344
# Train_MinReturn : 143.68307495117188
# Train_AverageEpLen : 85.16949152542372
# Train_EnvstepsSoFar : 271060
# TimeSinceStart : 288.119695186615
# Training Loss : 155.8451690673828
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 27 ************
#
# Collecting data to be used for training...
# At timestep:     10016 / 100002343 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 199.9014129638672
# Eval_StdReturn : 14.503755569458008
# Eval_MaxReturn : 223.37586975097656
# Eval_MinReturn : 175.76318359375
# Eval_AverageEpLen : 90.33333333333333
# Train_AverageReturn : 186.03439331054688
# Train_StdReturn : 18.39925765991211
# Train_MaxReturn : 223.70370483398438
# Train_MinReturn : 126.54641723632812
# Train_AverageEpLen : 85.6068376068376
# Train_EnvstepsSoFar : 281076
# TimeSinceStart : 297.9339950084686
# Training Loss : 155.1754150390625
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 28 ************
#
# Collecting data to be used for training...
# At timestep:     10055 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 181.985107421875
# Eval_StdReturn : 20.123268127441406
# Eval_MaxReturn : 197.57432556152344
# Eval_MinReturn : 128.39178466796875
# Eval_AverageEpLen : 84.91666666666667
# Train_AverageReturn : 189.15261840820312
# Train_StdReturn : 14.697457313537598
# Train_MaxReturn : 220.38034057617188
# Train_MinReturn : 140.0801544189453
# Train_AverageEpLen : 86.68103448275862
# Train_EnvstepsSoFar : 291131
# TimeSinceStart : 307.6537501811981
# Training Loss : 156.2906494140625
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 29 ************
#
# Collecting data to be used for training...
# At timestep:     10000 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 177.51441955566406
# Eval_StdReturn : 16.250926971435547
# Eval_MaxReturn : 203.7882080078125
# Eval_MinReturn : 139.236328125
# Eval_AverageEpLen : 83.61538461538461
# Train_AverageReturn : 185.02508544921875
# Train_StdReturn : 18.585264205932617
# Train_MaxReturn : 226.3955535888672
# Train_MinReturn : 117.21525573730469
# Train_AverageEpLen : 85.47008547008546
# Train_EnvstepsSoFar : 301131
# TimeSinceStart : 317.38099813461304
# Training Loss : 154.54891967773438
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 30 ************
#
# Collecting data to be used for training...
# At timestep:     10023 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 183.0469207763672
# Eval_StdReturn : 10.933335304260254
# Eval_MaxReturn : 197.7477264404297
# Eval_MinReturn : 161.01100158691406
# Eval_AverageEpLen : 84.75
# Train_AverageReturn : 178.7689971923828
# Train_StdReturn : 17.737255096435547
# Train_MaxReturn : 214.1144561767578
# Train_MinReturn : 127.11317443847656
# Train_AverageEpLen : 84.22689075630252
# Train_EnvstepsSoFar : 311154
# TimeSinceStart : 326.2776620388031
# Training Loss : 149.65464782714844
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 31 ************
#
# Collecting data to be used for training...
# At timestep:     10035 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 179.5004425048828
# Eval_StdReturn : 11.049212455749512
# Eval_MaxReturn : 195.52647399902344
# Eval_MinReturn : 154.642333984375
# Eval_AverageEpLen : 85.83333333333333
# Train_AverageReturn : 176.04666137695312
# Train_StdReturn : 21.16610336303711
# Train_MaxReturn : 209.52781677246094
# Train_MinReturn : 109.91170501708984
# Train_AverageEpLen : 83.625
# Train_EnvstepsSoFar : 321189
# TimeSinceStart : 335.18006014823914
# Training Loss : 148.2661895751953
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 32 ************
#
# Collecting data to be used for training...
# At timestep:     10007 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 175.7087860107422
# Eval_StdReturn : 9.535837173461914
# Eval_MaxReturn : 192.1733856201172
# Eval_MinReturn : 160.35118103027344
# Eval_AverageEpLen : 84.16666666666667
# Train_AverageReturn : 166.30926513671875
# Train_StdReturn : 22.38965606689453
# Train_MaxReturn : 205.79730224609375
# Train_MinReturn : 110.10636901855469
# Train_AverageEpLen : 80.70161290322581
# Train_EnvstepsSoFar : 331196
# TimeSinceStart : 344.60279607772827
# Training Loss : 143.10853576660156
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 33 ************
#
# Collecting data to be used for training...
# At timestep:     10032 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 167.41226196289062
# Eval_StdReturn : 15.48440170288086
# Eval_MaxReturn : 192.04769897460938
# Eval_MinReturn : 140.5677032470703
# Eval_AverageEpLen : 82.6923076923077
# Train_AverageReturn : 165.17172241210938
# Train_StdReturn : 24.101377487182617
# Train_MaxReturn : 200.47596740722656
# Train_MinReturn : 102.49371337890625
# Train_AverageEpLen : 80.90322580645162
# Train_EnvstepsSoFar : 341228
# TimeSinceStart : 353.2832462787628
# Training Loss : 141.08807373046875
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 34 ************
#
# Collecting data to be used for training...
# At timestep:     10035 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 172.38087463378906
# Eval_StdReturn : 12.002298355102539
# Eval_MaxReturn : 188.1773681640625
# Eval_MinReturn : 140.95265197753906
# Eval_AverageEpLen : 86.16666666666667
# Train_AverageReturn : 168.13473510742188
# Train_StdReturn : 18.029909133911133
# Train_MaxReturn : 194.5386199951172
# Train_MinReturn : 114.49746704101562
# Train_AverageEpLen : 82.93388429752066
# Train_EnvstepsSoFar : 351263
# TimeSinceStart : 361.6378860473633
# Training Loss : 140.1724853515625
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 35 ************
#
# Collecting data to be used for training...
# At timestep:     10000 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 167.5137481689453
# Eval_StdReturn : 19.927764892578125
# Eval_MaxReturn : 185.02011108398438
# Eval_MinReturn : 104.50962829589844
# Eval_AverageEpLen : 83.58333333333333
# Train_AverageReturn : 165.6360321044922
# Train_StdReturn : 19.856325149536133
# Train_MaxReturn : 200.57455444335938
# Train_MinReturn : 98.19756317138672
# Train_AverageEpLen : 82.64462809917356
# Train_EnvstepsSoFar : 361263
# TimeSinceStart : 370.01269912719727
# Training Loss : 138.05450439453125
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 36 ************
#
# Collecting data to be used for training...
# At timestep:     10046 / 100000000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 170.2536163330078
# Eval_StdReturn : 11.946742057800293
# Eval_MaxReturn : 187.62986755371094
# Eval_MinReturn : 143.1802520751953
# Eval_AverageEpLen : 85.83333333333333
# Train_AverageReturn : 163.72372436523438
# Train_StdReturn : 20.810026168823242
# Train_MaxReturn : 185.07135009765625
# Train_MinReturn : 85.0490951538086
# Train_AverageEpLen : 82.34426229508196
# Train_EnvstepsSoFar : 371309
# TimeSinceStart : 379.4477722644806
# Training Loss : 136.44947814941406
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 37 ************
#
# Collecting data to be used for training...
# At timestep:     10014 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 173.14683532714844
# Eval_StdReturn : 2.7104744911193848
# Eval_MaxReturn : 178.82720947265625
# Eval_MinReturn : 169.31134033203125
# Eval_AverageEpLen : 87.33333333333333
# Train_AverageReturn : 160.63726806640625
# Train_StdReturn : 23.30755043029785
# Train_MaxReturn : 187.42970275878906
# Train_MinReturn : 92.18534088134766
# Train_AverageEpLen : 81.41463414634147
# Train_EnvstepsSoFar : 381323
# TimeSinceStart : 388.92434000968933
# Training Loss : 134.9484405517578
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 38 ************
#
# Collecting data to be used for training...
# At timestep:     10017 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 168.61033630371094
# Eval_StdReturn : 8.395374298095703
# Eval_MaxReturn : 175.4689483642578
# Eval_MinReturn : 143.13479614257812
# Eval_AverageEpLen : 85.75
# Train_AverageReturn : 168.5157012939453
# Train_StdReturn : 16.252948760986328
# Train_MaxReturn : 184.3837127685547
# Train_MinReturn : 66.65385437011719
# Train_AverageEpLen : 84.88983050847457
# Train_EnvstepsSoFar : 391340
# TimeSinceStart : 397.19976925849915
# Training Loss : 136.98646545410156
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 39 ************
#
# Collecting data to be used for training...
# At timestep:     10016 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 169.40463256835938
# Eval_StdReturn : 15.501174926757812
# Eval_MaxReturn : 189.49795532226562
# Eval_MinReturn : 124.57049560546875
# Eval_AverageEpLen : 85.75
# Train_AverageReturn : 168.90280151367188
# Train_StdReturn : 13.448540687561035
# Train_MaxReturn : 180.73707580566406
# Train_MinReturn : 71.76422882080078
# Train_AverageEpLen : 85.6068376068376
# Train_EnvstepsSoFar : 401356
# TimeSinceStart : 406.30945897102356
# Training Loss : 135.84303283691406
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 40 ************
#
# Collecting data to be used for training...
# At timestep:     10042 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 165.4551544189453
# Eval_StdReturn : 26.1035099029541
# Eval_MaxReturn : 195.8944091796875
# Eval_MinReturn : 101.31280517578125
# Eval_AverageEpLen : 83.15384615384616
# Train_AverageReturn : 168.64068603515625
# Train_StdReturn : 18.513586044311523
# Train_MaxReturn : 211.5153045654297
# Train_MinReturn : 97.6181640625
# Train_AverageEpLen : 85.10169491525424
# Train_EnvstepsSoFar : 411398
# TimeSinceStart : 416.6953353881836
# Training Loss : 136.972412109375
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 41 ************
#
# Collecting data to be used for training...
# At timestep:     10026 / 100001980 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 178.6451416015625
# Eval_StdReturn : 38.485145568847656
# Eval_MaxReturn : 264.5538330078125
# Eval_MinReturn : 118.61968994140625
# Eval_AverageEpLen : 88.0
# Train_AverageReturn : 174.72207641601562
# Train_StdReturn : 27.304725646972656
# Train_MaxReturn : 284.46148681640625
# Train_MinReturn : 97.73629760742188
# Train_AverageEpLen : 87.18260869565218
# Train_EnvstepsSoFar : 421424
# TimeSinceStart : 427.1178421974182
# Training Loss : 140.04266357421875
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 42 ************
#
# Collecting data to be used for training...
# At timestep:     10018 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 158.51800537109375
# Eval_StdReturn : 19.112590789794922
# Eval_MaxReturn : 180.0793914794922
# Eval_MinReturn : 120.17007446289062
# Eval_AverageEpLen : 82.76923076923077
# Train_AverageReturn : 175.90554809570312
# Train_StdReturn : 29.682640075683594
# Train_MaxReturn : 272.7505187988281
# Train_MinReturn : 107.183837890625
# Train_AverageEpLen : 87.11304347826086
# Train_EnvstepsSoFar : 431442
# TimeSinceStart : 436.6824641227722
# Training Loss : 142.00653076171875
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 43 ************
#
# Collecting data to be used for training...
# At timestep:     10022 / 10000787 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 166.6462860107422
# Eval_StdReturn : 23.687925338745117
# Eval_MaxReturn : 217.50930786132812
# Eval_MinReturn : 130.43911743164062
# Eval_AverageEpLen : 86.5
# Train_AverageReturn : 179.8680419921875
# Train_StdReturn : 35.320499420166016
# Train_MaxReturn : 287.806640625
# Train_MinReturn : 102.91567993164062
# Train_AverageEpLen : 87.91228070175438
# Train_EnvstepsSoFar : 441464
# TimeSinceStart : 447.0357151031494
# Training Loss : 144.13372802734375
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 44 ************
#
# Collecting data to be used for training...
# At timestep:     10030 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 154.8797607421875
# Eval_StdReturn : 46.942325592041016
# Eval_MaxReturn : 189.38722229003906
# Eval_MinReturn : -1.7917325496673584
# Eval_AverageEpLen : 79.07692307692308
# Train_AverageReturn : 161.80113220214844
# Train_StdReturn : 31.451339721679688
# Train_MaxReturn : 274.0237731933594
# Train_MinReturn : 2.4339327812194824
# Train_AverageEpLen : 82.89256198347107
# Train_EnvstepsSoFar : 451494
# TimeSinceStart : 455.0623230934143
# Training Loss : 134.97552490234375
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 45 ************
#
# Collecting data to be used for training...
# At timestep:     10076 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 168.03086853027344
# Eval_StdReturn : 23.781099319458008
# Eval_MaxReturn : 236.2731475830078
# Eval_MinReturn : 135.17803955078125
# Eval_AverageEpLen : 86.08333333333333
# Train_AverageReturn : 160.4141082763672
# Train_StdReturn : 33.972145080566406
# Train_MaxReturn : 289.6626892089844
# Train_MinReturn : -0.3004109859466553
# Train_AverageEpLen : 82.59016393442623
# Train_EnvstepsSoFar : 461570
# TimeSinceStart : 463.07425713539124
# Training Loss : 134.21005249023438
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 46 ************
#
# Collecting data to be used for training...
# At timestep:     10055 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 175.62464904785156
# Eval_StdReturn : 39.88570022583008
# Eval_MaxReturn : 271.4702453613281
# Eval_MinReturn : 120.26158905029297
# Eval_AverageEpLen : 86.33333333333333
# Train_AverageReturn : 166.13348388671875
# Train_StdReturn : 34.41716384887695
# Train_MaxReturn : 262.1826171875
# Train_MinReturn : -0.43360811471939087
# Train_AverageEpLen : 84.49579831932773
# Train_EnvstepsSoFar : 471625
# TimeSinceStart : 472.16321325302124
# Training Loss : 137.08843994140625
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 47 ************
#
# Collecting data to be used for training...
# At timestep:     10068 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 215.32177734375
# Eval_StdReturn : 42.40201187133789
# Eval_MaxReturn : 282.2482604980469
# Eval_MinReturn : 155.98179626464844
# Eval_AverageEpLen : 101.9
# Train_AverageReturn : 182.2766876220703
# Train_StdReturn : 34.152679443359375
# Train_MaxReturn : 274.17535400390625
# Train_MinReturn : 93.54884338378906
# Train_AverageEpLen : 89.09734513274336
# Train_EnvstepsSoFar : 481693
# TimeSinceStart : 480.1822159290314
# Training Loss : 144.4241943359375
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 48 ************
#
# Collecting data to be used for training...
# At timestep:     10070 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 192.83241271972656
# Eval_StdReturn : 42.290863037109375
# Eval_MaxReturn : 283.4764099121094
# Eval_MinReturn : 131.09742736816406
# Eval_AverageEpLen : 92.36363636363636
# Train_AverageReturn : 192.23985290527344
# Train_StdReturn : 40.09441375732422
# Train_MaxReturn : 291.8005676269531
# Train_MinReturn : 92.55563354492188
# Train_AverageEpLen : 92.38532110091744
# Train_EnvstepsSoFar : 491763
# TimeSinceStart : 488.3725531101227
# Training Loss : 149.3819580078125
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 49 ************
#
# Collecting data to be used for training...
# At timestep:     10010 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 188.44732666015625
# Eval_StdReturn : 30.741302490234375
# Eval_MaxReturn : 260.43450927734375
# Eval_MinReturn : 148.68008422851562
# Eval_AverageEpLen : 91.75
# Train_AverageReturn : 193.5689239501953
# Train_StdReturn : 37.77779006958008
# Train_MaxReturn : 282.51776123046875
# Train_MinReturn : 122.88201141357422
# Train_AverageEpLen : 93.55140186915888
# Train_EnvstepsSoFar : 501773
# TimeSinceStart : 496.3128960132599
# Training Loss : 148.17474365234375
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 50 ************
#
# Collecting data to be used for training...
# At timestep:     10004 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 197.23081970214844
# Eval_StdReturn : 36.4016227722168
# Eval_MaxReturn : 260.52471923828125
# Eval_MinReturn : 160.49957275390625
# Eval_AverageEpLen : 94.72727272727273
# Train_AverageReturn : 200.26141357421875
# Train_StdReturn : 39.003143310546875
# Train_MaxReturn : 291.39013671875
# Train_MinReturn : 123.15460205078125
# Train_AverageEpLen : 96.1923076923077
# Train_EnvstepsSoFar : 511777
# TimeSinceStart : 505.4318883419037
# Training Loss : 150.64447021484375
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 51 ************
#
# Collecting data to be used for training...
# At timestep:     10050 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 196.86212158203125
# Eval_StdReturn : 41.71299743652344
# Eval_MaxReturn : 296.29681396484375
# Eval_MinReturn : 155.27737426757812
# Eval_AverageEpLen : 96.45454545454545
# Train_AverageReturn : 203.2556915283203
# Train_StdReturn : 49.915653228759766
# Train_MaxReturn : 397.8306884765625
# Train_MinReturn : 145.60975646972656
# Train_AverageEpLen : 97.57281553398059
# Train_EnvstepsSoFar : 521827
# TimeSinceStart : 514.2296161651611
# Training Loss : 151.52407836914062
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 52 ************
#
# Collecting data to be used for training...
# At timestep:     10111 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 195.34744262695312
# Eval_StdReturn : 43.61200714111328
# Eval_MaxReturn : 320.41119384765625
# Eval_MinReturn : 169.71563720703125
# Eval_AverageEpLen : 101.0
# Train_AverageReturn : 207.77003479003906
# Train_StdReturn : 53.07792663574219
# Train_MaxReturn : 394.1143798828125
# Train_MinReturn : 139.56851196289062
# Train_AverageEpLen : 100.10891089108911
# Train_EnvstepsSoFar : 531938
# TimeSinceStart : 523.6739621162415
# Training Loss : 151.135498046875
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 53 ************
#
# Collecting data to be used for training...
# At timestep:     10026 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 201.01480102539062
# Eval_StdReturn : 38.82672119140625
# Eval_MaxReturn : 288.2696533203125
# Eval_MinReturn : 170.31442260742188
# Eval_AverageEpLen : 102.3
# Train_AverageReturn : 211.86871337890625
# Train_StdReturn : 69.4976806640625
# Train_MaxReturn : 438.63665771484375
# Train_MinReturn : 164.36170959472656
# Train_AverageEpLen : 100.26
# Train_EnvstepsSoFar : 541964
# TimeSinceStart : 532.6597230434418
# Training Loss : 154.62570190429688
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 54 ************
#
# Collecting data to be used for training...
# At timestep:     10025 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 237.13296508789062
# Eval_StdReturn : 73.87120056152344
# Eval_MaxReturn : 411.8139953613281
# Eval_MinReturn : 171.1061553955078
# Eval_AverageEpLen : 108.6
# Train_AverageReturn : 212.01499938964844
# Train_StdReturn : 62.79084777832031
# Train_MaxReturn : 385.8988342285156
# Train_MinReturn : 148.89413452148438
# Train_AverageEpLen : 101.26262626262626
# Train_EnvstepsSoFar : 551989
# TimeSinceStart : 542.4724371433258
# Training Loss : 153.42860412597656
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 55 ************
#
# Collecting data to be used for training...
# At timestep:     10015 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 201.96621704101562
# Eval_StdReturn : 48.78855514526367
# Eval_MaxReturn : 288.8631591796875
# Eval_MinReturn : 138.1765899658203
# Eval_AverageEpLen : 100.4
# Train_AverageReturn : 229.67051696777344
# Train_StdReturn : 83.52855682373047
# Train_MaxReturn : 516.6126098632812
# Train_MinReturn : 150.03390502929688
# Train_AverageEpLen : 106.54255319148936
# Train_EnvstepsSoFar : 562004
# TimeSinceStart : 550.2073972225189
# Training Loss : 160.0828399658203
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 56 ************
#
# Collecting data to be used for training...
# At timestep:     10141 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 184.4468994140625
# Eval_StdReturn : 72.87672424316406
# Eval_MaxReturn : 335.3495788574219
# Eval_MinReturn : 73.2235336303711
# Eval_AverageEpLen : 89.0
# Train_AverageReturn : 235.8944091796875
# Train_StdReturn : 89.69985961914062
# Train_MaxReturn : 562.5587158203125
# Train_MinReturn : 132.01296997070312
# Train_AverageEpLen : 110.22826086956522
# Train_EnvstepsSoFar : 572145
# TimeSinceStart : 557.9174909591675
# Training Loss : 160.02825927734375
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 57 ************
#
# Collecting data to be used for training...
# At timestep:     10133 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 298.5106506347656
# Eval_StdReturn : 119.34595489501953
# Eval_MaxReturn : 492.3965148925781
# Eval_MinReturn : 156.9495391845703
# Eval_AverageEpLen : 134.125
# Train_AverageReturn : 261.0655822753906
# Train_StdReturn : 98.94026947021484
# Train_MaxReturn : 491.1505432128906
# Train_MinReturn : 133.78707885742188
# Train_AverageEpLen : 119.21176470588236
# Train_EnvstepsSoFar : 582278
# TimeSinceStart : 565.7067332267761
# Training Loss : 166.49191284179688
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 58 ************
#
# Collecting data to be used for training...
# At timestep:     10042 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 243.6387176513672
# Eval_StdReturn : 104.46456909179688
# Eval_MaxReturn : 417.9349365234375
# Eval_MinReturn : 128.63047790527344
# Eval_AverageEpLen : 107.9
# Train_AverageReturn : 234.11611938476562
# Train_StdReturn : 104.9464111328125
# Train_MaxReturn : 556.3062744140625
# Train_MinReturn : 10.190001487731934
# Train_AverageEpLen : 109.15217391304348
# Train_EnvstepsSoFar : 592320
# TimeSinceStart : 573.5102281570435
# Training Loss : 160.89077758789062
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 59 ************
#
# Collecting data to be used for training...
# At timestep:     10041 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 218.5375213623047
# Eval_StdReturn : 104.01510620117188
# Eval_MaxReturn : 413.14141845703125
# Eval_MinReturn : 124.60209655761719
# Eval_AverageEpLen : 104.4
# Train_AverageReturn : 263.2044982910156
# Train_StdReturn : 122.4218521118164
# Train_MaxReturn : 556.3464965820312
# Train_MinReturn : 75.39466857910156
# Train_AverageEpLen : 118.12941176470588
# Train_EnvstepsSoFar : 602361
# TimeSinceStart : 581.14182305336
# Training Loss : 169.59075927734375
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 60 ************
#
# Collecting data to be used for training...
# At timestep:     10007 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 238.0019073486328
# Eval_StdReturn : 104.4962387084961
# Eval_MaxReturn : 423.69146728515625
# Eval_MinReturn : 78.21158599853516
# Eval_AverageEpLen : 103.8
# Train_AverageReturn : 254.91001892089844
# Train_StdReturn : 129.70188903808594
# Train_MaxReturn : 569.720703125
# Train_MinReturn : -1.4037420749664307
# Train_AverageEpLen : 115.02298850574712
# Train_EnvstepsSoFar : 612368
# TimeSinceStart : 588.735481262207
# Training Loss : 168.80027770996094
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 61 ************
#
# Collecting data to be used for training...
# At timestep:     10062 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 296.13421630859375
# Eval_StdReturn : 130.60028076171875
# Eval_MaxReturn : 421.150146484375
# Eval_MinReturn : -0.8889772891998291
# Eval_AverageEpLen : 117.55555555555556
# Train_AverageReturn : 255.52296447753906
# Train_StdReturn : 115.29725646972656
# Train_MaxReturn : 528.4344482421875
# Train_MinReturn : 76.93106079101562
# Train_AverageEpLen : 111.8
# Train_EnvstepsSoFar : 622430
# TimeSinceStart : 596.4100561141968
# Training Loss : 174.3254852294922
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 62 ************
#
# Collecting data to be used for training...
# At timestep:     10121 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 324.8786315917969
# Eval_StdReturn : 128.55435180664062
# Eval_MaxReturn : 436.34063720703125
# Eval_MinReturn : 1.8598467111587524
# Eval_AverageEpLen : 124.66666666666667
# Train_AverageReturn : 309.3305358886719
# Train_StdReturn : 104.04866790771484
# Train_MaxReturn : 504.2844543457031
# Train_MinReturn : -1.3611690998077393
# Train_AverageEpLen : 128.1139240506329
# Train_EnvstepsSoFar : 632551
# TimeSinceStart : 604.1388461589813
# Training Loss : 189.2913360595703
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 63 ************
#
# Collecting data to be used for training...
# At timestep:     10025 / 10000
# Training agent...
#
# ...
# TimeSinceStart : 695.5836148262024
# Training Loss : 133.49815368652344
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 79 ************
#
# Collecting data to be used for training...
# At timestep:     10011 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 143.9185333251953
# Eval_StdReturn : 37.63010787963867
# Eval_MaxReturn : 167.9239959716797
# Eval_MinReturn : 22.52664566040039
# Eval_AverageEpLen : 75.57142857142857
# Train_AverageReturn : 135.91793823242188
# Train_StdReturn : 46.637725830078125
# Train_MaxReturn : 171.6309051513672
# Train_MinReturn : 16.941625595092773
# Train_AverageEpLen : 71.0
# Train_EnvstepsSoFar : 803116
# TimeSinceStart : 703.3450908660889
# Training Loss : 127.97224426269531
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 80 ************
#
# Collecting data to be used for training...
# At timestep:     10072 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 136.13180541992188
# Eval_StdReturn : 57.55028533935547
# Eval_MaxReturn : 168.86363220214844
# Eval_MinReturn : 20.89875030517578
# Eval_AverageEpLen : 70.26666666666667
# Train_AverageReturn : 143.41915893554688
# Train_StdReturn : 39.6572151184082
# Train_MaxReturn : 172.37501525878906
# Train_MinReturn : 18.28086280822754
# Train_AverageEpLen : 74.60740740740741
# Train_EnvstepsSoFar : 813188
# TimeSinceStart : 711.1419777870178
# Training Loss : 130.30686950683594
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 81 ************
#
# Collecting data to be used for training...
# At timestep:     10014 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 167.66433715820312
# Eval_StdReturn : 2.0353713035583496
# Eval_MaxReturn : 172.178955078125
# Eval_MinReturn : 163.22933959960938
# Eval_AverageEpLen : 83.5
# Train_AverageReturn : 163.89215087890625
# Train_StdReturn : 14.240259170532227
# Train_MaxReturn : 171.91603088378906
# Train_MinReturn : 21.260412216186523
# Train_AverageEpLen : 82.7603305785124
# Train_EnvstepsSoFar : 823202
# TimeSinceStart : 718.854514837265
# Training Loss : 136.64552307128906
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 82 ************
#
# Collecting data to be used for training...
# At timestep:     10064 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 170.9145965576172
# Eval_StdReturn : 1.74998140335083
# Eval_MaxReturn : 173.64385986328125
# Eval_MinReturn : 168.2978057861328
# Eval_AverageEpLen : 84.41666666666667
# Train_AverageReturn : 168.10446166992188
# Train_StdReturn : 2.500365972518921
# Train_MaxReturn : 182.97885131835938
# Train_MinReturn : 162.23487854003906
# Train_AverageEpLen : 83.86666666666666
# Train_EnvstepsSoFar : 833266
# TimeSinceStart : 726.6233077049255
# Training Loss : 138.00076293945312
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 83 ************
#
# Collecting data to be used for training...
# At timestep:     10078 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 101.23007202148438
# Eval_StdReturn : 43.03321838378906
# Eval_MaxReturn : 175.40464782714844
# Eval_MinReturn : 55.69706344604492
# Eval_AverageEpLen : 52.89473684210526
# Train_AverageReturn : 164.3084259033203
# Train_StdReturn : 23.312665939331055
# Train_MaxReturn : 177.3917236328125
# Train_MinReturn : 69.98381042480469
# Train_AverageEpLen : 81.2741935483871
# Train_EnvstepsSoFar : 843344
# TimeSinceStart : 734.4604799747467
# Training Loss : 138.2479705810547
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 84 ************
#
# Collecting data to be used for training...
# At timestep:     10038 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 69.5323486328125
# Eval_StdReturn : 22.824356079101562
# Eval_MaxReturn : 150.9341583251953
# Eval_MinReturn : 53.82355499267578
# Eval_AverageEpLen : 38.57692307692308
# Train_AverageReturn : 91.5237045288086
# Train_StdReturn : 39.22663497924805
# Train_MaxReturn : 176.0366973876953
# Train_MinReturn : 54.50299835205078
# Train_AverageEpLen : 48.728155339805824
# Train_EnvstepsSoFar : 853382
# TimeSinceStart : 742.3849258422852
# Training Loss : 109.99945068359375
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 85 ************
#
# Collecting data to be used for training...
# At timestep:     10056 / 10000000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 59.21781921386719
# Eval_StdReturn : 4.813748836517334
# Eval_MaxReturn : 72.10829162597656
# Eval_MinReturn : 49.19704055786133
# Eval_AverageEpLen : 33.5
# Train_AverageReturn : 66.50203704833984
# Train_StdReturn : 15.629477500915527
# Train_MaxReturn : 153.510498046875
# Train_MinReturn : 50.825225830078125
# Train_AverageEpLen : 37.24444444444445
# Train_EnvstepsSoFar : 863438
# TimeSinceStart : 750.4565958976746
# Training Loss : 91.58983612060547
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 86 ************
#
# Collecting data to be used for training...
# At timestep:     10021 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 60.42292022705078
# Eval_StdReturn : 5.351215839385986
# Eval_MaxReturn : 71.07717895507812
# Eval_MinReturn : 50.9275016784668
# Eval_AverageEpLen : 34.4
# Train_AverageReturn : 60.65076446533203
# Train_StdReturn : 7.667541980743408
# Train_MaxReturn : 145.97854614257812
# Train_MinReturn : 48.97329330444336
# Train_AverageEpLen : 34.31849315068493
# Train_EnvstepsSoFar : 873459
# TimeSinceStart : 758.4447586536407
# Training Loss : 86.89322662353516
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 87 ************
#
# Collecting data to be used for training...
# At timestep:     10005 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 62.310691833496094
# Eval_StdReturn : 13.986957550048828
# Eval_MaxReturn : 131.86880493164062
# Eval_MinReturn : 50.534942626953125
# Eval_AverageEpLen : 35.241379310344826
# Train_AverageReturn : 60.51645278930664
# Train_StdReturn : 7.2229390144348145
# Train_MaxReturn : 140.77174377441406
# Train_MinReturn : 49.49882888793945
# Train_AverageEpLen : 34.263698630136986
# Train_EnvstepsSoFar : 883464
# TimeSinceStart : 766.3526196479797
# Training Loss : 85.97334289550781
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 88 ************
#
# Collecting data to be used for training...
# At timestep:     10021 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 64.03455352783203
# Eval_StdReturn : 5.665984630584717
# Eval_MaxReturn : 80.89644622802734
# Eval_MinReturn : 54.41067886352539
# Eval_AverageEpLen : 36.32142857142857
# Train_AverageReturn : 61.29328155517578
# Train_StdReturn : 8.051817893981934
# Train_MaxReturn : 135.92529296875
# Train_MinReturn : 48.80262756347656
# Train_AverageEpLen : 34.795138888888886
# Train_EnvstepsSoFar : 893485
# TimeSinceStart : 774.4155957698822
# Training Loss : 86.25074768066406
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 89 ************
#
# Collecting data to be used for training...
# At timestep:     10029 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 75.19499206542969
# Eval_StdReturn : 20.847070693969727
# Eval_MaxReturn : 142.4010772705078
# Eval_MinReturn : 57.113746643066406
# Eval_AverageEpLen : 42.166666666666664
# Train_AverageReturn : 63.891090393066406
# Train_StdReturn : 9.605169296264648
# Train_MaxReturn : 139.54022216796875
# Train_MinReturn : 51.23187255859375
# Train_AverageEpLen : 36.2057761732852
# Train_EnvstepsSoFar : 903514
# TimeSinceStart : 782.3225977420807
# Training Loss : 88.35356140136719
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 90 ************
#
# Collecting data to be used for training...
# At timestep:     10030 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 108.03983306884766
# Eval_StdReturn : 31.637264251708984
# Eval_MaxReturn : 152.58843994140625
# Eval_MinReturn : 66.69367980957031
# Eval_AverageEpLen : 57.888888888888886
# Train_AverageReturn : 72.16944122314453
# Train_StdReturn : 16.28542137145996
# Train_MaxReturn : 144.0567626953125
# Train_MinReturn : 51.01518630981445
# Train_AverageEpLen : 40.607287449392715
# Train_EnvstepsSoFar : 913544
# TimeSinceStart : 790.4626908302307
# Training Loss : 94.1479263305664
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 91 ************
#
# Collecting data to be used for training...
# At timestep:     10015 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 165.51609802246094
# Eval_StdReturn : 8.20417594909668
# Eval_MaxReturn : 172.87257385253906
# Eval_MinReturn : 147.6426239013672
# Eval_AverageEpLen : 82.6923076923077
# Train_AverageReturn : 106.17247009277344
# Train_StdReturn : 35.935821533203125
# Train_MaxReturn : 171.92079162597656
# Train_MinReturn : 61.12934875488281
# Train_AverageEpLen : 56.5819209039548
# Train_EnvstepsSoFar : 923559
# TimeSinceStart : 799.401252746582
# Training Loss : 114.45307159423828
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 92 ************
#
# Collecting data to be used for training...
# At timestep:     10027 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 154.65127563476562
# Eval_StdReturn : 32.87770462036133
# Eval_MaxReturn : 173.072509765625
# Eval_MinReturn : 76.5289535522461
# Eval_AverageEpLen : 77.15384615384616
# Train_AverageReturn : 161.4577178955078
# Train_StdReturn : 19.376829147338867
# Train_MaxReturn : 175.2508544921875
# Train_MinReturn : 78.01152038574219
# Train_AverageEpLen : 80.216
# Train_EnvstepsSoFar : 933586
# TimeSinceStart : 808.9511528015137
# Training Loss : 135.67074584960938
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 93 ************
#
# Collecting data to be used for training...
# At timestep:     10021 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 170.40516662597656
# Eval_StdReturn : 2.7269980907440186
# Eval_MaxReturn : 175.26783752441406
# Eval_MinReturn : 166.8521728515625
# Eval_AverageEpLen : 83.83333333333333
# Train_AverageReturn : 166.95849609375
# Train_StdReturn : 14.360748291015625
# Train_MaxReturn : 179.45968627929688
# Train_MinReturn : 72.7079086303711
# Train_AverageEpLen : 82.81818181818181
# Train_EnvstepsSoFar : 943607
# TimeSinceStart : 817.8571028709412
# Training Loss : 137.17333984375
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 94 ************
#
# Collecting data to be used for training...
# At timestep:     10019 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 168.59625244140625
# Eval_StdReturn : 2.3840017318725586
# Eval_MaxReturn : 174.58114624023438
# Eval_MinReturn : 165.28131103515625
# Eval_AverageEpLen : 84.0
# Train_AverageReturn : 169.00680541992188
# Train_StdReturn : 8.732583999633789
# Train_MaxReturn : 178.58416748046875
# Train_MinReturn : 79.93155670166016
# Train_AverageEpLen : 83.49166666666666
# Train_EnvstepsSoFar : 953626
# TimeSinceStart : 826.1488556861877
# Training Loss : 138.5232391357422
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 95 ************
#
# Collecting data to be used for training...
# At timestep:     10013 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 168.08497619628906
# Eval_StdReturn : 2.3400485515594482
# Eval_MaxReturn : 173.1139678955078
# Eval_MinReturn : 162.7082061767578
# Eval_AverageEpLen : 83.66666666666667
# Train_AverageReturn : 168.78688049316406
# Train_StdReturn : 2.1391289234161377
# Train_MaxReturn : 174.292236328125
# Train_MinReturn : 164.59959411621094
# Train_AverageEpLen : 84.14285714285714
# Train_EnvstepsSoFar : 963639
# TimeSinceStart : 833.8797876834869
# Training Loss : 135.89122009277344
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 96 ************
#
# Collecting data to be used for training...
# At timestep:     10005 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 167.837646484375
# Eval_StdReturn : 1.7639062404632568
# Eval_MaxReturn : 170.69151306152344
# Eval_MinReturn : 164.3955078125
# Eval_AverageEpLen : 84.16666666666667
# Train_AverageReturn : 167.62252807617188
# Train_StdReturn : 2.249725341796875
# Train_MaxReturn : 174.4713897705078
# Train_MinReturn : 162.53692626953125
# Train_AverageEpLen : 84.07563025210084
# Train_EnvstepsSoFar : 973644
# TimeSinceStart : 841.5974938869476
# Training Loss : 136.41322326660156
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 97 ************
#
# Collecting data to be used for training...
# At timestep:     10006 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 166.9801483154297
# Eval_StdReturn : 1.914033055305481
# Eval_MaxReturn : 169.52749633789062
# Eval_MinReturn : 163.375244140625
# Eval_AverageEpLen : 83.58333333333333
# Train_AverageReturn : 166.77931213378906
# Train_StdReturn : 2.3248870372772217
# Train_MaxReturn : 174.1495819091797
# Train_MinReturn : 161.65708923339844
# Train_AverageEpLen : 84.08403361344538
# Train_EnvstepsSoFar : 983650
# TimeSinceStart : 849.3052098751068
# Training Loss : 135.0792236328125
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 98 ************
#
# Collecting data to be used for training...
# At timestep:     10045 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 167.998291015625
# Eval_StdReturn : 2.0268592834472656
# Eval_MaxReturn : 171.5326690673828
# Eval_MinReturn : 165.6287841796875
# Eval_AverageEpLen : 83.23076923076923
# Train_AverageReturn : 166.3544921875
# Train_StdReturn : 2.735167980194092
# Train_MaxReturn : 177.2232208251953
# Train_MinReturn : 161.87759399414062
# Train_AverageEpLen : 83.70833333333333
# Train_EnvstepsSoFar : 993695
# TimeSinceStart : 857.1282157897949
# Training Loss : 134.95668029785156
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 99 ************
#
# Collecting data to be used for training...
# At timestep:     10039 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 167.35153198242188
# Eval_StdReturn : 2.874107599258423
# Eval_MaxReturn : 173.02896118164062
# Eval_MinReturn : 163.46142578125
# Eval_AverageEpLen : 83.33333333333333
# Train_AverageReturn : 166.4163360595703
# Train_StdReturn : 2.6388750076293945
# Train_MaxReturn : 177.2436065673828
# Train_MinReturn : 161.37290954589844
# Train_AverageEpLen : 83.65833333333333
# Train_EnvstepsSoFar : 1003734
# TimeSinceStart : 864.9221980571747
# Training Loss : 135.3692169189453
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...

# %%
### Visualize Policy Gradient results on Hopper
# %load_ext tensorboard
# %tensorboard --logdir logs/policy_gradient/Hopper
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
#       <iframe id="tensorboard-frame-9d0e7c3c009b3b62" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-9d0e7c3c009b3b62");
#           const url = new URL("/", window.location);
#           const port = 6010;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ## Variance Reduction with a Value Function Baseline
# We can further reduce the policy gradient variance by including state-dependent baselines. In this section, we will train a value function network to predict the value of the policy at a state, then use the value function as a baseline by subtracting it from our reward-to-go estimate.
#
# Implement the value function baseline loss in the update method of the MLPPolicyPG class in <code>policies/MLP_policy.py</code>.

# %%
# Test value function gradient
torch.manual_seed(0)
ac_dim = 2
ob_dim = 3
batch_size = 5

policy = MLPPolicyPG(
            ac_dim=ac_dim,
            ob_dim=ob_dim,
            n_layers=1,
            size=2,
            learning_rate=0.25,
            nn_baseline=True)

np.random.seed(0)
obs = np.random.normal(size=(batch_size, ob_dim))
acts = np.random.normal(size=(batch_size, ac_dim))
advs = 1000 * np.random.normal(size=(batch_size,))
qvals = advs

first_weight_before = np.array(ptu.to_numpy(next(policy.baseline.parameters())))
print("Weight before update", first_weight_before)

for i in range(5):
    loss = policy.update(obs, acts, advs, qvals=qvals)['Baseline Loss']

print(loss)
expected_loss = 0.925361
loss_error = rel_error(loss, expected_loss)
print("Loss Error", loss_error, "should be on the order of 1e-6 or lower")

first_weight_after = ptu.to_numpy(next(policy.baseline.parameters()))
print('Weight after update', first_weight_after)

weight_change = first_weight_after - first_weight_before
print("Change in weights", weight_change)

expected_change = np.array([[ 0.38988823,  0.70297027,  0.2609921 ],
                            [-1.0340402,  -0.84166795,  0.7254925 ]])
updated_weight_error = rel_error(weight_change, expected_change)
print("Weight Update Error", updated_weight_error, "should be on the order of 1e-6 or lower")
# Out:
# Weight before update [[-0.23799711  0.0213871   0.22824687]
#  [ 0.34642333 -0.39140946 -0.25141457]]
# 0.92536086
# Loss Error 7.648885767117787e-08 should be on the order of 1e-6 or lower
# Weight after update [[ 0.15189107  0.72435737  0.48923904]
#  [-0.68761694 -1.2330772   0.474078  ]]
# Change in weights [[ 0.38988817  0.70297027  0.26099217]
#  [-1.0340402  -0.8416677   0.7254926 ]]
# Weight Update Error 1.4154350421085664e-07 should be on the order of 1e-6 or lower

# %% [markdown]
# In the estimate_advantage function in <code>agents/pg_agent.py</code>, fill out the advantage estimate using the baseline and test your implementation below.

# %%
### Test return computation
pg_args = dict(pg_base_args_dict)

env_str = 'CartPole'
pg_args['env_name'] = '{}-v0'.format(env_str)
pg_args['nn_baseline'] = True
pgtrainer = PG_Trainer(pg_args)
pgagent = pgtrainer.rl_trainer.agent

obs_dim = 4
N = 10
np.random.seed(0)
obs = np.random.normal(size=(N, obs_dim))
qs = np.random.normal(size=N)

baseline_advantages = pgagent.estimate_advantage(obs, qs)
expected_advantages = np.array([-0.44662586, -0.89629588, -1.14574752,  2.43957172, -0.06601728,
       -0.00501807, -0.74720337,  1.27468092, -1.20184486,  0.25312274])

advantage_error = rel_error(expected_advantages, baseline_advantages)
print("Advantage error", advantage_error, "should be on the order of 1e-6 or lower")
# Out:
# ########################
# logging outputs to  test
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# CartPole-v0
# Advantage error 3.6888988344448045e-07 should be on the order of 1e-6 or lower

# %% [markdown]
# ## Train your policies!
# In this section, we will train our policies using the reward-to-go estimator and learning a value function baseline. On Hopper, you should see your methods get over 300 rewards consistently, and sometimes over 400. Returns will tend to oscillate during training. You should also see that using a value function baseline greatly improves performance over our earlier experiments without it.

# %%
pg_args = dict(pg_base_args_dict)

env_str = 'Hopper'
pg_args['env_name'] = '{}-v2'.format(env_str)
pg_args['learning_rate'] = 0.01
pg_args['reward_to_go'] = True
pg_args['nn_baseline'] = True
pg_args['batch_size'] = 10000
pg_args['train_batch_size'] = 10000
pg_args['n_iter'] = 100

# Delete all previous logs
remove_folder('logs/policy_gradient/{}/with_baseline/'.format(env_str))

for seed in range(3):
    print("Running policy gradient experiment with seed", seed)
    pg_args['seed'] = seed
    pg_args['logdir'] = 'logs/policy_gradient/{}/with_baseline/seed{}'.format(env_str, seed)
    pgtrainer = PG_Trainer(pg_args)
    pgtrainer.run_training_loop()
# Out:
# Folder logs/policy_gradient/Hopper/with_baseline/ does not exist yet. No old results to delete
# Running policy gradient experiment with seed 0
# ########################
# logging outputs to  logs/policy_gradient/Hopper/with_baseline/seed0
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# Hopper-v2
#
#
# ********** Iteration 0 ************
#
# Collecting data to be used for training...
# At timestep:     10015 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 89.84849548339844
# Eval_StdReturn : 33.547855377197266
# Eval_MaxReturn : 155.4940185546875
# Eval_MinReturn : 29.384666442871094
# Eval_AverageEpLen : 58.5
# Train_AverageReturn : 9.403343200683594
# Train_StdReturn : 4.718483924865723
# Train_MaxReturn : 46.106727600097656
# Train_MinReturn : 2.846346378326416
# Train_AverageEpLen : 12.939276485788113
# Train_EnvstepsSoFar : 10015
# TimeSinceStart : 11.215137004852295
# Training Loss : 3.9577796459198
# Baseline Loss : 1.0592422485351562
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 1 ************
#
# Collecting data to be used for training...
# At timestep:     10034 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 110.52185821533203
# Eval_StdReturn : 52.784881591796875
# Eval_MaxReturn : 207.3875732421875
# Eval_MinReturn : 49.420433044433594
# Eval_AverageEpLen : 59.111111111111114
# Train_AverageReturn : 97.38761138916016
# Train_StdReturn : 51.84263610839844
# Train_MaxReturn : 263.6323547363281
# Train_MinReturn : 5.4555816650390625
# Train_AverageEpLen : 60.44578313253012
# Train_EnvstepsSoFar : 20049
# TimeSinceStart : 22.9211368560791
# Training Loss : -14.395066261291504
# Baseline Loss : 1.2495510578155518
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 2 ************
#
# Collecting data to be used for training...
# At timestep:     10024 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 154.86862182617188
# Eval_StdReturn : 59.431907653808594
# Eval_MaxReturn : 214.60768127441406
# Eval_MinReturn : 57.70475387573242
# Eval_AverageEpLen : 73.57142857142857
# Train_AverageReturn : 109.16539764404297
# Train_StdReturn : 44.80699920654297
# Train_MaxReturn : 247.84918212890625
# Train_MinReturn : 54.69504165649414
# Train_AverageEpLen : 57.94219653179191
# Train_EnvstepsSoFar : 30073
# TimeSinceStart : 39.5045907497406
# Training Loss : -8.466615676879883
# Baseline Loss : 1.0519475936889648
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 3 ************
#
# Collecting data to be used for training...
# At timestep:     10028 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 190.28428649902344
# Eval_StdReturn : 16.108142852783203
# Eval_MaxReturn : 207.78518676757812
# Eval_MinReturn : 144.90432739257812
# Eval_AverageEpLen : 85.91666666666667
# Train_AverageReturn : 138.61468505859375
# Train_StdReturn : 58.831478118896484
# Train_MaxReturn : 219.96075439453125
# Train_MinReturn : 20.248825073242188
# Train_AverageEpLen : 68.21768707482993
# Train_EnvstepsSoFar : 40101
# TimeSinceStart : 53.022629737854004
# Training Loss : 0.04973374679684639
# Baseline Loss : 1.0686314105987549
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 4 ************
#
# Collecting data to be used for training...
# At timestep:     10081 / 100003585 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 181.00526428222656
# Eval_StdReturn : 21.687156677246094
# Eval_MaxReturn : 207.7041015625
# Eval_MinReturn : 136.44358825683594
# Eval_AverageEpLen : 82.6923076923077
# Train_AverageReturn : 186.64569091796875
# Train_StdReturn : 29.183874130249023
# Train_MaxReturn : 214.93048095703125
# Train_MinReturn : 45.535240173339844
# Train_AverageEpLen : 84.71428571428571
# Train_EnvstepsSoFar : 50182
# TimeSinceStart : 64.33270502090454
# Training Loss : 8.81011962890625
# Baseline Loss : 1.0044747591018677
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 5 ************
#
# Collecting data to be used for training...
# At timestep:     10022 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 177.49363708496094
# Eval_StdReturn : 18.7716007232666
# Eval_MaxReturn : 210.1418914794922
# Eval_MinReturn : 144.29176330566406
# Eval_AverageEpLen : 81.0
# Train_AverageReturn : 188.60247802734375
# Train_StdReturn : 17.28499984741211
# Train_MaxReturn : 213.0032958984375
# Train_MinReturn : 127.2325439453125
# Train_AverageEpLen : 84.9322033898305
# Train_EnvstepsSoFar : 60204
# TimeSinceStart : 74.89191699028015
# Training Loss : 7.446451187133789
# Baseline Loss : 0.9286069869995117
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 6 ************
#
# Collecting data to be used for training...
# At timestep:     10002 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 185.8250274658203
# Eval_StdReturn : 18.03797721862793
# Eval_MaxReturn : 208.41139221191406
# Eval_MinReturn : 150.87249755859375
# Eval_AverageEpLen : 83.66666666666667
# Train_AverageReturn : 182.4478759765625
# Train_StdReturn : 26.729183197021484
# Train_MaxReturn : 221.31520080566406
# Train_MinReturn : 22.284727096557617
# Train_AverageEpLen : 82.66115702479338
# Train_EnvstepsSoFar : 70206
# TimeSinceStart : 85.58612203598022
# Training Loss : 2.8451578617095947
# Baseline Loss : 0.8878705501556396
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 7 ************
#
# Collecting data to be used for training...
# At timestep:     10031 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 195.0240936279297
# Eval_StdReturn : 8.210872650146484
# Eval_MaxReturn : 205.4698486328125
# Eval_MinReturn : 181.4990234375
# Eval_AverageEpLen : 87.16666666666667
# Train_AverageReturn : 186.92764282226562
# Train_StdReturn : 20.288211822509766
# Train_MaxReturn : 215.34487915039062
# Train_MinReturn : 101.64033508300781
# Train_AverageEpLen : 84.29411764705883
# Train_EnvstepsSoFar : 80237
# TimeSinceStart : 95.67747783660889
# Training Loss : 0.009700663387775421
# Baseline Loss : 0.8594198822975159
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 8 ************
#
# Collecting data to be used for training...
# At timestep:     10016 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 190.7256317138672
# Eval_StdReturn : 7.469960689544678
# Eval_MaxReturn : 201.5693817138672
# Eval_MinReturn : 176.16087341308594
# Eval_AverageEpLen : 86.25
# Train_AverageReturn : 191.70248413085938
# Train_StdReturn : 8.85873794555664
# Train_MaxReturn : 210.21084594726562
# Train_MinReturn : 173.30130004882812
# Train_AverageEpLen : 86.34482758620689
# Train_EnvstepsSoFar : 90253
# TimeSinceStart : 107.6881537437439
# Training Loss : -0.851201057434082
# Baseline Loss : 0.8118976950645447
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 9 ************
#
# Collecting data to be used for training...
# At timestep:     10084 / 100000000 4840 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 186.8950653076172
# Eval_StdReturn : 6.517127990722656
# Eval_MaxReturn : 202.5568084716797
# Eval_MinReturn : 177.33444213867188
# Eval_AverageEpLen : 84.91666666666667
# Train_AverageReturn : 190.42323303222656
# Train_StdReturn : 9.880912780761719
# Train_MaxReturn : 212.63162231445312
# Train_MinReturn : 144.91021728515625
# Train_AverageEpLen : 86.1880341880342
# Train_EnvstepsSoFar : 100337
# TimeSinceStart : 117.66964673995972
# Training Loss : 1.376444697380066
# Baseline Loss : 0.7493189573287964
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 10 ************
#
# Collecting data to be used for training...
# At timestep:     10062 / 10000 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 184.14830017089844
# Eval_StdReturn : 7.827200889587402
# Eval_MaxReturn : 202.0488739013672
# Eval_MinReturn : 174.2275390625
# Eval_AverageEpLen : 84.66666666666667
# Train_AverageReturn : 187.31427001953125
# Train_StdReturn : 7.629891872406006
# Train_MaxReturn : 209.68017578125
# Train_MinReturn : 170.99754333496094
# Train_AverageEpLen : 85.27118644067797
# Train_EnvstepsSoFar : 110399
# TimeSinceStart : 126.84771299362183
# Training Loss : 3.736957311630249
# Baseline Loss : 0.697478711605072
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 11 ************
#
# Collecting data to be used for training...
# At timestep:     10047 / 10000 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 179.7754669189453
# Eval_StdReturn : 6.320042610168457
# Eval_MaxReturn : 189.43637084960938
# Eval_MinReturn : 169.06674194335938
# Eval_AverageEpLen : 85.0
# Train_AverageReturn : 182.4474334716797
# Train_StdReturn : 7.454545974731445
# Train_MaxReturn : 201.3654327392578
# Train_MinReturn : 168.42466735839844
# Train_AverageEpLen : 84.42857142857143
# Train_EnvstepsSoFar : 120446
# TimeSinceStart : 136.70471096038818
# Training Loss : 2.9177544116973877
# Baseline Loss : 0.6453222036361694
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 12 ************
#
# Collecting data to be used for training...
# At timestep:     10067 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 185.88938903808594
# Eval_StdReturn : 6.465317726135254
# Eval_MaxReturn : 195.34878540039062
# Eval_MinReturn : 175.22589111328125
# Eval_AverageEpLen : 86.33333333333333
# Train_AverageReturn : 181.14501953125
# Train_StdReturn : 6.915023326873779
# Train_MaxReturn : 202.7167205810547
# Train_MinReturn : 159.00881958007812
# Train_AverageEpLen : 84.59663865546219
# Train_EnvstepsSoFar : 130513
# TimeSinceStart : 145.28763890266418
# Training Loss : 0.23087559640407562
# Baseline Loss : 0.620875895023346
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 13 ************
#
# Collecting data to be used for training...
# At timestep:     10033 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 180.67271423339844
# Eval_StdReturn : 19.964080810546875
# Eval_MaxReturn : 203.14382934570312
# Eval_MinReturn : 125.86585998535156
# Eval_AverageEpLen : 88.75
# Train_AverageReturn : 182.22409057617188
# Train_StdReturn : 10.483397483825684
# Train_MaxReturn : 214.21665954589844
# Train_MinReturn : 113.45899963378906
# Train_AverageEpLen : 85.75213675213675
# Train_EnvstepsSoFar : 140546
# TimeSinceStart : 153.80003571510315
# Training Loss : -2.150836229324341
# Baseline Loss : 0.6036656498908997
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 14 ************
#
# Collecting data to be used for training...
# At timestep:     10068 / 100004040 / 10000/ 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 237.35877990722656
# Eval_StdReturn : 59.7041015625
# Eval_MaxReturn : 325.3087463378906
# Eval_MinReturn : 128.80587768554688
# Eval_AverageEpLen : 111.77777777777777
# Train_AverageReturn : 185.51577758789062
# Train_StdReturn : 27.346515655517578
# Train_MaxReturn : 283.2076721191406
# Train_MinReturn : 83.40364074707031
# Train_AverageEpLen : 89.09734513274336
# Train_EnvstepsSoFar : 150614
# TimeSinceStart : 162.4391679763794
# Training Loss : -3.624161958694458
# Baseline Loss : 0.7122865319252014
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 15 ************
#
# Collecting data to be used for training...
# At timestep:     10025 / 10000 10000 5768 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 223.1217498779297
# Eval_StdReturn : 80.95442962646484
# Eval_MaxReturn : 344.2741394042969
# Eval_MinReturn : 61.80121612548828
# Eval_AverageEpLen : 103.4
# Train_AverageReturn : 227.30865478515625
# Train_StdReturn : 58.71143341064453
# Train_MaxReturn : 353.2084655761719
# Train_MinReturn : 65.27342224121094
# Train_AverageEpLen : 107.79569892473118
# Train_EnvstepsSoFar : 160639
# TimeSinceStart : 171.01409673690796
# Training Loss : 0.5139405727386475
# Baseline Loss : 1.0132256746292114
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 16 ************
#
# Collecting data to be used for training...
# At timestep:     10039 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 284.8402404785156
# Eval_StdReturn : 69.80098724365234
# Eval_MaxReturn : 378.668212890625
# Eval_MinReturn : 118.98700714111328
# Eval_AverageEpLen : 117.0
# Train_AverageReturn : 208.97225952148438
# Train_StdReturn : 81.90650177001953
# Train_MaxReturn : 349.4046630859375
# Train_MinReturn : 60.73265075683594
# Train_AverageEpLen : 98.42156862745098
# Train_EnvstepsSoFar : 170678
# TimeSinceStart : 179.43778896331787
# Training Loss : -1.4839476346969604
# Baseline Loss : 1.337218999862671
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 17 ************
#
# Collecting data to be used for training...
# At timestep:     10017 / 10000 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 269.18109130859375
# Eval_StdReturn : 98.41521453857422
# Eval_MaxReturn : 405.3529052734375
# Eval_MinReturn : 118.41952514648438
# Eval_AverageEpLen : 117.33333333333333
# Train_AverageReturn : 254.7919464111328
# Train_StdReturn : 85.09193420410156
# Train_MaxReturn : 484.77838134765625
# Train_MinReturn : 93.06729888916016
# Train_AverageEpLen : 111.3
# Train_EnvstepsSoFar : 180695
# TimeSinceStart : 190.15477585792542
# Training Loss : -2.235927104949951
# Baseline Loss : 1.3388903141021729
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 18 ************
#
# Collecting data to be used for training...
# At timestep:     10141 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 330.1430358886719
# Eval_StdReturn : 93.841796875
# Eval_MaxReturn : 526.4921264648438
# Eval_MinReturn : 203.9489288330078
# Eval_AverageEpLen : 160.14285714285714
# Train_AverageReturn : 283.65606689453125
# Train_StdReturn : 106.09461975097656
# Train_MaxReturn : 512.828857421875
# Train_MinReturn : 89.74556732177734
# Train_AverageEpLen : 126.7625
# Train_EnvstepsSoFar : 190836
# TimeSinceStart : 201.56341981887817
# Training Loss : -6.81513786315918
# Baseline Loss : 1.2345092296600342
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 19 ************
#
# Collecting data to be used for training...
# At timestep:     10064 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 230.29690551757812
# Eval_StdReturn : 100.64545440673828
# Eval_MaxReturn : 399.43060302734375
# Eval_MinReturn : 106.10774993896484
# Eval_AverageEpLen : 127.75
# Train_AverageReturn : 311.6125793457031
# Train_StdReturn : 113.38380432128906
# Train_MaxReturn : 547.5225830078125
# Train_MinReturn : 87.09115600585938
# Train_AverageEpLen : 150.2089552238806
# Train_EnvstepsSoFar : 200900
# TimeSinceStart : 211.44447779655457
# Training Loss : -7.6133294105529785
# Baseline Loss : 1.1571269035339355
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 20 ************
#
# Collecting data to be used for training...
# At timestep:     10026 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 133.20579528808594
# Eval_StdReturn : 62.890716552734375
# Eval_MaxReturn : 291.60357666015625
# Eval_MinReturn : 20.959692001342773
# Eval_AverageEpLen : 85.08333333333333
# Train_AverageReturn : 259.5895690917969
# Train_StdReturn : 124.56346893310547
# Train_MaxReturn : 574.74658203125
# Train_MinReturn : 60.101951599121094
# Train_AverageEpLen : 137.34246575342465
# Train_EnvstepsSoFar : 210926
# TimeSinceStart : 224.40506792068481
# Training Loss : -6.50931978225708
# Baseline Loss : 1.12124502658844
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 21 ************
#
# Collecting data to be used for training...
# At timestep:     10102 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 124.47021484375
# Eval_StdReturn : 50.19852828979492
# Eval_MaxReturn : 223.92430114746094
# Eval_MinReturn : -0.5181845426559448
# Eval_AverageEpLen : 71.42857142857143
# Train_AverageReturn : 198.38404846191406
# Train_StdReturn : 96.33367156982422
# Train_MaxReturn : 518.9171142578125
# Train_MinReturn : 6.852484703063965
# Train_AverageEpLen : 113.50561797752809
# Train_EnvstepsSoFar : 221028
# TimeSinceStart : 232.41298580169678
# Training Loss : -2.4056758880615234
# Baseline Loss : 1.0359759330749512
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 22 ************
#
# Collecting data to be used for training...
# At timestep:     10096 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 270.92279052734375
# Eval_StdReturn : 161.006103515625
# Eval_MaxReturn : 536.378662109375
# Eval_MinReturn : 63.07189178466797
# Eval_AverageEpLen : 125.25
# Train_AverageReturn : 162.09930419921875
# Train_StdReturn : 85.6174545288086
# Train_MaxReturn : 577.4396362304688
# Train_MinReturn : 52.967994689941406
# Train_AverageEpLen : 90.95495495495496
# Train_EnvstepsSoFar : 231124
# TimeSinceStart : 242.82664704322815
# Training Loss : 0.624725878238678
# Baseline Loss : 0.9721958041191101
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 23 ************
#
# Collecting data to be used for training...
# At timestep:     10120 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 324.8675842285156
# Eval_StdReturn : 158.37078857421875
# Eval_MaxReturn : 509.25030517578125
# Eval_MinReturn : 118.96355438232422
# Eval_AverageEpLen : 146.0
# Train_AverageReturn : 228.43756103515625
# Train_StdReturn : 121.75292205810547
# Train_MaxReturn : 575.1786499023438
# Train_MinReturn : 107.70999908447266
# Train_AverageEpLen : 113.70786516853933
# Train_EnvstepsSoFar : 241244
# TimeSinceStart : 251.99980783462524
# Training Loss : 1.8873404264450073
# Baseline Loss : 1.0018537044525146
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 24 ************
#
# Collecting data to be used for training...
# At timestep:     10111 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 359.9865417480469
# Eval_StdReturn : 136.32530212402344
# Eval_MaxReturn : 529.9849853515625
# Eval_MinReturn : 106.90796661376953
# Eval_AverageEpLen : 146.14285714285714
# Train_AverageReturn : 328.4925842285156
# Train_StdReturn : 169.36474609375
# Train_MaxReturn : 574.3555908203125
# Train_MinReturn : -1.2689833641052246
# Train_AverageEpLen : 138.5068493150685
# Train_EnvstepsSoFar : 251355
# TimeSinceStart : 261.2188808917999
# Training Loss : 2.2004270553588867
# Baseline Loss : 0.9755955934524536
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 25 ************
#
# Collecting data to be used for training...
# At timestep:     10119 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 317.3401184082031
# Eval_StdReturn : 43.73276138305664
# Eval_MaxReturn : 380.676513671875
# Eval_MinReturn : 247.08229064941406
# Eval_AverageEpLen : 133.75
# Train_AverageReturn : 390.6290283203125
# Train_StdReturn : 115.07067108154297
# Train_MaxReturn : 594.3243408203125
# Train_MinReturn : 95.84517669677734
# Train_AverageEpLen : 153.3181818181818
# Train_EnvstepsSoFar : 261474
# TimeSinceStart : 270.6137719154358
# Training Loss : 2.7901039123535156
# Baseline Loss : 0.9174721240997314
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 26 ************
#
# Collecting data to be used for training...
# At timestep:     10107 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 371.9410095214844
# Eval_StdReturn : 136.50709533691406
# Eval_MaxReturn : 585.9471435546875
# Eval_MinReturn : 116.33210754394531
# Eval_AverageEpLen : 142.375
# Train_AverageReturn : 336.2913513183594
# Train_StdReturn : 87.98869323730469
# Train_MaxReturn : 548.7415161132812
# Train_MinReturn : 106.2317123413086
# Train_AverageEpLen : 132.98684210526315
# Train_EnvstepsSoFar : 271581
# TimeSinceStart : 280.3635718822479
# Training Loss : 3.1432244777679443
# Baseline Loss : 0.9426353573799133
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 27 ************
#
# Collecting data to be used for training...
# At timestep:     10128 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 442.4067077636719
# Eval_StdReturn : 74.94538879394531
# Eval_MaxReturn : 570.8164672851562
# Eval_MinReturn : 372.3004150390625
# Eval_AverageEpLen : 162.0
# Train_AverageReturn : 353.739990234375
# Train_StdReturn : 109.17438507080078
# Train_MaxReturn : 573.1400756835938
# Train_MinReturn : 91.42019653320312
# Train_AverageEpLen : 136.86486486486487
# Train_EnvstepsSoFar : 281709
# TimeSinceStart : 290.6916038990021
# Training Loss : 2.559687614440918
# Baseline Loss : 0.955603837966919
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 28 ************
#
# Collecting data to be used for training...
# At timestep:     10067 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 277.69580078125
# Eval_StdReturn : 136.00050354003906
# Eval_MaxReturn : 402.68035888671875
# Eval_MinReturn : 97.86011505126953
# Eval_AverageEpLen : 111.2
# Train_AverageReturn : 360.4584045410156
# Train_StdReturn : 140.3413848876953
# Train_MaxReturn : 591.8077392578125
# Train_MinReturn : 77.78897094726562
# Train_AverageEpLen : 136.04054054054055
# Train_EnvstepsSoFar : 291776
# TimeSinceStart : 302.2641968727112
# Training Loss : 2.2961015701293945
# Baseline Loss : 0.8493857979774475
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 29 ************
#
# Collecting data to be used for training...
# At timestep:     10034 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 289.23016357421875
# Eval_StdReturn : 164.6791534423828
# Eval_MaxReturn : 553.8765258789062
# Eval_MinReturn : 103.89397430419922
# Eval_AverageEpLen : 114.33333333333333
# Train_AverageReturn : 318.39892578125
# Train_StdReturn : 155.30667114257812
# Train_MaxReturn : 581.975830078125
# Train_MinReturn : 74.65021514892578
# Train_AverageEpLen : 122.36585365853658
# Train_EnvstepsSoFar : 301810
# TimeSinceStart : 312.0254547595978
# Training Loss : 2.8959271907806396
# Baseline Loss : 0.7565706968307495
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 30 ************
#
# Collecting data to be used for training...
# At timestep:     10051 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 301.8260498046875
# Eval_StdReturn : 151.9779052734375
# Eval_MaxReturn : 508.77459716796875
# Eval_MinReturn : 91.08984375
# Eval_AverageEpLen : 115.77777777777777
# Train_AverageReturn : 319.7646484375
# Train_StdReturn : 152.7833251953125
# Train_MaxReturn : 623.9151611328125
# Train_MinReturn : 79.73332977294922
# Train_AverageEpLen : 122.57317073170732
# Train_EnvstepsSoFar : 311861
# TimeSinceStart : 322.08942008018494
# Training Loss : 1.8787320852279663
# Baseline Loss : 0.7382993698120117
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 31 ************
#
# Collecting data to be used for training...
# At timestep:     10180 / 1000010000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 403.97698974609375
# Eval_StdReturn : 150.23721313476562
# Eval_MaxReturn : 590.59912109375
# Eval_MinReturn : 98.62725067138672
# Eval_AverageEpLen : 147.71428571428572
# Train_AverageReturn : 342.6985168457031
# Train_StdReturn : 135.95016479492188
# Train_MaxReturn : 604.0372314453125
# Train_MinReturn : 75.30049896240234
# Train_AverageEpLen : 128.86075949367088
# Train_EnvstepsSoFar : 322041
# TimeSinceStart : 330.70391607284546
# Training Loss : 0.14819124341011047
# Baseline Loss : 0.7234958410263062
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 32 ************
#
# Collecting data to be used for training...
# At timestep:     10141 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 320.9103698730469
# Eval_StdReturn : 98.31527709960938
# Eval_MaxReturn : 402.2198486328125
# Eval_MinReturn : 88.40558624267578
# Eval_AverageEpLen : 125.22222222222223
# Train_AverageReturn : 338.0621032714844
# Train_StdReturn : 112.13220977783203
# Train_MaxReturn : 524.9471435546875
# Train_MinReturn : 78.20724487304688
# Train_AverageEpLen : 128.36708860759492
# Train_EnvstepsSoFar : 332182
# TimeSinceStart : 339.60259675979614
# Training Loss : -0.5081696510314941
# Baseline Loss : 0.6546671986579895
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 33 ************
#
# Collecting data to be used for training...
# At timestep:     10118 / 1000010000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 353.0106201171875
# Eval_StdReturn : 131.37326049804688
# Eval_MaxReturn : 573.7870483398438
# Eval_MinReturn : 92.1037826538086
# Eval_AverageEpLen : 131.5
# Train_AverageReturn : 362.7396240234375
# Train_StdReturn : 92.70439147949219
# Train_MaxReturn : 578.59423828125
# Train_MinReturn : 80.90597534179688
# Train_AverageEpLen : 134.90666666666667
# Train_EnvstepsSoFar : 342300
# TimeSinceStart : 347.36906695365906
# Training Loss : -2.0570788383483887
# Baseline Loss : 0.6060658693313599
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 34 ************
#
# Collecting data to be used for training...
# At timestep:     10042 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 341.4095458984375
# Eval_StdReturn : 88.32420349121094
# Eval_MaxReturn : 428.9010314941406
# Eval_MinReturn : 159.51119995117188
# Eval_AverageEpLen : 131.125
# Train_AverageReturn : 340.2406005859375
# Train_StdReturn : 97.42820739746094
# Train_MaxReturn : 601.0275268554688
# Train_MinReturn : 83.21048736572266
# Train_AverageEpLen : 128.74358974358975
# Train_EnvstepsSoFar : 352342
# TimeSinceStart : 355.03521370887756
# Training Loss : -2.8655011653900146
# Baseline Loss : 0.728144645690918
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 35 ************
#
# Collecting data to be used for training...
# At timestep:     10084 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 365.2513427734375
# Eval_StdReturn : 56.67628479003906
# Eval_MaxReturn : 453.5321960449219
# Eval_MinReturn : 274.67974853515625
# Eval_AverageEpLen : 139.75
# Train_AverageReturn : 360.68255615234375
# Train_StdReturn : 95.14927673339844
# Train_MaxReturn : 553.552734375
# Train_MinReturn : 98.44796752929688
# Train_AverageEpLen : 136.27027027027026
# Train_EnvstepsSoFar : 362426
# TimeSinceStart : 363.4342200756073
# Training Loss : -2.9693098068237305
# Baseline Loss : 0.7016765475273132
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 36 ************
#
# Collecting data to be used for training...
# At timestep:     10077 / 10000 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 445.6583557128906
# Eval_StdReturn : 102.36520385742188
# Eval_MaxReturn : 603.5021362304688
# Eval_MinReturn : 336.7906494140625
# Eval_AverageEpLen : 163.42857142857142
# Train_AverageReturn : 353.8851318359375
# Train_StdReturn : 66.09050750732422
# Train_MaxReturn : 522.2864379882812
# Train_MinReturn : 140.83834838867188
# Train_AverageEpLen : 136.17567567567568
# Train_EnvstepsSoFar : 372503
# TimeSinceStart : 372.874746799469
# Training Loss : -2.7136714458465576
# Baseline Loss : 0.692133903503418
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 37 ************
#
# Collecting data to be used for training...
# At timestep:     10123 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 411.57867431640625
# Eval_StdReturn : 71.88599395751953
# Eval_MaxReturn : 531.294189453125
# Eval_MinReturn : 351.94976806640625
# Eval_AverageEpLen : 152.42857142857142
# Train_AverageReturn : 383.356689453125
# Train_StdReturn : 77.04077911376953
# Train_MaxReturn : 565.98046875
# Train_MinReturn : 114.1131820678711
# Train_AverageEpLen : 144.61428571428573
# Train_EnvstepsSoFar : 382626
# TimeSinceStart : 381.4188919067383
# Training Loss : -5.132740497589111
# Baseline Loss : 0.6617860198020935
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 38 ************
#
# Collecting data to be used for training...
# At timestep:     10008 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 422.79779052734375
# Eval_StdReturn : 90.24627685546875
# Eval_MaxReturn : 569.2527465820312
# Eval_MinReturn : 353.4427490234375
# Eval_AverageEpLen : 155.42857142857142
# Train_AverageReturn : 416.4573974609375
# Train_StdReturn : 77.3584976196289
# Train_MaxReturn : 583.3366088867188
# Train_MinReturn : 305.4961242675781
# Train_AverageEpLen : 156.375
# Train_EnvstepsSoFar : 392634
# TimeSinceStart : 390.1730990409851
# Training Loss : -4.4785332679748535
# Baseline Loss : 0.670374870300293
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 39 ************
#
# Collecting data to be used for training...
# At timestep:     10109 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 368.2579040527344
# Eval_StdReturn : 44.96800231933594
# Eval_MaxReturn : 419.7396545410156
# Eval_MinReturn : 268.59283447265625
# Eval_AverageEpLen : 145.14285714285714
# Train_AverageReturn : 408.32147216796875
# Train_StdReturn : 71.39269256591797
# Train_MaxReturn : 583.7921752929688
# Train_MinReturn : 268.2467041015625
# Train_AverageEpLen : 153.16666666666666
# Train_EnvstepsSoFar : 402743
# TimeSinceStart : 397.84710669517517
# Training Loss : -1.1683852672576904
# Baseline Loss : 0.6455252170562744
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 40 ************
#
# Collecting data to be used for training...
# At timestep:     10039 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 391.73577880859375
# Eval_StdReturn : 108.65947723388672
# Eval_MaxReturn : 490.139404296875
# Eval_MinReturn : 147.55819702148438
# Eval_AverageEpLen : 147.42857142857142
# Train_AverageReturn : 400.0299072265625
# Train_StdReturn : 79.61213684082031
# Train_MaxReturn : 554.948974609375
# Train_MinReturn : 162.23597717285156
# Train_AverageEpLen : 152.1060606060606
# Train_EnvstepsSoFar : 412782
# TimeSinceStart : 406.5857837200165
# Training Loss : 1.7793301343917847
# Baseline Loss : 0.7075489163398743
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 41 ************
#
# Collecting data to be used for training...
# At timestep:     10126 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 414.148193359375
# Eval_StdReturn : 64.91068267822266
# Eval_MaxReturn : 559.6422119140625
# Eval_MinReturn : 360.44573974609375
# Eval_AverageEpLen : 157.57142857142858
# Train_AverageReturn : 414.0015869140625
# Train_StdReturn : 89.17646789550781
# Train_MaxReturn : 581.3167114257812
# Train_MinReturn : 158.963134765625
# Train_AverageEpLen : 155.7846153846154
# Train_EnvstepsSoFar : 422908
# TimeSinceStart : 415.3877670764923
# Training Loss : 3.3040690422058105
# Baseline Loss : 0.7457257509231567
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 42 ************
#
# Collecting data to be used for training...
# At timestep:     10065 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 382.322021484375
# Eval_StdReturn : 16.831497192382812
# Eval_MaxReturn : 407.5335693359375
# Eval_MinReturn : 360.298828125
# Eval_AverageEpLen : 143.85714285714286
# Train_AverageReturn : 398.6785583496094
# Train_StdReturn : 83.70573425292969
# Train_MaxReturn : 604.5691528320312
# Train_MinReturn : 164.18783569335938
# Train_AverageEpLen : 152.5
# Train_EnvstepsSoFar : 432973
# TimeSinceStart : 423.02809882164
# Training Loss : 4.167673587799072
# Baseline Loss : 0.6979976892471313
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 43 ************
#
# Collecting data to be used for training...
# At timestep:     10129 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 474.8321533203125
# Eval_StdReturn : 89.25525665283203
# Eval_MaxReturn : 551.1094970703125
# Eval_MinReturn : 283.96124267578125
# Eval_AverageEpLen : 174.16666666666666
# Train_AverageReturn : 409.05877685546875
# Train_StdReturn : 97.8569107055664
# Train_MaxReturn : 604.012939453125
# Train_MinReturn : 147.63624572753906
# Train_AverageEpLen : 153.46969696969697
# Train_EnvstepsSoFar : 443102
# TimeSinceStart : 431.5042450428009
# Training Loss : 2.533851385116577
# Baseline Loss : 0.6139864325523376
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 44 ************
#
# Collecting data to be used for training...
# At timestep:     10058 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 467.9366149902344
# Eval_StdReturn : 68.28863525390625
# Eval_MaxReturn : 539.91015625
# Eval_MinReturn : 378.2088928222656
# Eval_AverageEpLen : 169.0
# Train_AverageReturn : 421.42669677734375
# Train_StdReturn : 72.53642272949219
# Train_MaxReturn : 574.7596435546875
# Train_MinReturn : 285.5413513183594
# Train_AverageEpLen : 157.15625
# Train_EnvstepsSoFar : 453160
# TimeSinceStart : 439.4841899871826
# Training Loss : -1.010859727859497
# Baseline Loss : 0.5866150856018066
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 45 ************
#
# Collecting data to be used for training...
# At timestep:     10143 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 405.0975036621094
# Eval_StdReturn : 54.537025451660156
# Eval_MaxReturn : 507.0314636230469
# Eval_MinReturn : 357.591064453125
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : 422.2230529785156
# Train_StdReturn : 85.462890625
# Train_MaxReturn : 589.76123046875
# Train_MinReturn : 180.5440673828125
# Train_AverageEpLen : 156.04615384615386
# Train_EnvstepsSoFar : 463303
# TimeSinceStart : 447.22625207901
# Training Loss : -2.8329126834869385
# Baseline Loss : 0.5341498255729675
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 46 ************
#
# Collecting data to be used for training...
# At timestep:     10107 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 411.1487121582031
# Eval_StdReturn : 66.20967864990234
# Eval_MaxReturn : 551.2811889648438
# Eval_MinReturn : 361.4281005859375
# Eval_AverageEpLen : 155.28571428571428
# Train_AverageReturn : 436.50628662109375
# Train_StdReturn : 81.90948486328125
# Train_MaxReturn : 581.7073974609375
# Train_MinReturn : 343.905029296875
# Train_AverageEpLen : 160.42857142857142
# Train_EnvstepsSoFar : 473410
# TimeSinceStart : 454.83169198036194
# Training Loss : -4.309054374694824
# Baseline Loss : 0.5318815112113953
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 47 ************
#
# Collecting data to be used for training...
# At timestep:     10096 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 467.4646301269531
# Eval_StdReturn : 88.59425354003906
# Eval_MaxReturn : 573.919189453125
# Eval_MinReturn : 361.5337219238281
# Eval_AverageEpLen : 169.42857142857142
# Train_AverageReturn : 420.5027160644531
# Train_StdReturn : 85.77904510498047
# Train_MaxReturn : 579.419189453125
# Train_MinReturn : 138.8856658935547
# Train_AverageEpLen : 155.3230769230769
# Train_EnvstepsSoFar : 483506
# TimeSinceStart : 464.9406268596649
# Training Loss : -2.0537471771240234
# Baseline Loss : 0.515140175819397
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 48 ************
#
# Collecting data to be used for training...
# At timestep:     10163 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 435.7109680175781
# Eval_StdReturn : 51.075889587402344
# Eval_MaxReturn : 548.6644897460938
# Eval_MinReturn : 386.9754638671875
# Eval_AverageEpLen : 156.71428571428572
# Train_AverageReturn : 421.98345947265625
# Train_StdReturn : 89.05742645263672
# Train_MaxReturn : 577.8782958984375
# Train_MinReturn : 88.68795776367188
# Train_AverageEpLen : 156.35384615384615
# Train_EnvstepsSoFar : 493669
# TimeSinceStart : 473.2247197628021
# Training Loss : -1.5733386278152466
# Baseline Loss : 0.5285157561302185
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 49 ************
#
# Collecting data to be used for training...
# At timestep:     10128 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 381.52752685546875
# Eval_StdReturn : 92.71668243408203
# Eval_MaxReturn : 526.9463500976562
# Eval_MinReturn : 222.8679656982422
# Eval_AverageEpLen : 144.85714285714286
# Train_AverageReturn : 421.6015625
# Train_StdReturn : 74.48363494873047
# Train_MaxReturn : 580.1708984375
# Train_MinReturn : 341.3099670410156
# Train_AverageEpLen : 155.8153846153846
# Train_EnvstepsSoFar : 503797
# TimeSinceStart : 480.9115209579468
# Training Loss : 1.0855869054794312
# Baseline Loss : 0.44596508145332336
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 50 ************
#
# Collecting data to be used for training...
# At timestep:     10158 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 440.90380859375
# Eval_StdReturn : 67.47010040283203
# Eval_MaxReturn : 558.4600830078125
# Eval_MinReturn : 366.50592041015625
# Eval_AverageEpLen : 161.57142857142858
# Train_AverageReturn : 412.1462097167969
# Train_StdReturn : 63.41415023803711
# Train_MaxReturn : 572.6213989257812
# Train_MinReturn : 344.80987548828125
# Train_AverageEpLen : 151.61194029850745
# Train_EnvstepsSoFar : 513955
# TimeSinceStart : 488.6716139316559
# Training Loss : 2.796414375305176
# Baseline Loss : 0.4158233404159546
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 51 ************
#
# Collecting data to be used for training...
# At timestep:     10036 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 360.1541442871094
# Eval_StdReturn : 109.74834442138672
# Eval_MaxReturn : 501.3263854980469
# Eval_MinReturn : 92.63401794433594
# Eval_AverageEpLen : 135.5
# Train_AverageReturn : 405.5404052734375
# Train_StdReturn : 76.01033020019531
# Train_MaxReturn : 575.7596435546875
# Train_MinReturn : 97.63279724121094
# Train_AverageEpLen : 149.7910447761194
# Train_EnvstepsSoFar : 523991
# TimeSinceStart : 496.33924889564514
# Training Loss : 3.132384777069092
# Baseline Loss : 0.4138072729110718
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 52 ************
#
# Collecting data to be used for training...
# At timestep:     10119 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 382.5616760253906
# Eval_StdReturn : 19.024574279785156
# Eval_MaxReturn : 403.1474609375
# Eval_MinReturn : 357.0208740234375
# Eval_AverageEpLen : 143.57142857142858
# Train_AverageReturn : 398.635009765625
# Train_StdReturn : 70.92130279541016
# Train_MaxReturn : 580.684814453125
# Train_MinReturn : 85.53282165527344
# Train_AverageEpLen : 146.65217391304347
# Train_EnvstepsSoFar : 534110
# TimeSinceStart : 504.0628180503845
# Training Loss : 2.676213502883911
# Baseline Loss : 0.38331642746925354
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 53 ************
#
# Collecting data to be used for training...
# At timestep:     10087 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 413.94427490234375
# Eval_StdReturn : 38.1955451965332
# Eval_MaxReturn : 472.3039245605469
# Eval_MinReturn : 371.6850280761719
# Eval_AverageEpLen : 150.85714285714286
# Train_AverageReturn : 398.71307373046875
# Train_StdReturn : 49.3036994934082
# Train_MaxReturn : 581.7420654296875
# Train_MinReturn : 346.32159423828125
# Train_AverageEpLen : 146.18840579710144
# Train_EnvstepsSoFar : 544197
# TimeSinceStart : 511.77691078186035
# Training Loss : 0.11763141304254532
# Baseline Loss : 0.33072659373283386
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 54 ************
#
# Collecting data to be used for training...
# At timestep:     10056 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 428.10302734375
# Eval_StdReturn : 51.39466857910156
# Eval_MaxReturn : 516.3291015625
# Eval_MinReturn : 365.7142333984375
# Eval_AverageEpLen : 154.14285714285714
# Train_AverageReturn : 390.4894104003906
# Train_StdReturn : 39.05012130737305
# Train_MaxReturn : 566.8751220703125
# Train_MinReturn : 342.672119140625
# Train_AverageEpLen : 143.65714285714284
# Train_EnvstepsSoFar : 554253
# TimeSinceStart : 519.4802477359772
# Training Loss : -2.486948013305664
# Baseline Loss : 0.3010525405406952
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 55 ************
#
# Collecting data to be used for training...
# At timestep:     10006 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 386.234619140625
# Eval_StdReturn : 14.11349105834961
# Eval_MaxReturn : 408.242919921875
# Eval_MinReturn : 368.4274597167969
# Eval_AverageEpLen : 143.85714285714286
# Train_AverageReturn : 403.9048156738281
# Train_StdReturn : 41.94467544555664
# Train_MaxReturn : 557.9801025390625
# Train_MinReturn : 347.85943603515625
# Train_AverageEpLen : 147.14705882352942
# Train_EnvstepsSoFar : 564259
# TimeSinceStart : 527.7024698257446
# Training Loss : -8.834805488586426
# Baseline Loss : 0.37646928429603577
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 56 ************
#
# Collecting data to be used for training...
# At timestep:     10045 / 100005569 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 459.8426208496094
# Eval_StdReturn : 67.5663833618164
# Eval_MaxReturn : 575.2778930664062
# Eval_MinReturn : 390.02587890625
# Eval_AverageEpLen : 162.57142857142858
# Train_AverageReturn : 394.2645263671875
# Train_StdReturn : 41.16554260253906
# Train_MaxReturn : 572.342529296875
# Train_MinReturn : 352.8335876464844
# Train_AverageEpLen : 145.57971014492753
# Train_EnvstepsSoFar : 574304
# TimeSinceStart : 543.4617569446564
# Training Loss : -5.8502092361450195
# Baseline Loss : 0.2997371554374695
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 57 ************
#
# Collecting data to be used for training...
# At timestep:     10102 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 435.08648681640625
# Eval_StdReturn : 62.57788848876953
# Eval_MaxReturn : 544.4960327148438
# Eval_MinReturn : 359.564697265625
# Eval_AverageEpLen : 153.57142857142858
# Train_AverageReturn : 402.0009460449219
# Train_StdReturn : 46.257408142089844
# Train_MaxReturn : 561.2354125976562
# Train_MinReturn : 358.4938659667969
# Train_AverageEpLen : 146.40579710144928
# Train_EnvstepsSoFar : 584406
# TimeSinceStart : 553.8114449977875
# Training Loss : -4.636706829071045
# Baseline Loss : 0.29621759057044983
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 58 ************
#
# Collecting data to be used for training...
# At timestep:     10135 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 425.3083190917969
# Eval_StdReturn : 67.40044403076172
# Eval_MaxReturn : 560.8658447265625
# Eval_MinReturn : 362.11492919921875
# Eval_AverageEpLen : 156.0
# Train_AverageReturn : 401.8576965332031
# Train_StdReturn : 34.86429214477539
# Train_MaxReturn : 533.8119506835938
# Train_MinReturn : 357.42022705078125
# Train_AverageEpLen : 144.78571428571428
# Train_EnvstepsSoFar : 594541
# TimeSinceStart : 561.7888009548187
# Training Loss : 0.07597751915454865
# Baseline Loss : 0.26872289180755615
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 59 ************
#
# Collecting data to be used for training...
# At timestep:     10086 / 10000206 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 377.7441101074219
# Eval_StdReturn : 37.8471565246582
# Eval_MaxReturn : 437.2481689453125
# Eval_MinReturn : 305.27593994140625
# Eval_AverageEpLen : 140.375
# Train_AverageReturn : 397.7826843261719
# Train_StdReturn : 38.41066360473633
# Train_MaxReturn : 532.414794921875
# Train_MinReturn : 355.0472412109375
# Train_AverageEpLen : 146.17391304347825
# Train_EnvstepsSoFar : 604627
# TimeSinceStart : 571.0190258026123
# Training Loss : 1.9707049131393433
# Baseline Loss : 0.3250710070133209
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 60 ************
#
# Collecting data to be used for training...
# At timestep:     10095 / 10000 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 383.60614013671875
# Eval_StdReturn : 21.34556770324707
# Eval_MaxReturn : 413.7304382324219
# Eval_MinReturn : 359.3519287109375
# Eval_AverageEpLen : 140.5
# Train_AverageReturn : 405.1409912109375
# Train_StdReturn : 32.04640197753906
# Train_MaxReturn : 532.240478515625
# Train_MinReturn : 350.82904052734375
# Train_AverageEpLen : 146.30434782608697
# Train_EnvstepsSoFar : 614722
# TimeSinceStart : 580.0190558433533
# Training Loss : 3.4582314491271973
# Baseline Loss : 0.30388832092285156
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 61 ************
#
# Collecting data to be used for training...
# At timestep:     10047 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 391.4395751953125
# Eval_StdReturn : 17.312763214111328
# Eval_MaxReturn : 409.7452697753906
# Eval_MinReturn : 361.80078125
# Eval_AverageEpLen : 142.5
# Train_AverageReturn : 396.3196716308594
# Train_StdReturn : 51.48756790161133
# Train_MaxReturn : 569.0901489257812
# Train_MinReturn : 288.5115051269531
# Train_AverageEpLen : 145.6086956521739
# Train_EnvstepsSoFar : 624769
# TimeSinceStart : 590.6415529251099
# ...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 498.0107116699219
# Eval_StdReturn : 88.2110366821289
# Eval_MaxReturn : 575.645263671875
# Eval_MinReturn : 366.55364990234375
# Eval_AverageEpLen : 183.33333333333334
# Train_AverageReturn : 473.1269226074219
# Train_StdReturn : 79.044677734375
# Train_MaxReturn : 606.1126708984375
# Train_MinReturn : 357.71527099609375
# Train_AverageEpLen : 173.3448275862069
# Train_EnvstepsSoFar : 805819
# TimeSinceStart : 710.2367630004883
# Training Loss : -1.5963553190231323
# Baseline Loss : 0.3786379098892212
# Initial_DataCollection_AverageReturn : 17.71956443786621
# Done logging...
#
#
#
#
# ********** Iteration 80 ************
#
# Collecting data to be used for training...
# At timestep:     10109 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 483.6014404296875
# Eval_StdReturn : 82.93391418457031
# Eval_MaxReturn : 576.0526123046875
# Eval_MinReturn : 370.1948547363281
# Eval_AverageEpLen : 175.0
# Train_AverageReturn : 446.57867431640625
# Train_StdReturn : 81.92526245117188
# Train_MaxReturn : 589.976318359375
# Train_MinReturn : 254.58599853515625
# Train_AverageEpLen : 165.72131147540983
# Train_EnvstepsSoFar : 815928
# TimeSinceStart : 718.0343170166016
# Training Loss : 0.4129970669746399
# Baseline Loss : 0.3680674433708191
# Initial_DataCollection_AverageReturn : 17.71956443786621
# Done logging...
#
#
#
#
# ********** Iteration 81 ************
#
# Collecting data to be used for training...
# At timestep:     10093 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 500.8302917480469
# Eval_StdReturn : 74.51710510253906
# Eval_MaxReturn : 573.1353149414062
# Eval_MinReturn : 381.53570556640625
# Eval_AverageEpLen : 178.33333333333334
# Train_AverageReturn : 458.1060485839844
# Train_StdReturn : 77.28309631347656
# Train_MaxReturn : 592.8564453125
# Train_MinReturn : 360.6390075683594
# Train_AverageEpLen : 168.21666666666667
# Train_EnvstepsSoFar : 826021
# TimeSinceStart : 728.6232569217682
# Training Loss : -0.9220871925354004
# Baseline Loss : 0.3590591847896576
# Initial_DataCollection_AverageReturn : 17.71956443786621
# Done logging...
#
#
#
#
# ********** Iteration 82 ************
#
# Collecting data to be used for training...
# At timestep:     10041 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 503.9063415527344
# Eval_StdReturn : 68.4185791015625
# Eval_MaxReturn : 564.8613891601562
# Eval_MinReturn : 360.6455078125
# Eval_AverageEpLen : 182.66666666666666
# Train_AverageReturn : 458.56884765625
# Train_StdReturn : 85.97212219238281
# Train_MaxReturn : 595.5003051757812
# Train_MinReturn : 358.64068603515625
# Train_AverageEpLen : 170.1864406779661
# Train_EnvstepsSoFar : 836062
# TimeSinceStart : 738.3944051265717
# Training Loss : -1.155588984489441
# Baseline Loss : 0.3769106864929199
# Initial_DataCollection_AverageReturn : 17.71956443786621
# Done logging...
#
#
#
#
# ********** Iteration 83 ************
#
# Collecting data to be used for training...
# At timestep:     10114 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 434.8919372558594
# Eval_StdReturn : 71.61917114257812
# Eval_MaxReturn : 560.1798095703125
# Eval_MinReturn : 364.79876708984375
# Eval_AverageEpLen : 163.57142857142858
# Train_AverageReturn : 476.7694396972656
# Train_StdReturn : 74.27992248535156
# Train_MaxReturn : 583.1276245117188
# Train_MinReturn : 363.5049133300781
# Train_AverageEpLen : 174.3793103448276
# Train_EnvstepsSoFar : 846176
# TimeSinceStart : 746.4707250595093
# Training Loss : -2.4129762649536133
# Baseline Loss : 0.38675543665885925
# Initial_DataCollection_AverageReturn : 17.71956443786621
# Done logging...
#
#
#
#
# ********** Iteration 84 ************
#
# Collecting data to be used for training...
# At timestep:     10060 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 446.3639831542969
# Eval_StdReturn : 95.09744262695312
# Eval_MaxReturn : 552.2305908203125
# Eval_MinReturn : 262.8613586425781
# Eval_AverageEpLen : 168.66666666666666
# Train_AverageReturn : 460.15533447265625
# Train_StdReturn : 79.26612854003906
# Train_MaxReturn : 597.495849609375
# Train_MinReturn : 358.9820556640625
# Train_AverageEpLen : 170.5084745762712
# Train_EnvstepsSoFar : 856236
# TimeSinceStart : 755.013102054596
# Training Loss : -0.5131257176399231
# Baseline Loss : 0.37547388672828674
# Initial_DataCollection_AverageReturn : 17.71956443786621
# Done logging...
#
#
#
#
# ********** Iteration 85 ************
#
# Collecting data to be used for training...
# At timestep:     10106 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 421.3179016113281
# Eval_StdReturn : 125.04349517822266
# Eval_MaxReturn : 522.5879516601562
# Eval_MinReturn : 154.95077514648438
# Eval_AverageEpLen : 168.33333333333334
# Train_AverageReturn : 445.2340087890625
# Train_StdReturn : 80.49298858642578
# Train_MaxReturn : 563.525390625
# Train_MinReturn : 164.30462646484375
# Train_AverageEpLen : 168.43333333333334
# Train_EnvstepsSoFar : 866342
# TimeSinceStart : 765.9889929294586
# Training Loss : 2.6736819744110107
# Baseline Loss : 0.42514869570732117
# Initial_DataCollection_AverageReturn : 17.71956443786621
# Done logging...
#
#
#
#
# ********** Iteration 86 ************
#
# Collecting data to be used for training...
# At timestep:     10137 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 396.35662841796875
# Eval_StdReturn : 114.17223358154297
# Eval_MaxReturn : 563.4468994140625
# Eval_MinReturn : 163.37969970703125
# Eval_AverageEpLen : 154.28571428571428
# Train_AverageReturn : 436.91107177734375
# Train_StdReturn : 63.21226119995117
# Train_MaxReturn : 555.926025390625
# Train_MinReturn : 319.933349609375
# Train_AverageEpLen : 168.95
# Train_EnvstepsSoFar : 876479
# TimeSinceStart : 773.8395791053772
# Training Loss : 2.3657116889953613
# Baseline Loss : 0.4685969352722168
# Initial_DataCollection_AverageReturn : 17.71956443786621
# Done logging...
#
#
#
#
# ********** Iteration 87 ************
#
# Collecting data to be used for training...
# At timestep:     10099 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 465.7861633300781
# Eval_StdReturn : 42.20747756958008
# Eval_MaxReturn : 522.618408203125
# Eval_MinReturn : 390.9520263671875
# Eval_AverageEpLen : 174.66666666666666
# Train_AverageReturn : 422.8159484863281
# Train_StdReturn : 96.65348815917969
# Train_MaxReturn : 563.2550048828125
# Train_MinReturn : 163.27392578125
# Train_AverageEpLen : 165.55737704918033
# Train_EnvstepsSoFar : 886578
# TimeSinceStart : 781.6246230602264
# Training Loss : 2.5510787963867188
# Baseline Loss : 0.5693211555480957
# Initial_DataCollection_AverageReturn : 17.71956443786621
# Done logging...
#
#
#
#
# ********** Iteration 88 ************
#
# Collecting data to be used for training...
# At timestep:     10073 / 1000010000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 486.8356628417969
# Eval_StdReturn : 74.8528823852539
# Eval_MaxReturn : 570.710205078125
# Eval_MinReturn : 383.34808349609375
# Eval_AverageEpLen : 187.0
# Train_AverageReturn : 440.8902893066406
# Train_StdReturn : 74.6597671508789
# Train_MaxReturn : 596.4853515625
# Train_MinReturn : 232.4470672607422
# Train_AverageEpLen : 170.72881355932202
# Train_EnvstepsSoFar : 896651
# TimeSinceStart : 789.5514540672302
# Training Loss : 2.988018274307251
# Baseline Loss : 0.46828192472457886
# Initial_DataCollection_AverageReturn : 17.71956443786621
# Done logging...
#
#
#
#
# ********** Iteration 89 ************
#
# Collecting data to be used for training...
# At timestep:     10030 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 428.3361511230469
# Eval_StdReturn : 54.29881286621094
# Eval_MaxReturn : 549.7930297851562
# Eval_MinReturn : 389.99945068359375
# Eval_AverageEpLen : 157.28571428571428
# Train_AverageReturn : 459.41925048828125
# Train_StdReturn : 71.54203796386719
# Train_MaxReturn : 580.3510131835938
# Train_MinReturn : 333.9886474609375
# Train_AverageEpLen : 175.96491228070175
# Train_EnvstepsSoFar : 906681
# TimeSinceStart : 797.3359861373901
# Training Loss : -0.34410560131073
# Baseline Loss : 0.4289570748806
# Initial_DataCollection_AverageReturn : 17.71956443786621
# Done logging...
#
#
#
#
# ********** Iteration 90 ************
#
# Collecting data to be used for training...
# At timestep:     10009 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 442.2172546386719
# Eval_StdReturn : 79.6937484741211
# Eval_MaxReturn : 571.7158203125
# Eval_MinReturn : 367.40264892578125
# Eval_AverageEpLen : 166.71428571428572
# Train_AverageReturn : 506.1598815917969
# Train_StdReturn : 67.85808563232422
# Train_MaxReturn : 608.0559692382812
# Train_MinReturn : 364.0906982421875
# Train_AverageEpLen : 185.35185185185185
# Train_EnvstepsSoFar : 916690
# TimeSinceStart : 805.0901889801025
# Training Loss : -6.71187162399292
# Baseline Loss : 0.40111497044563293
# Initial_DataCollection_AverageReturn : 17.71956443786621
# Done logging...
#
#
#
#
# ********** Iteration 91 ************
#
# Collecting data to be used for training...
# At timestep:     10093 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 488.77392578125
# Eval_StdReturn : 88.29859924316406
# Eval_MaxReturn : 615.2595825195312
# Eval_MinReturn : 390.7101135253906
# Eval_AverageEpLen : 173.5
# Train_AverageReturn : 470.3766174316406
# Train_StdReturn : 85.8849868774414
# Train_MaxReturn : 614.148193359375
# Train_MinReturn : 305.3734130859375
# Train_AverageEpLen : 174.01724137931035
# Train_EnvstepsSoFar : 926783
# TimeSinceStart : 813.0046818256378
# Training Loss : -3.5711143016815186
# Baseline Loss : 0.3303321599960327
# Initial_DataCollection_AverageReturn : 17.71956443786621
# Done logging...
#
#
#
#
# ********** Iteration 92 ************
#
# Collecting data to be used for training...
# At timestep:     10041 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 484.1697692871094
# Eval_StdReturn : 72.92025756835938
# Eval_MaxReturn : 573.2588500976562
# Eval_MinReturn : 403.5733947753906
# Eval_AverageEpLen : 175.0
# Train_AverageReturn : 489.0718994140625
# Train_StdReturn : 65.88467407226562
# Train_MaxReturn : 595.0592041015625
# Train_MinReturn : 370.79547119140625
# Train_AverageEpLen : 182.56363636363636
# Train_EnvstepsSoFar : 936824
# TimeSinceStart : 820.7634110450745
# Training Loss : -4.373169422149658
# Baseline Loss : 0.35038793087005615
# Initial_DataCollection_AverageReturn : 17.71956443786621
# Done logging...
#
#
#
#
# ********** Iteration 93 ************
#
# Collecting data to be used for training...
# At timestep:     10137 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 419.9570617675781
# Eval_StdReturn : 64.38008880615234
# Eval_MaxReturn : 571.62060546875
# Eval_MinReturn : 365.2139587402344
# Eval_AverageEpLen : 155.28571428571428
# Train_AverageReturn : 456.5514831542969
# Train_StdReturn : 74.62911224365234
# Train_MaxReturn : 595.3262939453125
# Train_MinReturn : 361.82159423828125
# Train_AverageEpLen : 168.95
# Train_EnvstepsSoFar : 946961
# TimeSinceStart : 828.6002190113068
# Training Loss : 1.5681126117706299
# Baseline Loss : 0.2988519072532654
# Initial_DataCollection_AverageReturn : 17.71956443786621
# Done logging...
#
#
#
#
# ********** Iteration 94 ************
#
# Collecting data to be used for training...
# At timestep:     10138 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 468.0292053222656
# Eval_StdReturn : 74.2641830444336
# Eval_MaxReturn : 570.8626098632812
# Eval_MinReturn : 394.0484924316406
# Eval_AverageEpLen : 170.14285714285714
# Train_AverageReturn : 437.2145080566406
# Train_StdReturn : 75.52305603027344
# Train_MaxReturn : 583.7496948242188
# Train_MinReturn : 332.93505859375
# Train_AverageEpLen : 163.51612903225808
# Train_EnvstepsSoFar : 957099
# TimeSinceStart : 836.612909078598
# Training Loss : 4.323300361633301
# Baseline Loss : 0.31304535269737244
# Initial_DataCollection_AverageReturn : 17.71956443786621
# Done logging...
#
#
#
#
# ********** Iteration 95 ************
#
# Collecting data to be used for training...
# At timestep:     10024 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 454.2951965332031
# Eval_StdReturn : 86.01628112792969
# Eval_MaxReturn : 589.4849853515625
# Eval_MinReturn : 386.6029357910156
# Eval_AverageEpLen : 162.28571428571428
# Train_AverageReturn : 440.674560546875
# Train_StdReturn : 71.66342163085938
# Train_MaxReturn : 587.665283203125
# Train_MinReturn : 314.2369079589844
# Train_AverageEpLen : 164.327868852459
# Train_EnvstepsSoFar : 967123
# TimeSinceStart : 844.377191066742
# Training Loss : 5.2079572677612305
# Baseline Loss : 0.296631395816803
# Initial_DataCollection_AverageReturn : 17.71956443786621
# Done logging...
#
#
#
#
# ********** Iteration 96 ************
#
# Collecting data to be used for training...
# At timestep:     10138 / 100000000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 438.61712646484375
# Eval_StdReturn : 61.678165435791016
# Eval_MaxReturn : 556.601806640625
# Eval_MinReturn : 359.93548583984375
# Eval_AverageEpLen : 159.14285714285714
# Train_AverageReturn : 433.342041015625
# Train_StdReturn : 76.7831039428711
# Train_MaxReturn : 606.865234375
# Train_MinReturn : 347.90740966796875
# Train_AverageEpLen : 160.9206349206349
# Train_EnvstepsSoFar : 977261
# TimeSinceStart : 852.1909449100494
# Training Loss : 1.7469687461853027
# Baseline Loss : 0.2687358260154724
# Initial_DataCollection_AverageReturn : 17.71956443786621
# Done logging...
#
#
#
#
# ********** Iteration 97 ************
#
# Collecting data to be used for training...
# At timestep:     10067 / 100000000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 475.5470886230469
# Eval_StdReturn : 89.56056213378906
# Eval_MaxReturn : 611.4907836914062
# Eval_MinReturn : 371.8108825683594
# Eval_AverageEpLen : 170.16666666666666
# Train_AverageReturn : 440.0569152832031
# Train_StdReturn : 67.85926818847656
# Train_MaxReturn : 585.825439453125
# Train_MinReturn : 311.3088073730469
# Train_AverageEpLen : 162.3709677419355
# Train_EnvstepsSoFar : 987328
# TimeSinceStart : 859.9524631500244
# Training Loss : -1.3934375047683716
# Baseline Loss : 0.2926236093044281
# Initial_DataCollection_AverageReturn : 17.71956443786621
# Done logging...
#
#
#
#
# ********** Iteration 98 ************
#
# Collecting data to be used for training...
# At timestep:     10075 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 447.2562561035156
# Eval_StdReturn : 80.00761413574219
# Eval_MaxReturn : 594.258056640625
# Eval_MinReturn : 386.595458984375
# Eval_AverageEpLen : 163.42857142857142
# Train_AverageReturn : 432.71966552734375
# Train_StdReturn : 70.76716613769531
# Train_MaxReturn : 597.548583984375
# Train_MinReturn : 331.0617980957031
# Train_AverageEpLen : 159.9206349206349
# Train_EnvstepsSoFar : 997403
# TimeSinceStart : 867.747967004776
# Training Loss : -2.4472389221191406
# Baseline Loss : 0.24935144186019897
# Initial_DataCollection_AverageReturn : 17.71956443786621
# Done logging...
#
#
#
#
# ********** Iteration 99 ************
#
# Collecting data to be used for training...
# At timestep:     10012 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 502.038330078125
# Eval_StdReturn : 80.13785552978516
# Eval_MaxReturn : 571.841552734375
# Eval_MinReturn : 380.2099609375
# Eval_AverageEpLen : 181.66666666666666
# Train_AverageReturn : 427.51702880859375
# Train_StdReturn : 68.03267669677734
# Train_MaxReturn : 649.6724853515625
# Train_MinReturn : 301.01959228515625
# Train_AverageEpLen : 158.9206349206349
# Train_EnvstepsSoFar : 1007415
# TimeSinceStart : 875.5213589668274
# Training Loss : -1.615217924118042
# Baseline Loss : 0.2622799873352051
# Initial_DataCollection_AverageReturn : 17.71956443786621
# Done logging...

# %%
# Plot learning curves
### Visualize Policy Gradient results on Hopper
# %load_ext tensorboard
# %tensorboard --logdir logs/policy_gradient/Hopper
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6010 (pid 58182), started 1:16:34 ago. (Use '!kill 58182' to kill it.)
#       <iframe id="tensorboard-frame-879a027b1f5d3585" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-879a027b1f5d3585");
#           const url = new URL("/", window.location);
#           const port = 6010;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
