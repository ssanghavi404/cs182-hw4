# %% [markdown]
# # Imitation Learning with Neural Network Policies
# In this notebook, you will implement the supervised losses for behavior cloning and use it to train policies for locomotion tasks.

# %%
#@title imports
# As usual, a bit of setup
import os
import shutil
import time
import numpy as np
import torch

import deeprl.infrastructure.pytorch_util as ptu

from deeprl.infrastructure.rl_trainer import RL_Trainer
from deeprl.infrastructure.trainers import BC_Trainer
from deeprl.agents.bc_agent import BCAgent
from deeprl.policies.loaded_gaussian_policy import LoadedGaussianPolicy
from deeprl.policies.MLP_policy import MLPPolicySL

# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """ returns relative error """
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

def remove_folder(path):
    # check if folder exists
    if os.path.exists(path): 
        print("Clearing old results at {}".format(path))
        # remove if exists
        shutil.rmtree(path)
    else:
        print("Folder {} does not exist yet. No old results to delete".format(path))

# %%
bc_base_args_dict = dict(
    expert_policy_file = 'deeprl/policies/experts/Hopper.pkl', #@param
    expert_data = 'deeprl/expert_data/expert_data_Hopper-v2.pkl', #@param
    env_name = 'Hopper-v2', #@param ['Ant-v2', 'Humanoid-v2', 'Walker2d-v2', 'HalfCheetah-v2', 'Hopper-v2']
    exp_name = 'test_bc', #@param
    do_dagger = True, #@param {type: "boolean"}
    ep_len = 1000, #@param {type: "integer"}
    save_params = False, #@param {type: "boolean"}

    # Training
    num_agent_train_steps_per_iter = 1000, #@param {type: "integer"})
    n_iter = 1, #@param {type: "integer"})

    # batches & buffers
    batch_size = 10000, #@param {type: "integer"})
    eval_batch_size = 1000, #@param {type: "integer"}
    train_batch_size = 100, #@param {type: "integer"}
    max_replay_buffer_size = 1000000, #@param {type: "integer"}

    #@markdown network
    n_layers = 2, #@param {type: "integer"}
    size = 64, #@param {type: "integer"}
    learning_rate = 5e-3, #@param {type: "number"}

    #@markdown logging
    video_log_freq = -1, #@param {type: "integer"}
    scalar_log_freq = 1, #@param {type: "integer"}

    #@markdown gpu & run-time settings
    no_gpu = False, #@param {type: "boolean"}
    which_gpu = 0, #@param {type: "integer"}
    seed = 2, #@param {type: "integer"}
    logdir = 'test',
)

# %% [markdown]
# # Infrastructure
# **Policies**: We have provided implementations of simple neural network policies for your convenience. For discrete environments, the neural network takes in the current state and outputs the logits of the policy's action distribution at this state. The policy then outputs a categorical distribution using those logits. In environments with continuous action spaces, the network will output the mean of a diagonal Gaussian distribution, as well as having a separate single parameter for the log standard deviations of the Gaussian.
#
# Calling forward on the policy will output a torch distribution object, so look at the documentation at https://pytorch.org/docs/stable/distributions.html.
# Look at <code>policies/MLP_policy</code> to make sure you understand the implementation.
#
# **RL Training Loop**: The reinforcement learning training loop, which alternates between gathering samples from the environment and updating the policy (and other learned functions) can be found in <code>infrastructure/rl_trainer.py</code>. While you won't need to understand this for the basic behavior cloning part (as you only use a fixed set of expert data), you should read through and understand the run_training_loop function before starting the Dagger implementation.

# %% [markdown]
# # Basic Behavior Cloning
# The first part of the assignment will be a familiar exercise in supervised learning. Given a dataset of expert trajectories, we will simply train our policy to imitate the expert via maximum likelihood. Fill out the update method in the MLPPolicySL class in <code>policies/MLP_policy.py</code>.

# %%
### Basic test for correctness of loss and gradients
torch.manual_seed(0)
ac_dim = 2
ob_dim = 3
batch_size = 5

policy = MLPPolicySL(
            ac_dim=ac_dim,
            ob_dim=ob_dim,
            n_layers=1,
            size=2,
            learning_rate=0.25)

np.random.seed(0)
obs = np.random.normal(size=(batch_size, ob_dim))
acts = np.random.normal(size=(batch_size, ac_dim))

first_weight_before = np.array(ptu.to_numpy(next(policy.mean_net.parameters())))
print("Weight before update", first_weight_before)

for i in range(5):
    loss = policy.update(obs, acts)['Training Loss']

print(loss)
expected_loss = 2.628419
loss_error = rel_error(loss, expected_loss)
print("Loss Error", loss_error, "should be on the order of 1e-6 or lower")

first_weight_after = ptu.to_numpy(next(policy.mean_net.parameters()))
print('Weight after update', first_weight_after)

weight_change = first_weight_after - first_weight_before
print("Change in weights", weight_change)

expected_change = np.array([[ 0.04385546, -0.4614172,  -1.0613215 ],
                            [ 0.20986436, -1.2060736,  -1.0026767 ]])
updated_weight_error = rel_error(weight_change, expected_change)
print("Weight Update Error", updated_weight_error, "should be on the order of 1e-6 or lower")
# Out:
# Weight before update [[-0.00432253  0.30971587 -0.47518533]
#  [-0.42489457 -0.22236899  0.15482074]]
# 2.6284192
# Loss Error 3.059688933264463e-08 should be on the order of 1e-6 or lower
# Weight after update [[ 0.03953294 -0.15170133 -1.536507  ]
#  [-0.21503036 -1.4284427  -0.8478558 ]]
# Change in weights [[ 0.04385547 -0.4614172  -1.0613217 ]
#  [ 0.20986421 -1.2060738  -1.0026765 ]]
# Weight Update Error 3.476944822992553e-07 should be on the order of 1e-6 or lower

# %% [markdown]
# Having implemented our behavior cloning loss, we can now start training some policies to imitate the expert policies provided.
#
# Run the following cell to train policies with simple behavior cloning on the HalfCheetah environment.

# %%
bc_args = dict(bc_base_args_dict)

env_str = 'HalfCheetah'
bc_args['expert_policy_file'] = 'deeprl/policies/experts/{}.pkl'.format(env_str)
bc_args['expert_data'] = 'deeprl/expert_data/expert_data_{}-v2.pkl'.format(env_str)
bc_args['env_name'] = '{}-v2'.format(env_str)

# Delete all previous logs
remove_folder('logs/behavior_cloning/{}'.format(env_str))

for seed in range(3):
    print("Running behavior cloning experiment with seed", seed)
    bc_args['seed'] = seed
    bc_args['logdir'] = 'logs/behavior_cloning/{}/seed{}'.format(env_str, seed)
    bctrainer = BC_Trainer(bc_args)
    bctrainer.run_training_loop()
# Out:
# Clearing old results at logs/behavior_cloning/HalfCheetah
# Running behavior cloning experiment with seed 0
# ########################
# logging outputs to  logs/behavior_cloning/HalfCheetah/seed0
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# HalfCheetah-v2
# Loading expert policy from... deeprl/policies/experts/HalfCheetah.pkl
# obs (1, 17) (1, 17)
# Done restoring expert policy...
#
#
# ********** Iteration 0 ************
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 3760.600830078125
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 3760.600830078125
# Eval_MinReturn : 3760.600830078125
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 4205.7783203125
# Train_StdReturn : 83.038818359375
# Train_MaxReturn : 4288.81689453125
# Train_MinReturn : 4122.7392578125
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 0
# TimeSinceStart : 3.3423092365264893
# Training Loss : -7.846749305725098
# Initial_DataCollection_AverageReturn : 4205.7783203125
# Done logging...
#
#
# Running behavior cloning experiment with seed 1
# ########################
# logging outputs to  logs/behavior_cloning/HalfCheetah/seed1
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# HalfCheetah-v2
# Loading expert policy from... deeprl/policies/experts/HalfCheetah.pkl
# obs (1, 17) (1, 17)
# Done restoring expert policy...
#
#
# ********** Iteration 0 ************
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 3778.91259765625
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 3778.91259765625
# Eval_MinReturn : 3778.91259765625
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 4205.7783203125
# Train_StdReturn : 83.038818359375
# Train_MaxReturn : 4288.81689453125
# Train_MinReturn : 4122.7392578125
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 0
# TimeSinceStart : 3.5947251319885254
# Training Loss : -8.353276252746582
# Initial_DataCollection_AverageReturn : 4205.7783203125
# Done logging...
#
#
# Running behavior cloning experiment with seed 2
# ########################
# logging outputs to  logs/behavior_cloning/HalfCheetah/seed2
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# HalfCheetah-v2
# Loading expert policy from... deeprl/policies/experts/HalfCheetah.pkl
# obs (1, 17) (1, 17)
# Done restoring expert policy...
#
#
# ********** Iteration 0 ************
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 3935.19189453125
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 3935.19189453125
# Eval_MinReturn : 3935.19189453125
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 4205.7783203125
# Train_StdReturn : 83.038818359375
# Train_MaxReturn : 4288.81689453125
# Train_MinReturn : 4122.7392578125
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 0
# TimeSinceStart : 4.14573073387146
# Training Loss : -9.084443092346191
# Initial_DataCollection_AverageReturn : 4205.7783203125
# Done logging...

# %% [markdown]
# Visualize your results using Tensorboard. You should see that on HalfCheetah, the returns of your learned policies (Eval_AverageReturn) are fairly similar (thought a bit lower) to that of the expert (Initial_DataCollection_Average_Return).

# %%
### Visualize behavior cloning results on HalfCheetah
# %load_ext tensorboard
# %tensorboard --logdir logs/behavior_cloning/HalfCheetah
# Out:
#       <iframe id="tensorboard-frame-c26178375b18b10f" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-c26178375b18b10f");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# Now run the following cell to train policies with simple behavior cloning on Hopper.

# %%
bc_args = dict(bc_base_args_dict)

env_str = 'Hopper'
bc_args['expert_policy_file'] = 'deeprl/policies/experts/{}.pkl'.format(env_str)
bc_args['expert_data'] = 'deeprl/expert_data/expert_data_{}-v2.pkl'.format(env_str)
bc_args['env_name'] = '{}-v2'.format(env_str)

# Delete all previous logs
remove_folder('logs/behavior_cloning/{}'.format(env_str))

for seed in range(3):
    print("Running behavior cloning experiment on Hopper with seed", seed)
    bc_args['seed'] = seed
    bc_args['logdir'] = 'logs/behavior_cloning/{}/seed{}'.format(env_str, seed)
    bctrainer = BC_Trainer(bc_args)
    bctrainer.run_training_loop()
# Out:
# Folder logs/behavior_cloning/Hopper does not exist yet. No old results to delete
# Running behavior cloning experiment on Hopper with seed 0
# ########################
# logging outputs to  logs/behavior_cloning/Hopper/seed0
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# Hopper-v2
# Loading expert policy from... deeprl/policies/experts/Hopper.pkl
# obs (1, 11) (1, 11)
# Done restoring expert policy...
#
#
# ********** Iteration 0 ************
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 666.4054565429688
# Eval_StdReturn : 306.9835205078125
# Eval_MaxReturn : 1170.435302734375
# Eval_MinReturn : 395.15380859375
# Eval_AverageEpLen : 214.8
# Train_AverageReturn : 3772.67041015625
# Train_StdReturn : 1.9483642578125
# Train_MaxReturn : 3774.61865234375
# Train_MinReturn : 3770.721923828125
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 0
# TimeSinceStart : 4.094741106033325
# Training Loss : -3.9635016918182373
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
# Running behavior cloning experiment on Hopper with seed 1
# ########################
# logging outputs to  logs/behavior_cloning/Hopper/seed1
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# Hopper-v2
# Loading expert policy from... deeprl/policies/experts/Hopper.pkl
# obs (1, 11) (1, 11)
# Done restoring expert policy...
#
#
# ********** Iteration 0 ************
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 1049.7603759765625
# Eval_StdReturn : 105.64323425292969
# Eval_MaxReturn : 1191.901611328125
# Eval_MinReturn : 903.8468017578125
# Eval_AverageEpLen : 303.5
# Train_AverageReturn : 3772.67041015625
# Train_StdReturn : 1.9483642578125
# Train_MaxReturn : 3774.61865234375
# Train_MinReturn : 3770.721923828125
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 0
# TimeSinceStart : 4.2442638874053955
# Training Loss : -3.5583176612854004
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
# Running behavior cloning experiment on Hopper with seed 2
# ########################
# logging outputs to  logs/behavior_cloning/Hopper/seed2
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# Hopper-v2
# Loading expert policy from... deeprl/policies/experts/Hopper.pkl
# obs (1, 11) (1, 11)
# Done restoring expert policy...
#
#
# ********** Iteration 0 ************
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 1125.50048828125
# Eval_StdReturn : 297.20098876953125
# Eval_MaxReturn : 1548.74658203125
# Eval_MinReturn : 757.9973754882812
# Eval_AverageEpLen : 337.0
# Train_AverageReturn : 3772.67041015625
# Train_StdReturn : 1.9483642578125
# Train_MaxReturn : 3774.61865234375
# Train_MinReturn : 3770.721923828125
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 0
# TimeSinceStart : 5.619419097900391
# Training Loss : -3.5946712493896484
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...

# %% [markdown]
# Visualize your results using Tensorboard. You should see that on Hopper, the returns of your learned policies (Eval_AverageReturn) are substantially lower than that of the expert (Initial_DataCollection_Average_Return), due to the distribution shift issues that arise when doing naive behavior cloning.

# %%
### Visualize behavior cloning results on Hopper
# %load_ext tensorboard
# %tensorboard --logdir logs/behavior_cloning/Hopper
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
#       <iframe id="tensorboard-frame-55b7963c9187aec1" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-55b7963c9187aec1");
#           const url = new URL("/", window.location);
#           const port = 6007;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# # Dataset Aggregation
# As discussed in lecture, behavior cloning can suffer from distribution shift, as a small mismatch between the learned and expert policy can take the learned policy to new states that were unseen during training, on which the learned policy hasn't been trained. In Dagger, we will address this issue iteratively, where we use our expert policy to provide labels for the new states we encounter with our learned policy, and then retrain our policy on these newly labeled states.
#
# Implement the <code>do_relabel_with_expert</code> function in <code>infrastructure/rl_trainer.py</code>. The errors in the expert actions should be on the order of 1e-6 or less.

# %%
### Test do relabel function
bc_args = dict(bc_base_args_dict)

env_str = 'Hopper'
bc_args['expert_policy_file'] = 'deeprl/policies/experts/{}.pkl'.format(env_str)
bc_args['expert_data'] = 'deeprl/expert_data/expert_data_{}-v2.pkl'.format(env_str)
bc_args['env_name'] = '{}-v2'.format(env_str)
bctrainer = BC_Trainer(bc_args)

np.random.seed(0)
T = 2
ob_dim = 11
ac_dim = 3

paths = []
for i in range(3):
    obs = np.random.normal(size=(T, ob_dim))
    acs = np.random.normal(size=(T, ac_dim))
    paths.append(dict(observation=obs,
                      action=acs))
    
rl_trainer = bctrainer.rl_trainer
relabeled_paths = rl_trainer.do_relabel_with_expert(bctrainer.loaded_expert_policy, paths)

expert_actions = np.array([[[-1.7814021, -0.11137983,  1.763353  ],
                            [-2.589222,   -5.463195,    2.4301376 ]],
                           [[-2.8287444, -5.298558,   3.0320463],
                            [ 3.9611065,  2.626403,  -2.8639293]],
                           [[-0.3055225,  -0.9865407,   0.80830705],
                            [ 2.8788857,   3.5550566,  -0.92875874]]])

for i, (path, relabeled_path) in enumerate(zip(paths, relabeled_paths)):
    assert np.all(path['observation'] == relabeled_path['observation'])
    print("Path {} expert action error".format(i), rel_error(expert_actions[i], relabeled_path['action']))
# Out:
# ########################
# logging outputs to  test
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# Hopper-v2
# Loading expert policy from... deeprl/policies/experts/Hopper.pkl
# obs (1, 11) (1, 11)
# Done restoring expert policy...
#
# Relabelling collected observations with labels from an expert policy...
# Path 0 expert action error 1.399300851855153e-08
# Path 1 expert action error 4.011498573448329e-08
# Path 2 expert action error 1.2587788480400697e-08

# %% [markdown]
# We can run Dagger on the Hopper env again.

# %%
dagger_args = dict(bc_base_args_dict)

dagger_args['do_dagger'] = True
dagger_args['n_iter'] = 10

env_str = 'Hopper'
dagger_args['expert_policy_file'] = 'deeprl/policies/experts/{}.pkl'.format(env_str)
dagger_args['expert_data'] = 'deeprl/expert_data/expert_data_{}-v2.pkl'.format(env_str)
dagger_args['env_name'] = '{}-v2'.format(env_str)

# %%
# Delete all previous logs
remove_folder('logs/dagger/{}'.format(env_str))

for seed in range(3):
    print("Running Dagger experiment with seed", seed)
    dagger_args['seed'] = seed
    dagger_args['logdir'] = 'logs/dagger/{}/seed{}'.format(env_str, seed)
    bctrainer = BC_Trainer(dagger_args)
    bctrainer.run_training_loop()
# Out:
# Folder logs/dagger/Hopper does not exist yet. No old results to delete
# Running Dagger experiment with seed 0
# ########################
# logging outputs to  logs/dagger/Hopper/seed0
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# Hopper-v2
# Loading expert policy from... deeprl/policies/experts/Hopper.pkl
# obs (1, 11) (1, 11)
# Done restoring expert policy...
#
#
# ********** Iteration 0 ************
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 666.4054565429688
# Eval_StdReturn : 306.9835205078125
# Eval_MaxReturn : 1170.435302734375
# Eval_MinReturn : 395.15380859375
# Eval_AverageEpLen : 214.8
# Train_AverageReturn : 3772.67041015625
# Train_StdReturn : 1.9483642578125
# Train_MaxReturn : 3774.61865234375
# Train_MinReturn : 3770.721923828125
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 0
# TimeSinceStart : 3.799121856689453
# Training Loss : -3.9635016918182373
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
#
#
# ********** Iteration 1 ************
#
# Collecting data to be used for training...
# At timestep:     10273 / 10000
# Relabelling collected observations with labels from an expert policy...
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 3590.8544921875
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 3590.8544921875
# Eval_MinReturn : 3590.8544921875
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 838.8912963867188
# Train_StdReturn : 268.4754333496094
# Train_MaxReturn : 1329.719970703125
# Train_MinReturn : 397.4961242675781
# Train_AverageEpLen : 263.4102564102564
# Train_EnvstepsSoFar : 10273
# TimeSinceStart : 22.369933128356934
# Training Loss : -2.0046396255493164
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
#
#
# ********** Iteration 2 ************
#
# Collecting data to be used for training...
# At timestep:     10077 / 10000
# Relabelling collected observations with labels from an expert policy...
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 3570.490234375
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 3570.490234375
# Eval_MinReturn : 3570.490234375
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 3275.56396484375
# Train_StdReturn : 673.5064697265625
# Train_MaxReturn : 3704.2919921875
# Train_MinReturn : 1748.751953125
# Train_AverageEpLen : 916.0909090909091
# Train_EnvstepsSoFar : 20350
# TimeSinceStart : 37.723103046417236
# Training Loss : -2.3467464447021484
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
#
#
# ********** Iteration 3 ************
#
# Collecting data to be used for training...
# At timestep:     10947 / 10000
# Relabelling collected observations with labels from an expert policy...
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 3745.19580078125
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 3745.19580078125
# Eval_MinReturn : 3745.19580078125
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 3599.960205078125
# Train_StdReturn : 40.78079605102539
# Train_MaxReturn : 3663.85400390625
# Train_MinReturn : 3535.97509765625
# Train_AverageEpLen : 995.1818181818181
# Train_EnvstepsSoFar : 31297
# TimeSinceStart : 55.02692723274231
# Training Loss : -2.5123682022094727
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
#
#
# ********** Iteration 4 ************
#
# Collecting data to be used for training...
# At timestep:     10000 / 10000
# Relabelling collected observations with labels from an expert policy...
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 3757.64306640625
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 3757.64306640625
# Eval_MinReturn : 3757.64306640625
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 3747.95166015625
# Train_StdReturn : 9.914664268493652
# Train_MaxReturn : 3766.1201171875
# Train_MinReturn : 3735.890625
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 41297
# TimeSinceStart : 67.73741412162781
# Training Loss : -2.909160852432251
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
#
#
# ********** Iteration 5 ************
#
# Collecting data to be used for training...
# At timestep:     10000 / 10000
# Relabelling collected observations with labels from an expert policy...
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 3772.617919921875
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 3772.617919921875
# Eval_MinReturn : 3772.617919921875
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 3761.528076171875
# Train_StdReturn : 5.702089786529541
# Train_MaxReturn : 3769.97314453125
# Train_MinReturn : 3749.46240234375
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 51297
# TimeSinceStart : 82.0560052394867
# Training Loss : -3.4415283203125
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
#
#
# ********** Iteration 6 ************
#
# Collecting data to be used for training...
# At timestep:     10000 / 10000
# Relabelling collected observations with labels from an expert policy...
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 3768.54296875
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 3768.54296875
# Eval_MinReturn : 3768.54296875
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 3767.501953125
# Train_StdReturn : 3.2991039752960205
# Train_MaxReturn : 3772.21826171875
# Train_MinReturn : 3761.384765625
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 61297
# TimeSinceStart : 96.6656141281128
# Training Loss : -3.198549270629883
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
#
#
# ********** Iteration 7 ************
#
# Collecting data to be used for training...
# At timestep:     10000 / 10000
# Relabelling collected observations with labels from an expert policy...
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 3776.32177734375
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 3776.32177734375
# Eval_MinReturn : 3776.32177734375
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 3765.007080078125
# Train_StdReturn : 2.928715229034424
# Train_MaxReturn : 3769.583740234375
# Train_MinReturn : 3759.513427734375
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 71297
# TimeSinceStart : 110.06821203231812
# Training Loss : -4.421021938323975
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
#
#
# ********** Iteration 8 ************
#
# Collecting data to be used for training...
# At timestep:     10000 / 10000
# Relabelling collected observations with labels from an expert policy...
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 3764.630859375
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 3764.630859375
# Eval_MinReturn : 3764.630859375
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 3778.150390625
# Train_StdReturn : 4.649277210235596
# Train_MaxReturn : 3783.75732421875
# Train_MinReturn : 3769.109375
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 81297
# TimeSinceStart : 130.0249481201172
# Training Loss : -2.302765130996704
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
#
#
# ********** Iteration 9 ************
#
# Collecting data to be used for training...
# At timestep:     10000 / 10000
# Relabelling collected observations with labels from an expert policy...
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 3779.246337890625
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 3779.246337890625
# Eval_MinReturn : 3779.246337890625
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 3769.095703125
# Train_StdReturn : 3.5230789184570312
# Train_MaxReturn : 3774.68408203125
# Train_MinReturn : 3764.38525390625
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 91297
# TimeSinceStart : 144.2568199634552
# Training Loss : -4.5363993644714355
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
# Running Dagger experiment with seed 1
# ########################
# logging outputs to  logs/dagger/Hopper/seed1
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# Hopper-v2
# Loading expert policy from... deeprl/policies/experts/Hopper.pkl
# obs (1, 11) (1, 11)
# Done restoring expert policy...
#
#
# ********** Iteration 0 ************
#
# Training agent...
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 1049.7603759765625
# Eval_StdReturn : 105.64323425292969
# Eval_MaxReturn : 1191.901611328125
# Eval_MinReturn : 903.8468017578125
# Eval_AverageEpLen : 303.5
# Train_AverageReturn : 3772.67041015625
# Train_StdReturn : 1.9483642578125
# Train_MaxReturn : 3774.61865234375
# Train_MinReturn : 3770.721923828125
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 0
# TimeSinceStart : 5.393634796142578
# Training Loss : -3.5583176612854004
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
#
#
# ********** Iteration 1 ************
#
# Collecting data to be used for training...
# At timestep:     10219 / 10000
# Relabelling collected observations with labels from an expert policy...
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 1440.5400390625
# Eval_StdReturn : 195.06094360351562
# Eval_MaxReturn : 1692.3076171875
# Eval_MinReturn : 1217.019287109375
# Eval_AverageEpLen : 397.6666666666667
# Train_AverageReturn : 985.4781494140625
# Train_StdReturn : 198.470458984375
# Train_MaxReturn : 1508.777099609375
# Train_MinReturn : 454.7819519042969
# Train_AverageEpLen : 291.9714285714286
# Train_EnvstepsSoFar : 10219
# TimeSinceStart : 19.65240788459778
# Training Loss : -2.36603045463562
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
#
#
# ********** Iteration 2 ************
#
# Collecting data to be used for training...
# At timestep:     10134 / 10000
# Relabelling collected observations with labels from an expert policy...
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 3777.42626953125
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 3777.42626953125
# Eval_MinReturn : 3777.42626953125
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 1674.734130859375
# Train_StdReturn : 699.9581298828125
# Train_MaxReturn : 3326.99169921875
# Train_MinReturn : 1040.018798828125
# Train_AverageEpLen : 482.57142857142856
# Train_EnvstepsSoFar : 20353
# TimeSinceStart : 31.682497024536133
# Training Loss : -2.240135431289673
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
#
#
# ********** Iteration 3 ************
#
# Collecting data to be used for training...
# At timestep:     10468 / 10000
# Relabelling collected observations with labels from an expert policy...
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 3741.48828125
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 3741.48828125
# Eval_MinReturn : 3741.48828125
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 2635.545166015625
# Train_StdReturn : 838.362548828125
# Train_MaxReturn : 3808.29345703125
# Train_MinReturn : 1428.958740234375
# Train_AverageEpLen : 697.8666666666667
# Train_EnvstepsSoFar : 30821
# TimeSinceStart : 45.06920766830444
# Training Loss : -2.833050012588501
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
#
#
# ********** Iteration 4 ************
#
# Collecting data to be used for training...
# At timestep:     10442 / 10000
# Relabelling collected observations with labels from an expert policy...
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 3795.521728515625
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 3795.521728515625
# Eval_MinReturn : 3795.521728515625
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 3569.343994140625
# Train_StdReturn : 527.3106079101562
# Train_MaxReturn : 3766.02001953125
# Train_MinReturn : 1910.0098876953125
# Train_AverageEpLen : 949.2727272727273
# Train_EnvstepsSoFar : 41263
# TimeSinceStart : 57.40137076377869
# Training Loss : -3.1394989490509033
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
#
#
# ********** Iteration 5 ************
#
# Collecting data to be used for training...
# At timestep:     10000 / 10000
# Relabelling collected observations with labels from an expert policy...
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 3779.07080078125
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 3779.07080078125
# Eval_MinReturn : 3779.07080078125
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 3786.251220703125
# Train_StdReturn : 6.282173156738281
# Train_MaxReturn : 3800.6455078125
# Train_MinReturn : 3776.429443359375
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 51263
# TimeSinceStart : 70.67154002189636
# Training Loss : -3.5945980548858643
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
#
#
# ********** Iteration 6 ************
#
# Collecting data to be used for training...
# At timestep:     10000 / 10000
# Relabelling collected observations with labels from an expert policy...
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 3767.302734375
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 3767.302734375
# Eval_MinReturn : 3767.302734375
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 3776.465576171875
# Train_StdReturn : 4.773916721343994
# Train_MaxReturn : 3782.420166015625
# Train_MinReturn : 3766.45947265625
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 61263
# TimeSinceStart : 83.0494270324707
# Training Loss : -4.26783561706543
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
#
#
# ********** Iteration 7 ************
#
# Collecting data to be used for training...
# At timestep:     10000 / 10000
# Relabelling collected observations with labels from an expert policy...
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 3778.44873046875
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 3778.44873046875
# Eval_MinReturn : 3778.44873046875
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 3774.60498046875
# Train_StdReturn : 3.3513412475585938
# Train_MaxReturn : 3780.65185546875
# Train_MinReturn : 3770.24462890625
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 71263
# TimeSinceStart : 99.60223698616028
# Training Loss : -4.384787559509277
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
#
#
# ********** Iteration 8 ************
#
# Collecting data to be used for training...
# At timestep:     10000 / 10000
# Relabelling collected observations with labels from an expert policy...
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 3783.16162109375
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 3783.16162109375
# Eval_MinReturn : 3783.16162109375
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 3776.39697265625
# Train_StdReturn : 1.8323822021484375
# Train_MaxReturn : 3780.37060546875
# Train_MinReturn : 3773.6875
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 81263
# TimeSinceStart : 115.08604073524475
# Training Loss : -4.334052562713623
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
#
#
# ********** Iteration 9 ************
#
# Collecting data to be used for training...
# At timestep:     10000 / 10000
# Relabelling collected observations with labels from an expert policy...
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 3790.17919921875
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 3790.17919921875
# Eval_MinReturn : 3790.17919921875
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 3777.54052734375
# Train_StdReturn : 2.292917013168335
# Train_MaxReturn : 3781.568359375
# Train_MinReturn : 3774.13525390625
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 91263
# TimeSinceStart : 130.92199993133545
# Training Loss : -4.11234188079834
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
# Running Dagger experiment with seed 2
# ########################
# logging outputs to  logs/dagger/Hopper/seed2
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# Hopper-v2
# Loading expert policy from... deeprl/policies/experts/Hopper.pkl
# obs (1, 11) (1, 11)
# Done restoring expert policy...
#
#
# ********** Iteration 0 ************
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 1125.50048828125
# Eval_StdReturn : 297.20098876953125
# Eval_MaxReturn : 1548.74658203125
# Eval_MinReturn : 757.9973754882812
# Eval_AverageEpLen : 337.0
# Train_AverageReturn : 3772.67041015625
# Train_StdReturn : 1.9483642578125
# Train_MaxReturn : 3774.61865234375
# Train_MinReturn : 3770.721923828125
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 0
# TimeSinceStart : 4.535125970840454
# Training Loss : -3.5946712493896484
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
#
#
# ********** Iteration 1 ************
#
# Collecting data to be used for training...
# At timestep:     10138 / 10000
# Relabelling collected observations with labels from an expert policy...
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 1333.4521484375
# Eval_StdReturn : 344.8636474609375
# Eval_MaxReturn : 1820.841064453125
# Eval_MinReturn : 1074.4146728515625
# Eval_AverageEpLen : 369.0
# Train_AverageReturn : 1052.157958984375
# Train_StdReturn : 261.750732421875
# Train_MaxReturn : 1907.50341796875
# Train_MinReturn : 459.624267578125
# Train_AverageEpLen : 316.8125
# Train_EnvstepsSoFar : 10138
# TimeSinceStart : 19.758391857147217
# Training Loss : -1.8011637926101685
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
#
#
# ********** Iteration 2 ************
#
# Collecting data to be used for training...
# At timestep:     10087 / 10000
# Relabelling collected observations with labels from an expert policy...
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 1517.3055419921875
# Eval_StdReturn : 494.6833190917969
# Eval_MaxReturn : 2215.9140625
# Eval_MinReturn : 1135.955810546875
# Eval_AverageEpLen : 415.0
# Train_AverageReturn : 1372.3607177734375
# Train_StdReturn : 498.2509460449219
# Train_MaxReturn : 3030.372314453125
# Train_MinReturn : 796.6201782226562
# Train_AverageEpLen : 373.5925925925926
# Train_EnvstepsSoFar : 20225
# TimeSinceStart : 33.12146878242493
# Training Loss : -2.4438655376434326
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
#
#
# ********** Iteration 3 ************
#
# Collecting data to be used for training...
# At timestep:     10345 / 10000
# Relabelling collected observations with labels from an expert policy...
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 3628.40478515625
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 3628.40478515625
# Eval_MinReturn : 3628.40478515625
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 1649.8773193359375
# Train_StdReturn : 512.0026245117188
# Train_MaxReturn : 3261.7841796875
# Train_MinReturn : 1074.3609619140625
# Train_AverageEpLen : 449.7826086956522
# Train_EnvstepsSoFar : 30570
# TimeSinceStart : 44.191043853759766
# Training Loss : -2.6091315746307373
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
#
#
# ********** Iteration 4 ************
#
# Collecting data to be used for training...
# At timestep:     10000 / 10000
# Relabelling collected observations with labels from an expert policy...
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 3609.60107421875
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 3609.60107421875
# Eval_MinReturn : 3609.60107421875
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 3685.457763671875
# Train_StdReturn : 40.90141296386719
# Train_MaxReturn : 3765.1630859375
# Train_MinReturn : 3621.573974609375
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 40570
# TimeSinceStart : 57.41380476951599
# Training Loss : -3.593059778213501
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
#
#
# ********** Iteration 5 ************
#
# Collecting data to be used for training...
# At timestep:     10000 / 10000
# Relabelling collected observations with labels from an expert policy...
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 3763.18310546875
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 3763.18310546875
# Eval_MinReturn : 3763.18310546875
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 3595.18994140625
# Train_StdReturn : 42.855010986328125
# Train_MaxReturn : 3674.53271484375
# Train_MinReturn : 3530.157958984375
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 50570
# TimeSinceStart : 71.80023789405823
# Training Loss : -3.023463487625122
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
#
#
# ********** Iteration 6 ************
#
# Collecting data to be used for training...
# At timestep:     10000 / 10000
# Relabelling collected observations with labels from an expert policy...
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 3714.53564453125
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 3714.53564453125
# Eval_MinReturn : 3714.53564453125
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 3748.74072265625
# Train_StdReturn : 32.65801239013672
# Train_MaxReturn : 3778.110595703125
# Train_MinReturn : 3670.92529296875
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 60570
# TimeSinceStart : 84.28722381591797
# Training Loss : -3.946202039718628
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
#
#
# ********** Iteration 7 ************
#
# Collecting data to be used for training...
# At timestep:     10000 / 10000
# Relabelling collected observations with labels from an expert policy...
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 3772.12646484375
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 3772.12646484375
# Eval_MinReturn : 3772.12646484375
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 3682.297607421875
# Train_StdReturn : 19.07257843017578
# Train_MaxReturn : 3716.305908203125
# Train_MinReturn : 3660.740234375
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 70570
# TimeSinceStart : 98.34944272041321
# Training Loss : -4.224006175994873
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
#
#
# ********** Iteration 8 ************
#
# Collecting data to be used for training...
# At timestep:     10000 / 10000
# Relabelling collected observations with labels from an expert policy...
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 3787.5634765625
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 3787.5634765625
# Eval_MinReturn : 3787.5634765625
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 3784.311767578125
# Train_StdReturn : 4.844136714935303
# Train_MaxReturn : 3790.83251953125
# Train_MinReturn : 3776.358154296875
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 80570
# TimeSinceStart : 111.57426381111145
# Training Loss : -2.6909220218658447
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
#
#
# ********** Iteration 9 ************
#
# Collecting data to be used for training...
# At timestep:     10000 / 10000
# Relabelling collected observations with labels from an expert policy...
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 3768.92919921875
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 3768.92919921875
# Eval_MinReturn : 3768.92919921875
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 3778.928955078125
# Train_StdReturn : 4.718024730682373
# Train_MaxReturn : 3786.529296875
# Train_MinReturn : 3771.851318359375
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 90570
# TimeSinceStart : 126.32021188735962
# Training Loss : -3.6129961013793945
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...

# %% [markdown]
# Visualizing the Dagger results on Hopper, we see that Dagger is able to recover the performance of the expert policy after a few iterations of online interaction and expert relabeling.

# %%
### Visualize Dagger results on Hopper
# %load_ext tensorboard
# %tensorboard --logdir logs/dagger/Hopper
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
#       <iframe id="tensorboard-frame-cc86e2beee1612d2" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-cc86e2beee1612d2");
#           const url = new URL("/", window.location);
#           const port = 6008;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
